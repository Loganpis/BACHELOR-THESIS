# %% [markdown]
# <h1 style="font-size:100px; text-align:center;">ORDER PARAMETER</h1>

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import random
from statistics import mean 

k=1
J=0
S1=[]
s1p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s2p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s11p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s31p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s41p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s32p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s42p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s43p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s44p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s33p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s34p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s35p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s45p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s12p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s3p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s13p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s14p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s15p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s21p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s22p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s23p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s24p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s25p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s4p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s5p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p3 = np.random.choice([random.uniform(0, 2*np.pi)])
T=0.1
b= k/T
s = []
def prob(H):
    return np.exp(H*b) 

S = []
T1=[]

while T<1:
    for i in range(5000):
        s1p1e2 =np.random.choice([random.uniform(0, 2*np.pi)])
        s1p2e2 =np.random.choice([random.uniform(0, 2*np.pi)])
        s1p3e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    
        s2p1e2 =s2p1
        s2p2e2 =s2p2
        s2p3e2 =s2p3
        
        s11p1e2 = s11p1
        s11p2e2 = s11p2
        s11p3e2 = s11p3
        
        s31p1e2 = s31p1
        s31p2e2 = s31p2
        s31p3e2 = s31p3
        
        s41p1e2 = s41p1
        s41p2e2 = s41p2
        s41p3e2 = s41p3
        
        s42p1e2 = s42p1
        s42p2e2 = s42p2
        s42p3e2 = s42p3
        
        s43p1e2 = s43p1
        s43p2e2 = s43p2
        s43p3e2 = s43p3
        
        s44p1e2 = s44p1
        s44p2e2 = s44p2
        s44p3e2 = s44p3
        
        s32p1e2 = s32p1
        s32p2e2 = s32p2
        s32p3e2 = s32p3
        
        s33p1e2 = s33p1
        s33p2e2 = s33p2
        s33p3e2 = s33p3
        
        s34p1e2 = s34p1
        s34p2e2 = s34p2
        s34p3e2 = s34p3
        
        s35p1e2 = s35p1
        s35p2e2 = s35p2
        s35p3e2 = s35p3
        
        s45p1e2 = s45p1
        s45p2e2 = s45p2
        s45p3e2 = s45p3
        
        s12p1e2 = s12p1
        s12p2e2 = s12p2
        s12p3e2 = s12p3
        
        s13p1e2 = s13p1
        s13p2e2 = s13p2
        s13p3e2 = s13p3
        
        s3p1e2 = s3p1
        s3p2e2 = s3p2
        s3p3e2 = s3p3
        
        s4p1e2 = s4p1
        s4p2e2 = s4p2
        s4p3e2 = s4p3
        
        s14p1e2 = s14p1
        s14p2e2 = s14p2
        s14p3e2 = s14p3
        
        s15p1e2 = s15p1
        s15p2e2 = s15p2
        s15p3e2 = s15p3
        
        s21p1e2 = s21p1
        s21p2e2 = s21p2
        s21p3e2 = s21p3
        
        s5p1e2 = s5p1
        s5p2e2 = s5p2
        s5p3e2 = s5p3
        
        s22p1e2 = s22p1
        s22p2e2 = s22p2
        s22p3e2 = s22p3
        
        s23p1e2 = s23p1
        s23p2e2 = s23p2
        s23p3e2 = s23p3
        
        s24p1e2 = s24p1
        s24p2e2 = s24p2
        s24p3e2 = s24p3
        
        s25p1e2 = s25p1
        s25p2e2 = s25p2
        s25p3e2 = s25p3
    #site1        
        H1 = - np.cos(s1p1-s1p2) - np.cos(s1p2-s1p3)- np.cos(s1p3-s1p1)+ np.cos(s1p1-s2p1)+ np.cos(s1p2-s2p2)+ np.cos(s1p3-s2p3)+ np.cos(s1p1-s11p1)+ np.cos(s1p2-s11p2)+ np.cos(s1p3-s11p3)+ np.cos(s1p1-s41p1)+ np.cos(s1p2-s41p2)+ np.cos(s1p3-s41p3)+ np.cos(s1p1-s5p1)+ np.cos(s1p2-s5p2)+ np.cos(s1p3-s5p3)
        
        H12 = - np.cos(s1p1e2-s1p2e2)- np.cos(s1p3e2-s1p1e2)- np.cos(s1p2e2-s1p3e2)+ np.cos(s1p1e2-s2p1e2)+ np.cos(s1p2e2-s2p2e2)+ np.cos(s1p3e2-s2p3e2)+ np.cos(s1p1e2-s11p1e2)+ np.cos(s1p2e2-s11p2e2)+ np.cos(s1p3e2-s11p3e2)+ np.cos(s1p1e2-s41p1e2)+ np.cos(s1p2e2-s41p2e2)+ np.cos(s1p3e2-s41p3e2)+ np.cos(s1p1e2-s5p1e2)+ np.cos(s1p2e2-s5p2e2)+ np.cos(s1p3e2-s5p3e2)
    
        r= prob(H12)/prob(H1)
        x= np.random.choice([random.uniform(0, 1)])
        if r >= x:
            s1p1n = s1p1e2
            s1p2n = s1p2e2
            s1p3n = s1p3e2
            
            s1p1 = s1p1e2
            s1p2 = s1p2e2
            s1p3 = s1p3e2
            
        else:
            s1p1n = s1p1
            s1p2n = s1p2
            s1p3n = s1p3
        if s1p1n>=s1p2n>=s1p3n:
            s1= -1
        if s1p2n>=s1p1n>=s1p3n:    
            s1=1
        if s1p3n>=s1p2n>=s1p1n:   
            s1=1
        if s1p3n>=s1p1n>=s1p2n:    
            s1= -1     
        if s1p1n>=s1p3n>=s1p2n:
            s1=1    
        if s1p2n>=s1p3n>=s1p1n:    
            s1= -1       
        s1p1e2 =s1p1
        s1p2e2 =s1p2
        s1p3e2 =s1p3
        
        s2p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s2p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s2p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site2    
        H2 = - np.cos(s2p2-s2p3)- np.cos(s2p3-s2p1)- np.cos(s2p1-s2p2)+ np.cos(s2p1-s12p1)+ np.cos(s2p2-s12p2)+ np.cos(s2p3-s12p3)+ np.cos(s2p1-s1p1)+ np.cos(s2p2-s1p2)+ np.cos(s2p3-s1p2)+ np.cos(s2p1-s3p1)+ np.cos(s2p2-s3p2)+ np.cos(s2p3-s3p3)+ np.cos(s2p1-s42p1)+ np.cos(s2p2-s42p2)+ np.cos(s2p3-s42p3)
    
        H22 =- np.cos(s2p3e2-s2p1e2)- np.cos(s2p2e2-s2p3e2)- np.cos(s2p1e2-s2p2e2)+ np.cos(s2p1e2-s1p1e2)+ np.cos(s2p2e2-s1p2e2)+ np.cos(s2p3e2-s1p3e2)+ np.cos(s2p1e2-s12p1e2)+ np.cos(s2p2e2-s12p2e2)+ np.cos(s2p3e2-s12p3e2)+ np.cos(s2p1e2-s3p1e2)+ np.cos(s2p2e2-s3p2e2)+ np.cos(s2p3e2-s3p3e2)+ np.cos(s2p1e2-s42p1e2)+ np.cos(s2p2e2-s42p2e2)+ np.cos(s2p3e2-s42p3e2)
    
        r1 = prob(H22)/prob(H2)
        x1 = np.random.choice([random.uniform(0, 1)])
        if r1 >= x1:
            s2p1n = s2p1e2
            s2p2n = s2p2e2
            s2p3n = s2p3e2
            
            s2p1 = s2p1e2
            s2p2 = s2p2e2
            s2p3 = s2p3e2
            
        else:
            s2p1n = s2p1
            s2p2n = s2p2
            s2p3n = s2p3
            
        if s2p1n>=s2p2n>=s2p3n:
            s2= -1
        if s2p2n>=s2p1n>=s2p3n:    
            s2=1
        if s2p3n>=s2p2n>=s2p1n:   
            s2=1
        if s2p3n>=s2p1n>=s2p2n:    
            s2= -1     
        if s2p1n>=s2p3n>=s2p2n:
            s2=1    
        if s2p2n>=s2p3n>=s2p1n:    
            s2= -1    
        s2p1e2 = s2p1
        s2p2e2 = s2p2
        s2p3e2 = s2p3
        
        s3p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s3p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s3p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site3    
        H3 = -np.cos(s3p2-s3p3)- np.cos(s3p3-s3p1)- np.cos(s3p1-s3p2)+ np.cos(s3p1-s2p1)+ np.cos(s3p2-s2p2)+ np.cos(s3p3-s2p3)+ np.cos(s3p1-s13p1)+ np.cos(s3p2-s13p2)+ np.cos(s3p3-s13p3)+ np.cos(s3p1-s4p1)+ np.cos(s3p2-s4p2)+ np.cos(s3p3-s4p3)+ np.cos(s3p1-s43p1)+ np.cos(s3p2-s43p2)+ np.cos(s3p3-s43p3)
    
        H32 = - np.cos(s3p2e2-s3p3e2)- np.cos(s3p3e2-s3p1e2)- np.cos(s3p1e2-s3p2e2)+ np.cos(s3p1e2-s2p1e2)+ np.cos(s3p2e2-s2p2e2)+ np.cos(s3p3e2-s2p3e2)+ np.cos(s3p1e2-s13p1e2)+ np.cos(s3p2e2-s13p2e2)+ np.cos(s3p3e2-s13p3e2)+ np.cos(s3p1e2-s4p1e2)+ np.cos(s3p2e2-s4p2e2)+ np.cos(s3p3e2-s4p3e2)+ np.cos(s3p1e2-s43p1e2)+ np.cos(s3p2e2-s43p2e2)+ np.cos(s3p3e2-s43p3e2)
      
        r2 = prob(H32)/prob(H3)
        x2 = np.random.choice([random.uniform(0, 1)])
        if r2 >= x2:
            s3p1n = s3p1e2
            s3p2n = s3p2e2
            s3p3n = s3p3e2
            
            s3p1 = s3p1e2
            s3p2 = s3p2e2
            s3p3 = s3p3e2
        else:
            s3p1n = s3p1
            s3p2n = s3p2
            s3p3n = s3p3
        if s3p1n>=s3p2n>=s3p3n:
            s3= -1
        if s3p2n>=s3p1n>=s3p3n:    
            s3=1
        if s3p3n>=s3p2n>=s3p1n:   
            s3=1
        if s3p3n>=s3p1n>=s3p2n:    
            s3= -1     
        if s3p1n>=s3p3n>=s3p2n:
            s3=1    
        if s3p2n>=s3p3n>=s3p1n:    
            s3= -1     
        s3p1e2 = s3p1
        s3p2e2 = s3p2
        s3p3e2 = s3p3
        
        s4p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s4p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s4p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site4    
        H4 = - np.cos(s4p2-s4p3)- np.cos(s4p3-s4p1)- np.cos(s4p1-s4p2)+ np.cos(s4p1-s3p1)+ np.cos(s4p2-s3p2)+ np.cos(s4p3-s3p3)+ np.cos(s4p1-s14p1)+ np.cos(s4p2-s14p2)+ np.cos(s4p3-s14p3)+ np.cos(s4p1-s5p1)+ np.cos(s4p2-s5p2)+ np.cos(s4p3-s5p3)+ np.cos(s4p1-s44p1)+ np.cos(s4p2-s44p2)+ np.cos(s4p3-s44p3)
    
        H42 = - np.cos(s4p3e2-s4p1e2)- np.cos(s4p2e2-s3p3e2)- np.cos(s4p1e2-s4p2e2)+ np.cos(s4p1e2-s3p1e2)+ np.cos(s4p2e2-s3p2e2)+ np.cos(s4p3e2-s3p3e2)+ np.cos(s4p1e2-s14p1e2)+ np.cos(s4p2e2-s14p2e2)+ np.cos(s4p3e2-s14p3e2)+ np.cos(s4p1e2-s5p1e2)+ np.cos(s4p2e2-s5p2e2)+ np.cos(s4p3e2-s5p3e2)+ np.cos(s4p1e2-s44p1e2)+ np.cos(s4p2e2-s44p2e2)+ np.cos(s4p3e2-s44p3e2)
    
        r3 = prob(H42)/prob(H4)
        x3 = np.random.choice([random.uniform(0, 1)])
        if r3 >= x3:
            s4p1n = s4p1e2
            s4p2n = s4p2e2
            s4p3n = s4p3e2
            
            s4p1 = s4p1e2
            s4p2 = s4p2e2
            s4p3 = s4p3e2
        else:
            s4p1n = s4p1
            s4p2n = s4p2
            s4p3n = s4p3
        if s4p1n>=s4p2n>=s4p3n:
            s4= -1
        if s4p2n>=s4p1n>=s4p3n:    
            s4=1
        if s4p3n>=s4p2n>=s4p1n:   
            s4=1
        if s4p3n>=s4p1n>=s4p2n:    
            s4= -1     
        if s4p1n>=s4p3n>=s4p2n:
            s4=1    
        if s4p2n>=s4p3n>=s4p1n:    
            s4= -1    
        s4p1e2 = s4p1
        s4p2e2 = s4p2
        s4p3e2 = s4p3
        
        s5p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s5p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s5p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site5    
        H5 =- np.cos(s5p2-s5p3)- np.cos(s5p3-s5p1)- np.cos(s5p1-s5p2)+ np.cos(s5p1-s4p1)+ np.cos(s5p2-s4p2)+ np.cos(s5p3-s4p3)+ np.cos(s5p1-s15p1)+ np.cos(s5p2-s15p2)+ np.cos(s5p3-s15p3)+ np.cos(s5p1-s45p1)+ np.cos(s5p2-s45p2)+ np.cos(s5p3-s45p3)+ np.cos(s5p1-s1p1)+ np.cos(s5p2-s1p2)+ np.cos(s5p3-s1p3)
    
        H52 = - np.cos(s5p3e2-s5p1e2)- np.cos(s5p2e2-s5p3e2)- np.cos(s5p1e2-s5p2e2)+ np.cos(s5p1e2-s4p1e2)+ np.cos(s5p2e2-s4p2e2)+ np.cos(s5p3e2-s4p3e2)+ np.cos(s5p1e2-s15p1e2)+ np.cos(s5p2e2-s15p2e2)+ np.cos(s5p3e2-s15p3e2)+ np.cos(s5p1e2-s45p1e2)+ np.cos(s5p2e2-s45p2e2)+ np.cos(s5p3e2-s45p3e2)+ np.cos(s5p1e2-s1p1e2)+ np.cos(s5p2e2-s1p2e2)+ np.cos(s5p3e2-s1p3e2)
    
        r4 = prob(H52)/prob(H5)
        x4 = np.random.choice([random.uniform(0, 1)])
        if r4 >= x4:
            s5p1n = s5p1e2
            s5p2n = s5p2e2
            s5p3n = s5p3e2
            
            s5p1 = s5p1e2
            s5p2 = s5p2e2
            s5p3 = s5p3e2
        else:
            s5p1n = s5p1
            s5p2n = s5p2
            s5p3n = s5p3
        if s5p1n>=s5p2n>=s5p3n:
            s5= -1
        if s5p2n>=s5p1n>=s5p3n:    
            s5=1
        if s5p3n>=s5p2n>=s5p1n:   
            s5=1
        if s5p3n>=s5p1n>=s5p2n:    
            s5= -1     
        if s5p1n>=s5p3n>=s5p2n:
            s5=1    
        if s5p2n>=s5p3n>=s5p1n:    
            s5= -1              
        s5p1e2 = s5p1
        s5p2e2 = s5p2
        s5p3e2 = s5p3
        
        s11p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s11p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s11p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site11    
        H11 =- np.cos(s11p3-s11p1)- np.cos(s11p2-s11p3)- np.cos(s11p1-s11p2)+ np.cos(s11p1-s1p1)+ np.cos(s11p2-s1p2)+ np.cos(s11p3-s1p3)+ np.cos(s11p1-s12p1)+ np.cos(s11p2-s12p2)+ np.cos(s11p3-s12p3)+ np.cos(s11p1-s21p1)+ np.cos(s11p2-s21p2)+ np.cos(s11p3-s21p3)+ np.cos(s11p1-s15p1)+ np.cos(s11p2-s15p2)+ np.cos(s11p3-s15p3)
    
        H112 =- np.cos(s11p3e2-s11p1e2)- np.cos(s11p2e2-s11p3e2)- np.cos(s11p1e2-s11p2e2)+ np.cos(s11p1e2-s1p1e2)+ np.cos(s11p2e2-s1p2e2)+ np.cos(s11p3e2-s1p3e2)+ np.cos(s11p1e2-s12p1e2)+ np.cos(s11p2e2-s12p2e2)+ np.cos(s11p3e2-s12p3e2)+ np.cos(s11p1e2-s21p1e2)+ np.cos(s11p2e2-s21p2e2)+ np.cos(s11p3e2-s21p3e2)+ np.cos(s11p1e2-s15p1e2)+ np.cos(s11p2e2-s15p2e2)+ np.cos(s11p3e2-s15p3e2)
    
        r11 = prob(H112)/prob(H11)
        x11 = np.random.choice([random.uniform(0, 1)])
        if r11 >= x11:
            s11p1n = s11p1e2
            s11p2n = s11p2e2
            s11p3n = s11p3e2
            
            s11p1 = s11p1e2
            s11p2 = s11p2e2
            s11p3 = s11p3e2
            
        else:
            s11p1n = s11p1
            s11p2n = s11p2
            s11p3n = s11p3
        if s11p1n>=s11p2n>=s11p3n:
            s11= -1
        if s11p2n>=s11p1n>=s11p3n:    
            s11=1
        if s11p3n>=s11p2n>=s11p1n:   
            s11=1
        if s11p3n>=s11p1n>=s11p2n:    
            s11= -1     
        if s11p1n>=s11p3n>=s11p2n:
            s11=1    
        if s11p2n>=s11p3n>=s11p1n:    
            s11= -1             
        s11p1e2 = s11p1
        s11p2e2 = s11p2
        s11p3e2 = s11p3
        
        s12p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s12p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s12p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site12    
        H12s =- np.cos(s12p3-s12p1)- np.cos(s12p2-s12p3)- np.cos(s12p1-s12p2)+ np.cos(s12p1-s2p1)+ np.cos(s12p2-s2p2)+ np.cos(s12p3-s2p3)+ np.cos(s12p1-s13p1)+ np.cos(s12p2-s13p2)+ np.cos(s12p3-s13p3)+ np.cos(s12p1-s22p1)+ np.cos(s12p2-s22p2)+ np.cos(s12p3-s22p3)+ np.cos(s12p1-s11p1)+ np.cos(s12p2-s11p2)+ np.cos(s12p3-s11p3)
    
        H122 =- np.cos(s12p3e2-s12p1e2)- np.cos(s12p2e2-s12p3e2)- np.cos(s12p1e2-s12p2e2)+ np.cos(s12p1e2-s2p1e2)+ np.cos(s12p2e2-s2p2e2)+ np.cos(s12p3e2-s2p3e2)+ np.cos(s12p1e2-s13p1e2)+ np.cos(s12p2e2-s13p2e2)+ np.cos(s12p3e2-s13p3e2)+ np.cos(s12p1e2-s22p1e2)+ np.cos(s12p2e2-s22p2e2)+ np.cos(s12p3e2-s22p3e2)+ np.cos(s12p1e2-s11p1e2)+ np.cos(s12p2e2-s11p2e2)+ np.cos(s12p3e2-s11p3e2)
    
        r12 = prob(H122)/prob(H12s)
        x12 = np.random.choice([random.uniform(0, 1)])
        if r12 >= x12:
            s12p1n = s12p1e2
            s12p2n = s12p2e2
            s12p3n = s12p3e2
            
            s12p1 = s12p1e2
            s12p2 = s12p2e2
            s12p3 = s12p3e2
            
        else:
            s12p1n = s12p1
            s12p2n = s12p2
            s12p3n = s12p3
        if s12p1n>=s12p2n>=s12p3n:
            s12= -1
        if s12p2n>=s12p1n>=s12p3n:    
            s12=1
        if s12p3n>=s12p2n>=s12p1n:   
            s12=1
        if s12p3n>=s12p1n>=s12p2n:    
            s12= -1     
        if s12p1n>=s12p3n>=s12p2n:
            s12=1    
        if s12p2n>=s12p3n>=s12p1n:    
            s12= -1        
        s12p1e2 = s12p1
        s12p2e2 = s12p2
        s12p3e2 = s12p3
        
        s13p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s13p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s13p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site13    
        H13 =- np.cos(s13p3-s13p1)- np.cos(s13p2-s13p3)- np.cos(s13p1-s13p2)+ np.cos(s13p1-s3p1)+ np.cos(s13p2-s3p2)+ np.cos(s13p3-s3p3)+ np.cos(s13p1-s14p1)+ np.cos(s13p2-s14p2)+ np.cos(s13p3-s14p3)+ np.cos(s13p1-s23p1)+ np.cos(s13p2-s23p2)+ np.cos(s13p3-s23p3)+ np.cos(s13p1-s12p1)+ np.cos(s13p2-s12p2)+ np.cos(s13p3-s12p3)
    
        H132 =- np.cos(s13p3e2-s13p1e2)- np.cos(s13p2e2-s13p3e2)- np.cos(s13p1e2-s13p2e2)+ np.cos(s13p1e2-s3p1e2)+ np.cos(s13p2e2-s3p2e2)+ np.cos(s13p3e2-s3p3e2)+ np.cos(s13p1e2-s14p1e2)+ np.cos(s13p2e2-s14p2e2)+ np.cos(s13p3e2-s14p3e2)+ np.cos(s13p1e2-s23p1e2)+ np.cos(s13p2e2-s23p2e2)+ np.cos(s13p3e2-s23p3e2)+ np.cos(s13p1e2-s12p1e2)+ np.cos(s13p2e2-s12p2e2)+ np.cos(s13p3e2-s12p3e2)
    
        r13 = prob(H132)/prob(H13)
        x13 = np.random.choice([random.uniform(0, 1)])
        if r13 >= x13:
            s13p1n = s13p1e2
            s13p2n = s13p2e2
            s13p3n = s13p3e2
            
            s13p1 = s13p1e2
            s13p2 = s13p2e2
            s13p3 = s13p3e2
            
        else:
            s13p1n = s13p1
            s13p2n = s13p2
            s13p3n = s13p3
        if s13p1n>=s13p2n>=s13p3n:
            s13= -1
        if s13p2n>=s13p1n>=s13p3n:    
            s13=1
        if s13p3n>=s13p2n>=s13p1n:   
            s13=1
        if s13p3n>=s13p1n>=s13p2n:    
            s13= -1     
        if s13p1n>=s13p3n>=s13p2n:
            s13=1    
        if s13p2n>=s13p3n>=s13p1n:    
            s13= -1     
        s13p1e2 = s13p1
        s13p2e2 = s13p2
        s13p3e2 = s13p3
        
        s14p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s14p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s14p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site14    
        H14 =- np.cos(s14p3-s14p1)- np.cos(s14p2-s14p3)- np.cos(s14p1-s14p2)+ np.cos(s14p1-s4p1)+ np.cos(s14p2-s4p2)+ np.cos(s14p3-s4p3)+ np.cos(s14p1-s15p1)+ np.cos(s14p2-s15p2)+ np.cos(s14p3-s15p3)+ np.cos(s14p1-s24p1)+ np.cos(s14p2-s24p2)+ np.cos(s14p3-s24p3)+ np.cos(s14p1-s13p1)+ np.cos(s14p2-s13p2)+ np.cos(s14p3-s13p3)
    
        H142 =- np.cos(s14p3e2-s14p1e2)- np.cos(s14p2e2-s14p3e2)- np.cos(s14p1e2-s14p2e2)+ np.cos(s14p1e2-s4p1e2)+ np.cos(s14p2e2-s4p2e2)+ np.cos(s14p3e2-s4p3e2)+ np.cos(s14p1e2-s15p1e2)+ np.cos(s14p2e2-s15p2e2)+ np.cos(s14p3e2-s15p3e2)+ np.cos(s14p1e2-s24p1e2)+ np.cos(s14p2e2-s24p2e2)+ np.cos(s14p3e2-s24p3e2)+ np.cos(s14p1e2-s13p1e2)+ np.cos(s14p2e2-s13p2e2)+ np.cos(s14p3e2-s13p3e2)
    
        r14 = prob(H142)/prob(H14)
        x14 = np.random.choice([random.uniform(0, 1)])
        if r14 >= x14:
            s14p1n = s14p1e2
            s14p2n = s14p2e2
            s14p3n = s14p3e2
            
            s14p1 = s14p1e2
            s14p2 = s14p2e2
            s14p3 = s14p3e2
            
        else:
            s14p1n = s14p1
            s14p2n = s14p2
            s14p3n = s14p3
        if s14p1n>=s14p2n>=s14p3n:
            s14= -1
        if s14p2n>=s14p1n>=s14p3n:    
            s14=1
        if s14p3n>=s14p2n>=s14p1n:   
            s14=1
        if s14p3n>=s14p1n>=s14p2n:    
            s14= -1     
        if s14p1n>=s14p3n>=s14p2n:
            s14=1    
        if s14p2n>=s14p3n>=s14p1n:    
            s14= -1  
        s14p1e2 = s14p1
        s14p2e2 = s14p2
        s14p3e2 = s14p3

        s15p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s15p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s15p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])                  
    #site15    
        H15 =- np.cos(s15p3-s15p1)- np.cos(s15p2-s15p3)- np.cos(s15p1-s15p2)+ np.cos(s15p1-s5p1)+ np.cos(s15p2-s5p2)+ np.cos(s15p3-s5p3)+ np.cos(s15p1-s25p1)+ np.cos(s15p2-s25p2)+ np.cos(s15p3-s25p3)+ np.cos(s15p1-s14p1)+ np.cos(s15p2-s14p2)+ np.cos(s15p3-s14p3)+ np.cos(s15p1-s11p1)+ np.cos(s15p2-s11p2)+ np.cos(s15p3-s11p3)
    
        H152 =- np.cos(s15p3e2-s15p1e2)- np.cos(s15p2e2-s15p3e2)- np.cos(s15p1e2-s15p2e2)+ np.cos(s15p1e2-s5p1e2)+ np.cos(s15p2e2-s5p2e2)+ np.cos(s15p3e2-s5p3e2)+ np.cos(s15p1e2-s25p1e2)+ np.cos(s15p2e2-s25p2e2)+ np.cos(s15p3e2-s25p3e2)+ np.cos(s15p1e2-s14p1e2)+ np.cos(s15p2e2-s14p2e2)+ np.cos(s15p3e2-s14p3e2)+ np.cos(s15p1e2-s11p1e2)+ np.cos(s15p2e2-s11p2e2)+ np.cos(s15p3e2-s11p3e2)
    
        r15 = prob(H152)/prob(H15)
        x15 = np.random.choice([random.uniform(0, 1)])
        if r15 >= x15:
            s15p1n = s15p1e2
            s15p2n = s15p2e2
            s15p3n = s15p3e2
            
            s15p1 = s15p1e2
            s15p2 = s15p2e2
            s15p3 = s15p3e2
        else:
            s15p1n = s15p1
            s15p2n = s15p2
            s15p3n = s15p3
        if s15p1n>=s15p2n>=s15p3n:
            s15= -1
        if s15p2n>=s15p1n>=s15p3n:    
            s15=1
        if s15p3n>=s15p2n>=s15p1n:   
            s15=1
        if s15p3n>=s15p1n>=s15p2n:    
            s15= -1     
        if s15p1n>=s15p3n>=s15p2n:
            s15=1    
        if s15p2n>=s15p3n>=s15p1n:    
            s15= -1    
        s15p1e2 = s15p1
        s15p2e2 = s15p2
        s15p3e2 = s15p3

        s21p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s21p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s21p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
    #site21    
        H21 =- np.cos(s21p3-s21p1)- np.cos(s21p2-s21p3)- np.cos(s21p1-s21p2)+ np.cos(s21p1-s11p1)+ np.cos(s21p2-s11p2)+ np.cos(s21p3-s11p3)+ np.cos(s21p1-s31p1)+ np.cos(s21p2-s31p2)+ np.cos(s21p3-s31p3)+ np.cos(s21p1-s22p1)+ np.cos(s21p2-s22p2)+ np.cos(s21p3-s22p3)+ np.cos(s21p1-s25p1)+ np.cos(s21p2-s25p2)+ np.cos(s21p3-s25p3)
    
        H212 =- np.cos(s21p3e2-s21p1e2)- np.cos(s21p2e2-s21p3e2)- np.cos(s21p1e2-s21p2e2)+ np.cos(s21p1e2-s11p1e2)+ np.cos(s21p2e2-s11p2e2)+ np.cos(s21p3e2-s11p3e2)+ np.cos(s21p1e2-s31p1e2)+ np.cos(s21p2e2-s31p2e2)+ np.cos(s21p3e2-s31p3e2)+ np.cos(s21p1e2-s22p1e2)+ np.cos(s21p2e2-s22p2e2)+ np.cos(s21p3e2-s22p3e2)+ np.cos(s21p1e2-s25p1e2)+ np.cos(s21p2e2-s25p2e2)+ np.cos(s21p3e2-s25p3e2)
    
        r21 = prob(H212)/prob(H21)
        x21 = np.random.choice([random.uniform(0, 1)])
        if r21 >= x21:
            s21p1n = s21p1e2
            s21p2n = s21p2e2
            s21p3n = s21p3e2
            
            s21p1 = s21p1e2
            s21p2 = s21p2e2
            s21p3 = s21p3e2
  
        else:
            s21p1n = s21p1
            s21p2n = s21p2
            s21p3n = s21p3
        if s21p1n>=s21p2n>=s21p3n:
            s21= -1
        if s21p2n>=s21p1n>=s21p3n:    
            s21=1
        if s21p3n>=s21p2n>=s21p1n:   
            s21=1
        if s21p3n>=s21p1n>=s21p2n:    
            s21= -1     
        if s21p1n>=s21p3n>=s21p2n:
            s21=1    
        if s21p2n>=s21p3n>=s21p1n:    
            s21= -1
        s21p1e2 = s21p1
        s21p2e2 = s21p2
        s21p3e2 = s22p3   

        s22p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s22p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s22p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])            
    #site22    
        H22 =- np.cos(s22p3-s22p1)- np.cos(s22p2-s22p3)- np.cos(s22p1-s22p2)+ np.cos(s22p1-s12p1)+ np.cos(s22p2-s12p2)+ np.cos(s22p3-s12p3)+ np.cos(s22p1-s32p1)+ np.cos(s22p2-s32p2)+ np.cos(s22p3-s32p3)+ np.cos(s22p1-s23p1)+ np.cos(s22p2-s23p2)+ np.cos(s22p3-s23p3)+ np.cos(s22p1-s21p1)+ np.cos(s22p2-s21p2)+ np.cos(s22p3-s21p3)
    
        H222 =- np.cos(s22p3e2-s22p1e2)- np.cos(s22p2e2-s22p3e2)- np.cos(s22p1e2-s22p2e2)+ np.cos(s22p1e2-s12p1e2)+ np.cos(s22p2e2-s12p2e2)+ np.cos(s22p3e2-s12p3e2)+ np.cos(s22p1e2-s32p1e2)+ np.cos(s22p2e2-s32p2e2)+ np.cos(s22p3e2-s32p3e2)+ np.cos(s22p1e2-s23p1e2)+ np.cos(s22p2e2-s23p2e2)+ np.cos(s22p3e2-s23p3e2)+ np.cos(s22p1e2-s21p1e2)+ np.cos(s22p2e2-s21p2e2)+ np.cos(s22p3e2-s21p3e2)
    
        r22 = prob(H222)/prob(H22)
        x22 = np.random.choice([random.uniform(0, 1)])
        if r22 >= x22:
            s22p1n = s22p1e2
            s22p2n = s22p2e2
            s22p3n = s22p3e2
            
            s22p1 = s22p1e2
            s22p2 = s22p2e2
            s22p3 = s22p3e2
            
        else:
            s22p1n = s22p1
            s22p2n = s22p2
            s22p3n = s22p3
        if s22p1n>=s22p2n>=s22p3n:
            s22= -1
        if s22p2n>=s22p1n>=s22p3n:    
            s22=1
        if s22p3n>=s22p2n>=s22p1n:   
            s22=1
        if s22p3n>=s22p1n>=s22p2n:    
            s22= -1     
        if s22p1n>=s22p3n>=s22p2n:
            s22=1    
        if s22p2n>=s22p3n>=s22p1n:    
            s22= -1      
        s22p1e2 = s22p1
        s22p2e2 = s22p2
        s22p3e2 = s22p3  
        
        s23p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s23p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s23p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])   
    #site23    
        H23 =- np.cos(s23p3-s23p1)- np.cos(s23p2-s23p3)- np.cos(s23p1-s23p2)+ np.cos(s23p1-s13p1)+ np.cos(s23p2-s13p2)+ np.cos(s23p3-s13p3)+ np.cos(s23p1-s33p1)+ np.cos(s23p2-s33p2)+ np.cos(s23p3-s33p3)+ np.cos(s23p1-s24p1)+ np.cos(s23p2-s24p2)+ np.cos(s23p3-s24p3)+ np.cos(s23p1-s22p1)+ np.cos(s23p2-s22p2)+ np.cos(s23p3-s22p3)
    
        H232 =- np.cos(s23p3e2-s23p1e2)- np.cos(s23p2e2-s23p3e2)- np.cos(s23p1e2-s23p2e2)+ np.cos(s23p1e2-s13p1e2)+ np.cos(s23p2e2-s13p2e2)+ np.cos(s23p3e2-s13p3e2)+ np.cos(s23p1e2-s33p1e2)+ np.cos(s23p2e2-s33p2e2)+ np.cos(s23p3e2-s33p3e2)+ np.cos(s23p1e2-s24p1e2)+ np.cos(s23p2e2-s24p2e2)+ np.cos(s23p3e2-s24p3e2)+ np.cos(s23p1e2-s22p1e2)+ np.cos(s23p2e2-s22p2e2)+ np.cos(s23p3e2-s22p3e2)
    
        r23 = prob(H232)/prob(H23)
        x23 = np.random.choice([random.uniform(0, 1)])
        if r23>=x23:
            s23p1n = s23p1e2
            s23p2n = s23p2e2
            s23p3n = s23p3e2
            
            s23p1 = s23p1e2
            s23p2 = s23p2e2
            s23p3 = s23p3e2

        else:
            s23p1n = s23p1
            s23p2n = s23p2
            s23p3n = s23p3
        if s23p1n>=s23p2n>=s23p3n:
            s23= -1
        if s23p2n>=s23p1n>=s23p3n:    
            s23=1
        if s23p3n>=s23p2n>=s23p1n:   
            s23=1
        if s23p3n>=s23p1n>=s23p2n:    
            s23= -1     
        if s23p1n>=s23p3n>=s23p2n:
            s23=1    
        if s23p2n>=s23p3n>=s23p1n:    
            s23= -1     
        s23p1e2 = s23p1
        s23p2e2 = s23p2
        s23p3e2 = s23p3
        
        s24p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s24p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s24p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])           
    #site24    
        H24 =- np.cos(s24p3-s24p1)- np.cos(s24p2-s24p3)- np.cos(s24p1-s24p2)+ np.cos(s24p1-s14p1)+ np.cos(s24p2-s14p2)+ np.cos(s24p3-s14p3)+ np.cos(s24p1-s34p1)+ np.cos(s24p2-s34p2)+ np.cos(s24p3-s34p3)+ np.cos(s24p1-s25p1)+ np.cos(s24p2-s25p2)+ np.cos(s24p3-s25p3)+ np.cos(s24p1-s23p1)+ np.cos(s24p2-s23p2)+ np.cos(s24p3-s23p3)
    
        H242 =- np.cos(s24p3e2-s24p1e2)- np.cos(s24p2e2-s24p3e2)- np.cos(s24p1e2-s24p2e2)+ np.cos(s24p1e2-s14p1e2)+ np.cos(s24p2e2-s14p2e2)+ np.cos(s24p3e2-s14p3e2)+ np.cos(s24p1e2-s34p1e2)+ np.cos(s24p2e2-s34p2e2)+ np.cos(s24p3e2-s34p3e2)+ np.cos(s24p1e2-s25p1e2)+ np.cos(s24p2e2-s25p2e2)+ np.cos(s24p3e2-s25p3e2)+ np.cos(s24p1e2-s23p1e2)+ np.cos(s24p2e2-s23p2e2)+ np.cos(s24p3e2-s23p3e2)
    
        r24 = prob(H242)/prob(H24)
        x24 = np.random.choice([random.uniform(0, 1)])
        if r24>=x24:
            s24p1n = s24p1e2
            s24p2n = s24p2e2
            s24p3n = s24p3e2
            
            s24p1 = s24p1e2
            s24p2 = s24p2e2
            s24p3 = s24p3e2

        else:
            s24p1n = s24p1
            s24p2n = s24p2
            s24p3n = s24p3 
        if s24p1n>=s24p2n>=s24p3n:
            s24= -1
        if s24p2n>=s24p1n>=s24p3n:    
            s24=1
        if s24p3n>=s24p2n>=s24p1n:   
            s24=1
        if s24p3n>=s24p1n>=s24p2n:    
            s24= -1     
        if s24p1n>=s24p3n>=s24p2n:
            s24=1    
        if s24p2n>=s24p3n>=s24p1n:    
            s24= -1             
        s24p1e2 = s24p1
        s24p2e2 = s24p2
        s24p3e2 = s24p3 
        
        s25p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s25p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s25p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
    #site25    
        H25 =- np.cos(s25p3-s25p1)- np.cos(s25p2-s25p3)- np.cos(s25p1-s25p2)+ np.cos(s25p1-s15p1)+ np.cos(s25p2-s15p2)+ np.cos(s25p3-s15p3)+ np.cos(s25p1-s35p1)+ np.cos(s25p2-s35p2)+ np.cos(s25p3-s35p3)+ np.cos(s25p1-s24p1)+ np.cos(s25p2-s24p2)+ np.cos(s25p3-s24p3)+ np.cos(s25p1-s21p1)+ np.cos(s25p2-s21p2)+ np.cos(s25p3-s21p3)
    
        H252 =- np.cos(s25p3e2-s25p1e2)- np.cos(s25p2e2-s25p3e2)- np.cos(s25p1e2-s25p2e2)+ np.cos(s25p1e2-s15p1e2)+ np.cos(s25p2e2-s15p2e2)+ np.cos(s25p3e2-s15p3e2)+ np.cos(s25p1e2-s35p1e2)+ np.cos(s25p2e2-s35p2e2)+ np.cos(s25p3e2-s35p3e2)+ np.cos(s25p1e2-s24p1e2)+ np.cos(s25p2e2-s24p2e2)+ np.cos(s25p3e2-s24p3e2)+ np.cos(s25p1e2-s21p1e2)+ np.cos(s25p2e2-s21p2e2)+ np.cos(s25p3e2-s21p3e2)
    
        r25 = prob(H252)/prob(H25)
        x25 = np.random.choice([random.uniform(0, 1)])
        if r25>=x25:
            s25p1n = s25p1e2
            s25p2n = s25p2e2
            s25p3n = s25p3e2
            
            s25p1 = s25p1e2
            s25p2 = s25p2e2
            s25p3 = s25p3e2

        else:
            s25p1n = s25p1
            s25p2n = s25p2
            s25p3n = s25p3
        if s25p1n>=s25p2n>=s25p3n:
            s25= -1
        if s25p2n>=s25p1n>=s25p3n:    
            s25=1
        if s25p3n>=s25p2n>=s25p1n:   
            s25=1
        if s25p3n>=s25p1n>=s25p2n:    
            s25= -1     
        if s25p1n>=s25p3n>=s25p2n:
            s25=1    
        if s25p2n>=s25p3n>=s25p1n:    
            s25= -1   
        s25p1e2 = s25p1
        s25p2e2 = s25p2
        s25p3e2 = s25p3

        s31p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s31p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s31p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 

    #site31    
        H31 =- np.cos(s31p3-s31p1)- np.cos(s31p2-s31p3)- np.cos(s31p1-s31p2)+ np.cos(s31p1-s21p1)+ np.cos(s31p2-s21p2)+ np.cos(s31p3-s21p3)+ np.cos(s31p1-s41p1)+ np.cos(s31p2-s41p2)+ np.cos(s31p3-s41p3)+ np.cos(s31p1-s32p1)+ np.cos(s31p2-s32p2)+ np.cos(s31p3-s32p3)+ np.cos(s31p1-s35p1)+ np.cos(s31p2-s35p2)+ np.cos(s31p3-s35p3)
    
        H312 =- np.cos(s31p3e2-s31p1e2)- np.cos(s31p2e2-s31p3e2)- np.cos(s31p1e2-s31p2e2)+ np.cos(s31p1e2-s21p1e2)+ np.cos(s31p2e2-s21p2e2)+ np.cos(s31p3e2-s21p3e2)+ np.cos(s31p1e2-s41p1e2)+ np.cos(s31p2e2-s41p2e2)+ np.cos(s31p3e2-s41p3e2)+ np.cos(s31p1e2-s32p1e2)+ np.cos(s31p2e2-s32p2e2)+ np.cos(s31p3e2-s32p3e2)+ np.cos(s31p1e2-s35p1e2)+ np.cos(s31p2e2-s35p2e2)+ np.cos(s31p3e2-s35p3e2)
    
        r31 = prob(H312)/prob(H31)
        x31 = np.random.choice([random.uniform(0, 1)])
        if r31>=x31:
            s31p1n = s31p1e2
            s31p2n = s31p2e2
            s31p3n = s31p3e2

            s31p1 = s31p1e2
            s31p2 = s31p2e2
            s31p3 = s31p3e2
        else:
            s31p1n = s31p1
            s31p2n = s31p2
            s31p3n = s31p3
        if s31p1n>=s31p2n>=s31p3n:
            s31= -1
        if s31p2n>=s31p1n>=s31p3n:    
            s31=1
        if s31p3n>=s31p2n>=s31p1n:   
            s31=1
        if s31p3n>=s31p1n>=s31p2n:    
            s31= -1     
        if s31p1n>=s31p3n>=s31p2n:
            s31=1    
        if s31p2n>=s31p3n>=s31p1n:    
            s31= -1 
        s31p1e2 = s31p1
        s31p2e2 = s31p2
        s31p3e2 = s31p3
        
        s32p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s32p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s32p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
        
    #site32    
        H32 =- np.cos(s32p3-s32p1)- np.cos(s32p2-s32p3)- np.cos(s32p1-s32p2)+ np.cos(s32p1-s22p1)+ np.cos(s32p2-s22p2)+ np.cos(s32p3-s22p3)+ np.cos(s32p1-s42p1)+ np.cos(s32p2-s42p2)+ np.cos(s32p3-s42p3)+ np.cos(s32p1-s33p1)+ np.cos(s32p2-s33p2)+ np.cos(s32p3-s33p3)+ np.cos(s32p1-s31p1)+ np.cos(s32p2-s31p2)+ np.cos(s32p3-s31p3)
    
        H322 =- np.cos(s32p3e2-s32p1e2)- np.cos(s32p2e2-s32p3e2)- np.cos(s32p1e2-s32p2e2)+ np.cos(s32p1e2-s22p1e2)+ np.cos(s32p2e2-s22p2e2)+ np.cos(s32p3e2-s22p3e2)+ np.cos(s32p1e2-s42p1e2)+ np.cos(s32p2e2-s42p2e2)+ np.cos(s32p3e2-s42p3e2)+ np.cos(s32p1e2-s33p1e2)+ np.cos(s32p2e2-s33p2e2)+ np.cos(s32p3e2-s33p3e2)+ np.cos(s32p1e2-s31p1e2)+ np.cos(s32p2e2-s31p2e2)+ np.cos(s32p3e2-s31p3e2)
    
        r32 = prob(H322)/prob(H32)
        x32 = np.random.choice([random.uniform(0, 1)])
        if r32>=x32:
            s32p1n = s32p1e2
            s32p2n = s32p2e2
            s32p3n = s32p3e2

            s32p1 = s32p1e2
            s32p2 = s32p2e2
            s32p3 = s32p3e2
        else:
            s32p1n = s32p1
            s32p2n = s32p2
            s32p3n = s32p3
        if s32p1n>=s32p2n>=s32p3n:
            s32= -1
        if s32p2n>=s32p1n>=s32p3n:    
            s32=1
        if s32p3n>=s32p2n>=s32p1n:   
            s32=1
        if s32p3n>=s32p1n>=s32p2n:    
            s32= -1     
        if s32p1n>=s32p3n>=s32p2n:
            s32=1    
        if s32p2n>=s32p3n>=s32p1n:    
            s32= -1               
        s32p1e2 = s32p1
        s32p2e2 = s32p2
        s32p3e2 = s32p3        
        
        s33p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s33p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s33p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
    #site33    
        H33 =- np.cos(s33p3-s33p1)- np.cos(s33p2-s33p3)- np.cos(s33p1-s33p2)+ np.cos(s33p1-s23p1)+ np.cos(s33p2-s23p2)+ np.cos(s33p3-s23p3)+ np.cos(s33p1-s43p1)+ np.cos(s33p2-s43p2)+ np.cos(s33p3-s43p3)+ np.cos(s33p1-s34p1)+ np.cos(s33p2-s34p2)+ np.cos(s33p3-s34p3)+ np.cos(s33p1-s32p1)+ np.cos(s33p2-s32p2)+ np.cos(s33p3-s32p3)
    
        H332 =- np.cos(s33p3e2-s33p1e2)- np.cos(s33p2e2-s33p3e2)- np.cos(s33p1e2-s33p2e2)+ np.cos(s33p1e2-s23p1e2)+ np.cos(s33p2e2-s23p2e2)+ np.cos(s33p3e2-s23p3e2)+ np.cos(s33p1e2-s43p1e2)+ np.cos(s33p2e2-s43p2e2)+ np.cos(s33p3e2-s43p3e2)+ np.cos(s33p1e2-s34p1e2)+ np.cos(s33p2e2-s34p2e2)+ np.cos(s33p3e2-s34p3e2)+ np.cos(s33p1e2-s32p1e2)+ np.cos(s33p2e2-s32p2e2)+ np.cos(s33p3e2-s32p3e2)
    
        r33 = prob(H332)/prob(H33)
        x33 = np.random.choice([random.uniform(0, 1)])
        if r33>=x33:
            s33p1n = s33p1e2
            s33p2n = s33p2e2
            s33p3n = s33p3e2
            
            s33p1 = s33p1e2
            s33p2 = s33p2e2
            s33p3 = s33p3e2
            
        else:
            s33p1n = s33p1
            s33p2n = s33p2
            s33p3n = s33p3
        if s33p1n>=s33p2n>=s33p3n:
            s33= -1
        if s33p2n>=s33p1n>=s33p3n:    
            s33=1
        if s33p3n>=s33p2n>=s33p1n:   
            s33=1
        if s33p3n>=s33p1n>=s33p2n:    
            s33= -1     
        if s33p1n>=s33p3n>=s33p2n:
            s33=1    
        if s33p2n>=s33p3n>=s33p1n:    
            s33= -1       
        s33p1e2 = s33p1
        s33p2e2 = s33p2
        s33p3e2 = s33p3

        s34p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s34p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s34p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
    #site34    
        H34 =- np.cos(s34p3-s34p1)- np.cos(s34p2-s34p3)- np.cos(s34p1-s34p2)+ np.cos(s34p1-s24p1)+ np.cos(s34p2-s24p2)+ np.cos(s34p3-s24p3)+ np.cos(s34p1-s44p1)+ np.cos(s34p2-s44p2)+ np.cos(s34p3-s44p3)+ np.cos(s34p1-s35p1)+ np.cos(s34p2-s35p2)+ np.cos(s34p3-s35p3)+ np.cos(s34p1-s33p1)+ np.cos(s34p2-s33p2)+ np.cos(s34p3-s33p3)
    
        H342 =- np.cos(s34p3e2-s34p1e2)- np.cos(s34p2e2-s34p3e2)- np.cos(s34p1e2-s34p2e2)+ np.cos(s34p1e2-s24p1e2)+ np.cos(s34p2e2-s24p2e2)+ np.cos(s34p3e2-s24p3e2)+ np.cos(s34p1e2-s44p1e2)+ np.cos(s34p2e2-s44p2e2)+ np.cos(s34p3e2-s44p3e2)+ np.cos(s34p1e2-s35p1e2)+ np.cos(s34p2e2-s35p2e2)+ np.cos(s34p3e2-s35p3e2)+ np.cos(s34p1e2-s33p1e2)+ np.cos(s34p2e2-s33p2e2)+ np.cos(s34p3e2-s33p3e2)
    
        r34 = prob(H342)/prob(H34)
        x34 = np.random.choice([random.uniform(0, 1)])
        if r34>=x34:
            s34p1n = s34p1e2
            s34p2n = s34p2e2
            s34p3n = s34p3e2
            
            s34p1 = s34p1e2
            s34p2 = s34p2e2
            s34p3 = s34p3e2

        else:
            s34p1n = s34p1
            s34p2n = s34p2
            s34p3n = s34p3
        if s34p1n>=s34p2n>=s34p3n:
            s34= -1
        if s34p2n>=s34p1n>=s34p3n:    
            s34=1
        if s34p3n>=s34p2n>=s34p1n:   
            s34=1
        if s34p3n>=s34p1n>=s34p2n:    
            s34= -1     
        if s34p1n>=s34p3n>=s34p2n:
            s34=1    
        if s34p2n>=s34p3n>=s34p1n:    
            s34= -1          
        s34p1e2 = s34p1
        s34p2e2 = s34p2
        s34p3e2 = s34p3

        s35p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s35p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s35p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
    #site35    
        H35 =- np.cos(s35p3-s35p1)- np.cos(s35p2-s35p3)- np.cos(s35p1-s35p2)+ np.cos(s35p1-s25p1)+ np.cos(s35p2-s25p2)+ np.cos(s35p3-s25p3)+ np.cos(s35p1-s45p1)+ np.cos(s35p2-s45p2)+ np.cos(s35p3-s45p3)+ np.cos(s35p1-s34p1)+ np.cos(s35p2-s34p2)+ np.cos(s35p3-s34p3)+ np.cos(s35p1-s31p1)+ np.cos(s35p2-s31p2)+ np.cos(s35p3-s31p3)
    
        H352 =- np.cos(s35p3e2-s35p1e2)- np.cos(s35p2e2-s35p3e2)- np.cos(s35p1e2-s35p2e2)+ np.cos(s35p1e2-s25p1e2)+ np.cos(s35p2e2-s25p2e2)+ np.cos(s35p3e2-s25p3e2)+ np.cos(s35p1e2-s45p1e2)+ np.cos(s35p2e2-s45p2e2)+ np.cos(s35p3e2-s45p3e2)+ np.cos(s35p1e2-s34p1e2)+ np.cos(s35p2e2-s34p2e2)+ np.cos(s35p3e2-s34p3e2)+ np.cos(s35p1e2-s31p1e2)+ np.cos(s35p2e2-s31p2e2)+ np.cos(s35p3e2-s31p3e2)
    
        r35 = prob(H352)/prob(H35)
        x35 = np.random.choice([random.uniform(0, 1)])
        if r35>=x35:
            s35p1n = s35p1e2
            s35p2n = s35p2e2
            s35p3n = s35p3e2
            
            s35p1 = s35p1e2
            s35p2 = s35p2e2
            s35p3 = s35p3e2

        else:
            s35p1n = s35p1
            s35p2n = s35p2
            s35p3n = s35p3
        if s35p1n>=s35p2n>=s35p3n:
            s35= -1
        if s35p2n>=s35p1n>=s35p3n:    
            s35=1
        if s35p3n>=s35p2n>=s35p1n:   
            s35=1
        if s35p3n>=s35p1n>=s35p2n:    
            s35= -1     
        if s35p1n>=s35p3n>=s35p2n:
            s35=1    
        if s35p2n>=s35p3n>=s35p1n:    
            s35= -1       
        s35p1e2 = s35p1
        s35p2e2 = s35p2
        s35p3e2 = s35p3

        s41p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s41p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s41p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site41    
        H41 =- np.cos(s41p3-s41p1)- np.cos(s41p2-s41p3)- np.cos(s41p1-s41p2)+ np.cos(s41p1-s31p1)+ np.cos(s41p2-s31p2)+ np.cos(s41p3-s31p3)+ np.cos(s41p1-s1p1)+ np.cos(s41p2-s1p2)+ np.cos(s41p3-s1p3)+ np.cos(s41p1-s42p1)+ np.cos(s41p2-s42p2)+ np.cos(s41p3-s42p3)+ np.cos(s41p1-s45p1)+ np.cos(s41p2-s45p2)+ np.cos(s41p3-s45p3)
    
        H412 =- np.cos(s41p3e2-s41p1e2)- np.cos(s41p2e2-s41p3e2)- np.cos(s41p1e2-s41p2e2)+ np.cos(s41p1e2-s31p1e2)+ np.cos(s41p2e2-s31p2e2)+ np.cos(s41p3e2-s31p3e2)+ np.cos(s41p1e2-s1p1e2)+ np.cos(s41p2e2-s1p2e2)+ np.cos(s41p3e2-s1p3e2)+ np.cos(s41p1e2-s42p1e2)+ np.cos(s41p2e2-s42p2e2)+ np.cos(s41p3e2-s42p3e2)+ np.cos(s41p1e2-s45p1e2)+ np.cos(s41p2e2-s45p2e2)+ np.cos(s41p3e2-s45p3e2)
    
        r41 = prob(H412)/prob(H41)
        x41 = np.random.choice([random.uniform(0, 1)])
        if r41>=x41:
            s41p1n = s41p1e2
            s41p2n = s41p2e2
            s41p3n = s41p3e2
            
            s41p1 = s41p1e2
            s41p2 = s41p2e2
            s41p3 = s41p3e2

        else:
            s41p1n = s41p1
            s41p2n = s41p2
            s41p3n = s41p3
        if s41p1n>=s41p2n>=s41p3n:
            s41= -1
        if s41p2n>=s41p1n>=s41p3n:    
            s41=1
        if s41p3n>=s41p2n>=s41p1n:   
            s41=1
        if s41p3n>=s41p1n>=s41p2n:    
            s41= -1     
        if s41p1n>=s41p3n>=s41p2n:
            s41=1    
        if s41p2n>=s41p3n>=s41p1n:    
            s41= -1     
        s41p1e2 = s41p1
        s41p2e2 = s41p2
        s41p3e2 = s42p3

        s42p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s42p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s42p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site42    
        H42 =- np.cos(s42p3-s42p1)- np.cos(s42p2-s42p3)- np.cos(s42p1-s42p2)+ np.cos(s42p1-s32p1)+ np.cos(s42p2-s32p2)+ np.cos(s42p3-s32p3)+ np.cos(s42p1-s2p1)+ np.cos(s42p2-s2p2)+ np.cos(s42p3-s2p3)+ np.cos(s42p1-s43p1)+ np.cos(s42p2-s43p2)+ np.cos(s42p3-s43p3)+ np.cos(s42p1-s41p1)+ np.cos(s42p2-s41p2)+ np.cos(s42p3-s41p3)
    
        H422 =- np.cos(s42p3e2-s42p1e2)- np.cos(s42p2e2-s42p3e2)- np.cos(s42p1e2-s42p2e2)+ np.cos(s42p1e2-s32p1e2)+ np.cos(s42p2e2-s32p2e2)+ np.cos(s42p3e2-s32p3e2)+ np.cos(s42p1e2-s2p1e2)+ np.cos(s42p2e2-s2p2e2)+ np.cos(s42p3e2-s2p3e2)+ np.cos(s42p1e2-s43p1e2)+ np.cos(s42p2e2-s43p2e2)+ np.cos(s42p3e2-s43p3e2)+ np.cos(s42p1e2-s41p1e2)+ np.cos(s42p2e2-s41p2e2)+ np.cos(s42p3e2-s41p3e2)
    
        r42 = prob(H422)/prob(H42)
        x42 = np.random.choice([random.uniform(0, 1)])
        if r42>=x42:
            s42p1n = s42p1e2
            s42p2n = s42p2e2
            s42p3n = s42p3e2
            
            s42p1 = s42p1e2
            s42p2 = s42p2e2
            s42p3 = s42p3e2

        else:
            s42p1n = s42p1
            s42p2n = s42p2
            s42p3n = s42p3
        if s42p1n>=s42p2n>=s42p3n:
            s42= -1
        if s42p2n>=s42p1n>=s42p3n:    
            s42=1
        if s42p3n>=s42p2n>=s42p1n:   
            s42=1
        if s42p3n>=s42p1n>=s42p2n:    
            s42= -1     
        if s42p1n>=s42p3n>=s42p2n:
            s42=1    
        if s42p2n>=s42p3n>=s42p1n:    
            s42= -1        
        s42p1e2 = s42p1
        s42p2e2 = s42p2
        s42p3e2 = s42p3

        s43p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s43p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s43p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site43    
        H43 =- np.cos(s43p3-s43p1)- np.cos(s43p2-s43p3)- np.cos(s43p1-s43p2)+ np.cos(s43p1-s33p1)+ np.cos(s43p2-s33p2)+ np.cos(s43p3-s33p3)+ np.cos(s43p1-s3p1)+ np.cos(s43p2-s3p2)+ np.cos(s43p3-s3p3)+ np.cos(s43p1-s44p1)+ np.cos(s43p2-s44p2)+ np.cos(s43p3-s44p3)+ np.cos(s43p1-s42p1)+ np.cos(s43p2-s42p2)+ np.cos(s43p3-s42p3)
    
        H432 =- np.cos(s43p3e2-s43p1e2)- np.cos(s43p2e2-s43p3e2)- np.cos(s43p1e2-s43p2e2)+ np.cos(s43p1e2-s33p1e2)+ np.cos(s43p2e2-s33p2e2)+ np.cos(s43p3e2-s33p3e2)+ np.cos(s43p1e2-s3p1e2)+ np.cos(s43p2e2-s3p2e2)+ np.cos(s43p3e2-s3p3e2)+ np.cos(s43p1e2-s44p1e2)+ np.cos(s43p2e2-s44p2e2)+ np.cos(s43p3e2-s44p3e2)+ np.cos(s43p1e2-s42p1e2)+ np.cos(s43p2e2-s42p2e2)+ np.cos(s43p3e2-s42p3e2)
    
        r43 = prob(H432)/prob(H43)
        x43 = np.random.choice([random.uniform(0, 1)])
        if r43>=x43:
            s43p1n = s43p1e2
            s43p2n = s43p2e2
            s43p3n = s43p3e2
            
            s43p1 = s43p1e2
            s43p2 = s43p2e2
            s43p3 = s43p3e2

        else:
            s43p1n = s43p1
            s43p2n = s43p2
            s43p3n = s43p3
        if s43p1n>=s43p2n>=s43p3n:
            s43= -1
        if s43p2n>=s43p1n>=s43p3n:    
            s43=1
        if s43p3n>=s43p2n>=s43p1n:   
            s43=1
        if s43p3n>=s43p1n>=s43p2n:    
            s43= -1     
        if s43p1n>=s43p3n>=s43p2n:
            s43=1    
        if s43p2n>=s43p3n>=s43p1n:    
            s43= -1    
        s43p1e2 = s43p1
        s43p2e2 = s43p2
        s43p3e2 = s43p3

        s44p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s44p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s44p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    #site44    
        H44 =- np.cos(s44p3-s44p1)- np.cos(s44p2-s44p3)- np.cos(s44p1-s44p2)+ np.cos(s44p1-s34p1)+ np.cos(s44p2-s34p2)+ np.cos(s44p3-s34p3)+ np.cos(s44p1-s4p1)+ np.cos(s44p2-s4p2)+ np.cos(s44p3-s4p3)+ np.cos(s44p1-s45p1)+ np.cos(s44p2-s45p2)+ np.cos(s44p3-s45p3)+ np.cos(s44p1-s43p1)+ np.cos(s44p2-s43p2)+ np.cos(s44p3-s43p3)
    
        H442 =- np.cos(s44p3e2-s44p1e2)- np.cos(s44p2e2-s44p3e2)- np.cos(s44p1e2-s44p2e2)+ np.cos(s44p1e2-s34p1e2)+ np.cos(s44p2e2-s34p2e2)+ np.cos(s44p3e2-s34p3e2)+ np.cos(s44p1e2-s4p1e2)+ np.cos(s44p2e2-s4p2e2)+ np.cos(s44p3e2-s4p3e2)+ np.cos(s44p1e2-s45p1e2)+ np.cos(s44p2e2-s45p2e2)+ np.cos(s44p3e2-s45p3e2)+ np.cos(s44p1e2-s43p1e2)+ np.cos(s44p2e2-s43p2e2)+ np.cos(s44p3e2-s43p3e2)
    
        r44 = prob(H442)/prob(H44)
        x44 = np.random.choice([random.uniform(0, 1)])
        if r44>=x44:
            s44p1n = s44p1e2
            s44p2n = s44p2e2
            s44p3n = s44p3e2
            
            s44p1 = s44p1e2
            s44p2 = s44p2e2
            s44p3 = s44p3e2
 
        else:
            s44p1n = s44p1
            s44p2n = s44p2
            s44p3n = s44p3
        if s44p1n>=s44p2n>=s44p3n:
            s44= -1
        if s44p2n>=s44p1n>=s44p3n:    
            s44=1
        if s44p3n>=s44p2n>=s44p1n:   
            s44=1
        if s44p3n>=s44p1n>=s44p2n:    
            s44= -1     
        if s44p1n>=s44p3n>=s44p2n:
            s44=1    
        if s44p2n>=s44p3n>=s44p1n:    
            s44= -1            
        s44p1e2 = s44p1
        s44p2e2 = s44p2
        s44p3e2 = s44p3
        
        s45p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s45p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
        s45p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])        
    #site45    
        H45 =- np.cos(s45p3-s45p1)- np.cos(s45p2-s45p3)- np.cos(s45p1-s45p2)+ np.cos(s45p1-s35p1)+ np.cos(s45p2-s35p2)+ np.cos(s45p3-s35p3)+ np.cos(s45p1-s5p1)+ np.cos(s45p2-s5p2)+ np.cos(s45p3-s5p3)+ np.cos(s45p1-s44p1)+ np.cos(s45p2-s44p2)+ np.cos(s45p3-s44p3)+ np.cos(s45p1-s41p1)+ np.cos(s45p2-s41p2)+ np.cos(s45p3-s41p3)
    
        H452 =- np.cos(s45p3e2-s45p1e2)- np.cos(s45p2e2-s45p3e2)- np.cos(s45p1e2-s45p2e2)+ np.cos(s45p1e2-s35p1e2)+ np.cos(s45p2e2-s35p2e2)+ np.cos(s45p3e2-s35p3e2)+ np.cos(s45p1e2-s5p1e2)+ np.cos(s45p2e2-s5p2e2)+ np.cos(s45p3e2-s5p3e2)+ np.cos(s45p1e2-s44p1e2)+ np.cos(s45p2e2-s44p2e2)+ np.cos(s45p3e2-s44p3e2)+ np.cos(s45p1e2-s41p1e2)+ np.cos(s45p2e2-s41p2e2)+ np.cos(s45p3e2-s41p3e2)
    
        r45 = prob(H452)/prob(H45)
        x45 = np.random.choice([random.uniform(0, 1)])
        if r45>=x45:
            s45p1n = s45p1e2
            s45p2n = s45p2e2
            s45p3n = s45p3e2
            
            s45p1 = s45p1e2
            s45p2 = s45p2e2
            s45p3 = s45p3e2

        else:
            s45p1n = s45p1
            s45p2n = s45p2
            s45p3n = s45p3
        if s45p1n>=s45p2n>=s45p3n:
            s45= -1
        if s45p2n>=s45p1n>=s45p3n:    
            s45=1
        if s45p3n>=s45p2n>=s45p1n:   
            s45=1
        if s45p3n>=s45p1n>=s45p2n:    
            s45= -1     
        if s45p1n>=s45p3n>=s45p2n:
            s45=1    
        if s45p2n>=s45p3n>=s45p1n:    
            s45= -1 
        if J<500:
            J=J+1
        else:
            s.append(s1)
            s.append(s2)
            s.append(s3)
            s.append(s4)
            s.append(s5)
            s.append(s11)
            s.append(s12)
            s.append(s13)
            s.append(s14)
            s.append(s15)
            s.append(s21)
            s.append(s22)
            s.append(s23)
            s.append(s24)
            s.append(s25)
            s.append(s31)
            s.append(s32)
            s.append(s33)
            s.append(s34)
            s.append(s35)
            s.append(s41)
            s.append(s42)
            s.append(s43)
            s.append(s44)
            s.append(s45)
            S.append(abs(mean(s)))
    T1.append(T)
    print(T)
    T=T+0.1                                                                
    S1.append(abs(mean(S)))
    print(abs(mean(S)))
    J=0
    S=[]
    s1p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s1p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s1p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s2p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s11p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s31p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s41p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s32p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s42p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s43p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s44p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s33p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s34p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s35p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s45p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s12p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s3p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s13p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s14p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s15p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s21p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s22p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s23p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s24p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s25p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s4p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p3 = np.random.choice([random.uniform(0, 2*np.pi)])

    s5p1 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p3 = np.random.choice([random.uniform(0, 2*np.pi)])
plt.plot(T1,S1)
# Out:
# 0.1
# 0.9989103310991294
# 0.2
# 0.4036103129281187
# 0.30000000000000004
# 0.09371199334329536
# 0.4
# 0.08377371442915817
# 0.5
# 0.059902332566207264
# 0.6
# 0.20962212547765183
# 0.7
# 0.1815193345427467
# 0.7999999999999999
# 0.15406923887399615
# 0.8999999999999999
# 0.24778034407978794
# 0.9999999999999999
# 0.22313977572205101

# %% [markdown]
# <h1 style="font-size:100px; text-align:center;">XY MODEL</h1>

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import random
from statistics import mean 

k=1

S1=[]

s1l=[]
s2l=[]
s3l=[]
s4l=[]
s5l=[]
s11l=[]
s12l=[]
s13l=[]
s14l=[]
s15l=[]
s21l=[]
s22l=[]
s23l=[]
s24l=[]
s25l=[]
s31l=[]
s32l=[]
s33l=[]
s34l=[]
s35l=[]
s41l=[]
s42l=[]
s43l=[]
s44l=[]
s45l=[]


s1p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s2p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s11p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s31p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s41p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s32p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s42p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s43p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s44p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s33p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s34p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s35p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s45p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s12p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s3p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s13p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s14p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s15p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s21p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s22p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s23p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s24p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s25p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s4p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s5p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p3 = np.random.choice([random.uniform(0, 2*np.pi)])
T=0.5
b= k/T
s = []
def prob(H):
    return np.exp(H*b) 

S = []
T1=[]

for i in range(1000):
    s1p1e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    s1p2e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    s1p3e2 =np.random.choice([random.uniform(0, 2*np.pi)])

    s2p1e2 =s2p1
    s2p2e2 =s2p2
    s2p3e2 =s2p3
    
    s11p1e2 = s11p1
    s11p2e2 = s11p2
    s11p3e2 = s11p3
    
    s31p1e2 = s31p1
    s31p2e2 = s31p2
    s31p3e2 = s31p3
    
    s41p1e2 = s41p1
    s41p2e2 = s41p2
    s41p3e2 = s41p3
    
    s42p1e2 = s42p1
    s42p2e2 = s42p2
    s42p3e2 = s42p3
    
    s43p1e2 = s43p1
    s43p2e2 = s43p2
    s43p3e2 = s43p3
    
    s44p1e2 = s44p1
    s44p2e2 = s44p2
    s44p3e2 = s44p3
    
    s32p1e2 = s32p1
    s32p2e2 = s32p2
    s32p3e2 = s32p3
    
    s33p1e2 = s33p1
    s33p2e2 = s33p2
    s33p3e2 = s33p3
    
    s34p1e2 = s34p1
    s34p2e2 = s34p2
    s34p3e2 = s34p3
    
    s35p1e2 = s35p1
    s35p2e2 = s35p2
    s35p3e2 = s35p3
    
    s45p1e2 = s45p1
    s45p2e2 = s45p2
    s45p3e2 = s45p3
    
    s12p1e2 = s12p1
    s12p2e2 = s12p2
    s12p3e2 = s12p3
    
    s13p1e2 = s13p1
    s13p2e2 = s13p2
    s13p3e2 = s13p3
    
    s3p1e2 = s3p1
    s3p2e2 = s3p2
    s3p3e2 = s3p3
    
    s4p1e2 = s4p1
    s4p2e2 = s4p2
    s4p3e2 = s4p3
    
    s14p1e2 = s14p1
    s14p2e2 = s14p2
    s14p3e2 = s14p3
    
    s15p1e2 = s15p1
    s15p2e2 = s15p2
    s15p3e2 = s15p3
    
    s21p1e2 = s21p1
    s21p2e2 = s21p2
    s21p3e2 = s21p3
    
    s5p1e2 = s5p1
    s5p2e2 = s5p2
    s5p3e2 = s5p3
    
    s22p1e2 = s22p1
    s22p2e2 = s22p2
    s22p3e2 = s22p3
    
    s23p1e2 = s23p1
    s23p2e2 = s23p2
    s23p3e2 = s23p3
    
    s24p1e2 = s24p1
    s24p2e2 = s24p2
    s24p3e2 = s24p3
    
    s25p1e2 = s25p1
    s25p2e2 = s25p2
    s25p3e2 = s25p3
#site1        
    H1 = - np.cos(s1p1-s1p2) - np.cos(s1p2-s1p3)- np.cos(s1p3-s1p1)+ np.cos(s1p1-s2p1)+ np.cos(s1p2-s2p2)+ np.cos(s1p3-s2p3)+ np.cos(s1p1-s11p1)+ np.cos(s1p2-s11p2)+ np.cos(s1p3-s11p3)+ np.cos(s1p1-s41p1)+ np.cos(s1p2-s41p2)+ np.cos(s1p3-s41p3)+ np.cos(s1p1-s5p1)+ np.cos(s1p2-s5p2)+ np.cos(s1p3-s5p3)
    
    H12 = - np.cos(s1p1e2-s1p2e2)- np.cos(s1p3e2-s1p1e2)- np.cos(s1p2e2-s1p3e2)+ np.cos(s1p1e2-s2p1e2)+ np.cos(s1p2e2-s2p2e2)+ np.cos(s1p3e2-s2p3e2)+ np.cos(s1p1e2-s11p1e2)+ np.cos(s1p2e2-s11p2e2)+ np.cos(s1p3e2-s11p3e2)+ np.cos(s1p1e2-s41p1e2)+ np.cos(s1p2e2-s41p2e2)+ np.cos(s1p3e2-s41p3e2)+ np.cos(s1p1e2-s5p1e2)+ np.cos(s1p2e2-s5p2e2)+ np.cos(s1p3e2-s5p3e2)

    r= prob(H12)/prob(H1)
    x= np.random.choice([random.uniform(0, 1)])
    if r >= x:
        s1p1n = s1p1e2
        s1p2n = s1p2e2
        s1p3n = s1p3e2
        
        s1p1 = s1p1e2
        s1p2 = s1p2e2
        s1p3 = s1p3e2
        
    else:
        s1p1n = s1p1
        s1p2n = s1p2
        s1p3n = s1p3
    if s1p1n>=s1p2n>=s1p3n:
        s1= -1
    if s1p2n>=s1p1n>=s1p3n:    
        s1=1
    if s1p3n>=s1p2n>=s1p1n:   
        s1=1
    if s1p3n>=s1p1n>=s1p2n:    
        s1= -1     
    if s1p1n>=s1p3n>=s1p2n:
        s1=1    
    if s1p2n>=s1p3n>=s1p1n:    
        s1= -1    
    s.append(s1)
    s1l.append(s1)    
    s1p1e2 =s1p1
    s1p2e2 =s1p2
    s1p3e2 =s1p3
    
    s2p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site2    
    H2 = - np.cos(s2p2-s2p3)- np.cos(s2p3-s2p1)- np.cos(s2p1-s2p2)+ np.cos(s2p1-s12p1)+ np.cos(s2p2-s12p2)+ np.cos(s2p3-s12p3)+ np.cos(s2p1-s1p1)+ np.cos(s2p2-s1p2)+ np.cos(s2p3-s1p2)+ np.cos(s2p1-s3p1)+ np.cos(s2p2-s3p2)+ np.cos(s2p3-s3p3)+ np.cos(s2p1-s42p1)+ np.cos(s2p2-s42p2)+ np.cos(s2p3-s42p3)

    H22 =- np.cos(s2p3e2-s2p1e2)- np.cos(s2p2e2-s2p3e2)- np.cos(s2p1e2-s2p2e2)+ np.cos(s2p1e2-s1p1e2)+ np.cos(s2p2e2-s1p2e2)+ np.cos(s2p3e2-s1p3e2)+ np.cos(s2p1e2-s12p1e2)+ np.cos(s2p2e2-s12p2e2)+ np.cos(s2p3e2-s12p3e2)+ np.cos(s2p1e2-s3p1e2)+ np.cos(s2p2e2-s3p2e2)+ np.cos(s2p3e2-s3p3e2)+ np.cos(s2p1e2-s42p1e2)+ np.cos(s2p2e2-s42p2e2)+ np.cos(s2p3e2-s42p3e2)

    r1 = prob(H22)/prob(H2)
    x1 = np.random.choice([random.uniform(0, 1)])
    if r1 >= x1:
        s2p1n = s2p1e2
        s2p2n = s2p2e2
        s2p3n = s2p3e2
        
        s2p1 = s2p1e2
        s2p2 = s2p2e2
        s2p3 = s2p3e2
        
    else:
        s2p1n = s2p1
        s2p2n = s2p2
        s2p3n = s2p3
        
    if s2p1n>=s2p2n>=s2p3n:
        s2= -1
    if s2p2n>=s2p1n>=s2p3n:    
        s2=1
    if s2p3n>=s2p2n>=s2p1n:   
        s2=1
    if s2p3n>=s2p1n>=s2p2n:    
        s2= -1     
    if s2p1n>=s2p3n>=s2p2n:
        s2=1    
    if s2p2n>=s2p3n>=s2p1n:    
        s2= -1    
    s.append(s2)
    s2l.append(s2)
    s2p1e2 = s2p1
    s2p2e2 = s2p2
    s2p3e2 = s2p3
    
    s3p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site3    
    H3 = -np.cos(s3p2-s3p3)- np.cos(s3p3-s3p1)- np.cos(s3p1-s3p2)+ np.cos(s3p1-s2p1)+ np.cos(s3p2-s2p2)+ np.cos(s3p3-s2p3)+ np.cos(s3p1-s13p1)+ np.cos(s3p2-s13p2)+ np.cos(s3p3-s13p3)+ np.cos(s3p1-s4p1)+ np.cos(s3p2-s4p2)+ np.cos(s3p3-s4p3)+ np.cos(s3p1-s43p1)+ np.cos(s3p2-s43p2)+ np.cos(s3p3-s43p3)

    H32 = - np.cos(s3p2e2-s3p3e2)- np.cos(s3p3e2-s3p1e2)- np.cos(s3p1e2-s3p2e2)+ np.cos(s3p1e2-s2p1e2)+ np.cos(s3p2e2-s2p2e2)+ np.cos(s3p3e2-s2p3e2)+ np.cos(s3p1e2-s13p1e2)+ np.cos(s3p2e2-s13p2e2)+ np.cos(s3p3e2-s13p3e2)+ np.cos(s3p1e2-s4p1e2)+ np.cos(s3p2e2-s4p2e2)+ np.cos(s3p3e2-s4p3e2)+ np.cos(s3p1e2-s43p1e2)+ np.cos(s3p2e2-s43p2e2)+ np.cos(s3p3e2-s43p3e2)
  
    r2 = prob(H32)/prob(H3)
    x2 = np.random.choice([random.uniform(0, 1)])
    if r2 >= x2:
        s3p1n = s3p1e2
        s3p2n = s3p2e2
        s3p3n = s3p3e2
        
        s3p1 = s3p1e2
        s3p2 = s3p2e2
        s3p3 = s3p3e2
    else:
        s3p1n = s3p1
        s3p2n = s3p2
        s3p3n = s3p3
    if s3p1n>=s3p2n>=s3p3n:
        s3= -1
    if s3p2n>=s3p1n>=s3p3n:    
        s3=1
    if s3p3n>=s3p2n>=s3p1n:   
        s3=1
    if s3p3n>=s3p1n>=s3p2n:    
        s3= -1     
    if s3p1n>=s3p3n>=s3p2n:
        s3=1    
    if s3p2n>=s3p3n>=s3p1n:    
        s3= -1  
    s.append(s3) 
    s3l.append(s3)
    s3p1e2 = s3p1
    s3p2e2 = s3p2
    s3p3e2 = s3p3
    
    s4p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site4    
    H4 = - np.cos(s4p2-s4p3)- np.cos(s4p3-s4p1)- np.cos(s4p1-s4p2)+ np.cos(s4p1-s3p1)+ np.cos(s4p2-s3p2)+ np.cos(s4p3-s3p3)+ np.cos(s4p1-s14p1)+ np.cos(s4p2-s14p2)+ np.cos(s4p3-s14p3)+ np.cos(s4p1-s5p1)+ np.cos(s4p2-s5p2)+ np.cos(s4p3-s5p3)+ np.cos(s4p1-s44p1)+ np.cos(s4p2-s44p2)+ np.cos(s4p3-s44p3)

    H42 = - np.cos(s4p3e2-s4p1e2)- np.cos(s4p2e2-s3p3e2)- np.cos(s4p1e2-s4p2e2)+ np.cos(s4p1e2-s3p1e2)+ np.cos(s4p2e2-s3p2e2)+ np.cos(s4p3e2-s3p3e2)+ np.cos(s4p1e2-s14p1e2)+ np.cos(s4p2e2-s14p2e2)+ np.cos(s4p3e2-s14p3e2)+ np.cos(s4p1e2-s5p1e2)+ np.cos(s4p2e2-s5p2e2)+ np.cos(s4p3e2-s5p3e2)+ np.cos(s4p1e2-s44p1e2)+ np.cos(s4p2e2-s44p2e2)+ np.cos(s4p3e2-s44p3e2)

    r3 = prob(H42)/prob(H4)
    x3 = np.random.choice([random.uniform(0, 1)])
    if r3 >= x3:
        s4p1n = s4p1e2
        s4p2n = s4p2e2
        s4p3n = s4p3e2
        
        s4p1 = s4p1e2
        s4p2 = s4p2e2
        s4p3 = s4p3e2
    else:
        s4p1n = s4p1
        s4p2n = s4p2
        s4p3n = s4p3
    if s4p1n>=s4p2n>=s4p3n:
        s4= -1
    if s4p2n>=s4p1n>=s4p3n:    
        s4=1
    if s4p3n>=s4p2n>=s4p1n:   
        s4=1
    if s4p3n>=s4p1n>=s4p2n:    
        s4= -1     
    if s4p1n>=s4p3n>=s4p2n:
        s4=1    
    if s4p2n>=s4p3n>=s4p1n:    
        s4= -1    
    s.append(s4)
    s4l.append(s4)
    s4p1e2 = s4p1
    s4p2e2 = s4p2
    s4p3e2 = s4p3
    
    s5p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site5    
    H5 =- np.cos(s5p2-s5p3)- np.cos(s5p3-s5p1)- np.cos(s5p1-s5p2)+ np.cos(s5p1-s4p1)+ np.cos(s5p2-s4p2)+ np.cos(s5p3-s4p3)+ np.cos(s5p1-s15p1)+ np.cos(s5p2-s15p2)+ np.cos(s5p3-s15p3)+ np.cos(s5p1-s45p1)+ np.cos(s5p2-s45p2)+ np.cos(s5p3-s45p3)+ np.cos(s5p1-s1p1)+ np.cos(s5p2-s1p2)+ np.cos(s5p3-s1p3)

    H52 = - np.cos(s5p3e2-s5p1e2)- np.cos(s5p2e2-s5p3e2)- np.cos(s5p1e2-s5p2e2)+ np.cos(s5p1e2-s4p1e2)+ np.cos(s5p2e2-s4p2e2)+ np.cos(s5p3e2-s4p3e2)+ np.cos(s5p1e2-s15p1e2)+ np.cos(s5p2e2-s15p2e2)+ np.cos(s5p3e2-s15p3e2)+ np.cos(s5p1e2-s45p1e2)+ np.cos(s5p2e2-s45p2e2)+ np.cos(s5p3e2-s45p3e2)+ np.cos(s5p1e2-s1p1e2)+ np.cos(s5p2e2-s1p2e2)+ np.cos(s5p3e2-s1p3e2)

    r4 = prob(H52)/prob(H5)
    x4 = np.random.choice([random.uniform(0, 1)])
    if r4 >= x4:
        s5p1n = s5p1e2
        s5p2n = s5p2e2
        s5p3n = s5p3e2
        
        s5p1 = s5p1e2
        s5p2 = s5p2e2
        s5p3 = s5p3e2
    else:
        s5p1n = s5p1
        s5p2n = s5p2
        s5p3n = s5p3
    if s5p1n>=s5p2n>=s5p3n:
        s5= -1
    if s5p2n>=s5p1n>=s5p3n:    
        s5=1
    if s5p3n>=s5p2n>=s5p1n:   
        s5=1
    if s5p3n>=s5p1n>=s5p2n:    
        s5= -1     
    if s5p1n>=s5p3n>=s5p2n:
        s5=1    
    if s5p2n>=s5p3n>=s5p1n:    
        s5= -1   
    s.append(s5)
    s5l.append(s5)            
    s5p1e2 = s5p1
    s5p2e2 = s5p2
    s5p3e2 = s5p3
    
    s11p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site11    
    H11 =- np.cos(s11p3-s11p1)- np.cos(s11p2-s11p3)- np.cos(s11p1-s11p2)+ np.cos(s11p1-s1p1)+ np.cos(s11p2-s1p2)+ np.cos(s11p3-s1p3)+ np.cos(s11p1-s12p1)+ np.cos(s11p2-s12p2)+ np.cos(s11p3-s12p3)+ np.cos(s11p1-s21p1)+ np.cos(s11p2-s21p2)+ np.cos(s11p3-s21p3)+ np.cos(s11p1-s15p1)+ np.cos(s11p2-s15p2)+ np.cos(s11p3-s15p3)

    H112 =- np.cos(s11p3e2-s11p1e2)- np.cos(s11p2e2-s11p3e2)- np.cos(s11p1e2-s11p2e2)+ np.cos(s11p1e2-s1p1e2)+ np.cos(s11p2e2-s1p2e2)+ np.cos(s11p3e2-s1p3e2)+ np.cos(s11p1e2-s12p1e2)+ np.cos(s11p2e2-s12p2e2)+ np.cos(s11p3e2-s12p3e2)+ np.cos(s11p1e2-s21p1e2)+ np.cos(s11p2e2-s21p2e2)+ np.cos(s11p3e2-s21p3e2)+ np.cos(s11p1e2-s15p1e2)+ np.cos(s11p2e2-s15p2e2)+ np.cos(s11p3e2-s15p3e2)

    r11 = prob(H112)/prob(H11)
    x11 = np.random.choice([random.uniform(0, 1)])
    if r11 >= x11:
        s11p1n = s11p1e2
        s11p2n = s11p2e2
        s11p3n = s11p3e2
        
        s11p1 = s11p1e2
        s11p2 = s11p2e2
        s11p3 = s11p3e2
        
    else:
        s11p1n = s11p1
        s11p2n = s11p2
        s11p3n = s11p3
    if s11p1n>=s11p2n>=s11p3n:
        s11= -1
    if s11p2n>=s11p1n>=s11p3n:    
        s11=1
    if s11p3n>=s11p2n>=s11p1n:   
        s11=1
    if s11p3n>=s11p1n>=s11p2n:    
        s11= -1     
    if s11p1n>=s11p3n>=s11p2n:
        s11=1    
    if s11p2n>=s11p3n>=s11p1n:    
        s11= -1   
    s.append(s11)    
    s11l.append(s11)        
    s11p1e2 = s11p1
    s11p2e2 = s11p2
    s11p3e2 = s11p3
    
    s12p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site12    
    H12s =- np.cos(s12p3-s12p1)- np.cos(s12p2-s12p3)- np.cos(s12p1-s12p2)+ np.cos(s12p1-s2p1)+ np.cos(s12p2-s2p2)+ np.cos(s12p3-s2p3)+ np.cos(s12p1-s13p1)+ np.cos(s12p2-s13p2)+ np.cos(s12p3-s13p3)+ np.cos(s12p1-s22p1)+ np.cos(s12p2-s22p2)+ np.cos(s12p3-s22p3)+ np.cos(s12p1-s11p1)+ np.cos(s12p2-s11p2)+ np.cos(s12p3-s11p3)

    H122 =- np.cos(s12p3e2-s12p1e2)- np.cos(s12p2e2-s12p3e2)- np.cos(s12p1e2-s12p2e2)+ np.cos(s12p1e2-s2p1e2)+ np.cos(s12p2e2-s2p2e2)+ np.cos(s12p3e2-s2p3e2)+ np.cos(s12p1e2-s13p1e2)+ np.cos(s12p2e2-s13p2e2)+ np.cos(s12p3e2-s13p3e2)+ np.cos(s12p1e2-s22p1e2)+ np.cos(s12p2e2-s22p2e2)+ np.cos(s12p3e2-s22p3e2)+ np.cos(s12p1e2-s11p1e2)+ np.cos(s12p2e2-s11p2e2)+ np.cos(s12p3e2-s11p3e2)

    r12 = prob(H122)/prob(H12s)
    x12 = np.random.choice([random.uniform(0, 1)])
    if r12 >= x12:
        s12p1n = s12p1e2
        s12p2n = s12p2e2
        s12p3n = s12p3e2
        
        s12p1 = s12p1e2
        s12p2 = s12p2e2
        s12p3 = s12p3e2
        
    else:
        s12p1n = s12p1
        s12p2n = s12p2
        s12p3n = s12p3
    if s12p1n>=s12p2n>=s12p3n:
        s12= -1
    if s12p2n>=s12p1n>=s12p3n:    
        s12=1
    if s12p3n>=s12p2n>=s12p1n:   
        s12=1
    if s12p3n>=s12p1n>=s12p2n:    
        s12= -1     
    if s12p1n>=s12p3n>=s12p2n:
        s12=1    
    if s12p2n>=s12p3n>=s12p1n:    
        s12= -1    
    s.append(s12)    
    s12l.append(s12)
    s12p1e2 = s12p1
    s12p2e2 = s12p2
    s12p3e2 = s12p3
    
    s13p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site13    
    H13 =- np.cos(s13p3-s13p1)- np.cos(s13p2-s13p3)- np.cos(s13p1-s13p2)+ np.cos(s13p1-s3p1)+ np.cos(s13p2-s3p2)+ np.cos(s13p3-s3p3)+ np.cos(s13p1-s14p1)+ np.cos(s13p2-s14p2)+ np.cos(s13p3-s14p3)+ np.cos(s13p1-s23p1)+ np.cos(s13p2-s23p2)+ np.cos(s13p3-s23p3)+ np.cos(s13p1-s12p1)+ np.cos(s13p2-s12p2)+ np.cos(s13p3-s12p3)

    H132 =- np.cos(s13p3e2-s13p1e2)- np.cos(s13p2e2-s13p3e2)- np.cos(s13p1e2-s13p2e2)+ np.cos(s13p1e2-s3p1e2)+ np.cos(s13p2e2-s3p2e2)+ np.cos(s13p3e2-s3p3e2)+ np.cos(s13p1e2-s14p1e2)+ np.cos(s13p2e2-s14p2e2)+ np.cos(s13p3e2-s14p3e2)+ np.cos(s13p1e2-s23p1e2)+ np.cos(s13p2e2-s23p2e2)+ np.cos(s13p3e2-s23p3e2)+ np.cos(s13p1e2-s12p1e2)+ np.cos(s13p2e2-s12p2e2)+ np.cos(s13p3e2-s12p3e2)

    r13 = prob(H132)/prob(H13)
    x13 = np.random.choice([random.uniform(0, 1)])
    if r13 >= x13:
        s13p1n = s13p1e2
        s13p2n = s13p2e2
        s13p3n = s13p3e2
        
        s13p1 = s13p1e2
        s13p2 = s13p2e2
        s13p3 = s13p3e2
        
    else:
        s13p1n = s13p1
        s13p2n = s13p2
        s13p3n = s13p3
    if s13p1n>=s13p2n>=s13p3n:
        s13= -1
    if s13p2n>=s13p1n>=s13p3n:    
        s13=1
    if s13p3n>=s13p2n>=s13p1n:   
        s13=1
    if s13p3n>=s13p1n>=s13p2n:    
        s13= -1     
    if s13p1n>=s13p3n>=s13p2n:
        s13=1    
    if s13p2n>=s13p3n>=s13p1n:    
        s13= -1  
    s.append(s13)  
    s13l.append(s13)
    s13p1e2 = s13p1
    s13p2e2 = s13p2
    s13p3e2 = s13p3
    
    s14p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site14    
    H14 =- np.cos(s14p3-s14p1)- np.cos(s14p2-s14p3)- np.cos(s14p1-s14p2)+ np.cos(s14p1-s4p1)+ np.cos(s14p2-s4p2)+ np.cos(s14p3-s4p3)+ np.cos(s14p1-s15p1)+ np.cos(s14p2-s15p2)+ np.cos(s14p3-s15p3)+ np.cos(s14p1-s24p1)+ np.cos(s14p2-s24p2)+ np.cos(s14p3-s24p3)+ np.cos(s14p1-s13p1)+ np.cos(s14p2-s13p2)+ np.cos(s14p3-s13p3)

    H142 =- np.cos(s14p3e2-s14p1e2)- np.cos(s14p2e2-s14p3e2)- np.cos(s14p1e2-s14p2e2)+ np.cos(s14p1e2-s4p1e2)+ np.cos(s14p2e2-s4p2e2)+ np.cos(s14p3e2-s4p3e2)+ np.cos(s14p1e2-s15p1e2)+ np.cos(s14p2e2-s15p2e2)+ np.cos(s14p3e2-s15p3e2)+ np.cos(s14p1e2-s24p1e2)+ np.cos(s14p2e2-s24p2e2)+ np.cos(s14p3e2-s24p3e2)+ np.cos(s14p1e2-s13p1e2)+ np.cos(s14p2e2-s13p2e2)+ np.cos(s14p3e2-s13p3e2)

    r14 = prob(H142)/prob(H14)
    x14 = np.random.choice([random.uniform(0, 1)])
    if r14 >= x14:
        s14p1n = s14p1e2
        s14p2n = s14p2e2
        s14p3n = s14p3e2
        
        s14p1 = s14p1e2
        s14p2 = s14p2e2
        s14p3 = s14p3e2
        
    else:
        s14p1n = s14p1
        s14p2n = s14p2
        s14p3n = s14p3
    if s14p1n>=s14p2n>=s14p3n:
        s14= -1
    if s14p2n>=s14p1n>=s14p3n:    
        s14=1
    if s14p3n>=s14p2n>=s14p1n:   
        s14=1
    if s14p3n>=s14p1n>=s14p2n:    
        s14= -1     
    if s14p1n>=s14p3n>=s14p2n:
        s14=1    
    if s14p2n>=s14p3n>=s14p1n:    
        s14= -1  
    s.append(s14)
    s14l.append(s14)
    s14p1e2 = s14p1
    s14p2e2 = s14p2
    s14p3e2 = s14p3

    s15p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])                  
#site15    
    H15 =- np.cos(s15p3-s15p1)- np.cos(s15p2-s15p3)- np.cos(s15p1-s15p2)+ np.cos(s15p1-s5p1)+ np.cos(s15p2-s5p2)+ np.cos(s15p3-s5p3)+ np.cos(s15p1-s25p1)+ np.cos(s15p2-s25p2)+ np.cos(s15p3-s25p3)+ np.cos(s15p1-s14p1)+ np.cos(s15p2-s14p2)+ np.cos(s15p3-s14p3)+ np.cos(s15p1-s11p1)+ np.cos(s15p2-s11p2)+ np.cos(s15p3-s11p3)

    H152 =- np.cos(s15p3e2-s15p1e2)- np.cos(s15p2e2-s15p3e2)- np.cos(s15p1e2-s15p2e2)+ np.cos(s15p1e2-s5p1e2)+ np.cos(s15p2e2-s5p2e2)+ np.cos(s15p3e2-s5p3e2)+ np.cos(s15p1e2-s25p1e2)+ np.cos(s15p2e2-s25p2e2)+ np.cos(s15p3e2-s25p3e2)+ np.cos(s15p1e2-s14p1e2)+ np.cos(s15p2e2-s14p2e2)+ np.cos(s15p3e2-s14p3e2)+ np.cos(s15p1e2-s11p1e2)+ np.cos(s15p2e2-s11p2e2)+ np.cos(s15p3e2-s11p3e2)

    r15 = prob(H152)/prob(H15)
    x15 = np.random.choice([random.uniform(0, 1)])
    if r15 >= x15:
        s15p1n = s15p1e2
        s15p2n = s15p2e2
        s15p3n = s15p3e2
        
        s15p1 = s15p1e2
        s15p2 = s15p2e2
        s15p3 = s15p3e2
    else:
        s15p1n = s15p1
        s15p2n = s15p2
        s15p3n = s15p3
    if s15p1n>=s15p2n>=s15p3n:
        s15= -1
    if s15p2n>=s15p1n>=s15p3n:    
        s15=1
    if s15p3n>=s15p2n>=s15p1n:   
        s15=1
    if s15p3n>=s15p1n>=s15p2n:    
        s15= -1     
    if s15p1n>=s15p3n>=s15p2n:
        s15=1    
    if s15p2n>=s15p3n>=s15p1n:    
        s15= -1    
    s.append(s15) 
    s15l.append(s15)
    s15p1e2 = s15p1
    s15p2e2 = s15p2
    s15p3e2 = s15p3

    s21p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
#site21    
    H21 =- np.cos(s21p3-s21p1)- np.cos(s21p2-s21p3)- np.cos(s21p1-s21p2)+ np.cos(s21p1-s11p1)+ np.cos(s21p2-s11p2)+ np.cos(s21p3-s11p3)+ np.cos(s21p1-s31p1)+ np.cos(s21p2-s31p2)+ np.cos(s21p3-s31p3)+ np.cos(s21p1-s22p1)+ np.cos(s21p2-s22p2)+ np.cos(s21p3-s22p3)+ np.cos(s21p1-s25p1)+ np.cos(s21p2-s25p2)+ np.cos(s21p3-s25p3)

    H212 =- np.cos(s21p3e2-s21p1e2)- np.cos(s21p2e2-s21p3e2)- np.cos(s21p1e2-s21p2e2)+ np.cos(s21p1e2-s11p1e2)+ np.cos(s21p2e2-s11p2e2)+ np.cos(s21p3e2-s11p3e2)+ np.cos(s21p1e2-s31p1e2)+ np.cos(s21p2e2-s31p2e2)+ np.cos(s21p3e2-s31p3e2)+ np.cos(s21p1e2-s22p1e2)+ np.cos(s21p2e2-s22p2e2)+ np.cos(s21p3e2-s22p3e2)+ np.cos(s21p1e2-s25p1e2)+ np.cos(s21p2e2-s25p2e2)+ np.cos(s21p3e2-s25p3e2)

    r21 = prob(H212)/prob(H21)
    x21 = np.random.choice([random.uniform(0, 1)])
    if r21 >= x21:
        s21p1n = s21p1e2
        s21p2n = s21p2e2
        s21p3n = s21p3e2
        
        s21p1 = s21p1e2
        s21p2 = s21p2e2
        s21p3 = s21p3e2
  
    else:
        s21p1n = s21p1
        s21p2n = s21p2
        s21p3n = s21p3
    if s21p1n>=s21p2n>=s21p3n:
        s21= -1
    if s21p2n>=s21p1n>=s21p3n:    
        s21=1
    if s21p3n>=s21p2n>=s21p1n:   
        s21=1
    if s21p3n>=s21p1n>=s21p2n:    
        s21= -1     
    if s21p1n>=s21p3n>=s21p2n:
        s21=1    
    if s21p2n>=s21p3n>=s21p1n:    
        s21= -1
    s.append(s21)
    s21l.append(s21)
    s21p1e2 = s21p1
    s21p2e2 = s21p2
    s21p3e2 = s22p3   

    s22p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])            
#site22    
    H22 =- np.cos(s22p3-s22p1)- np.cos(s22p2-s22p3)- np.cos(s22p1-s22p2)+ np.cos(s22p1-s12p1)+ np.cos(s22p2-s12p2)+ np.cos(s22p3-s12p3)+ np.cos(s22p1-s32p1)+ np.cos(s22p2-s32p2)+ np.cos(s22p3-s32p3)+ np.cos(s22p1-s23p1)+ np.cos(s22p2-s23p2)+ np.cos(s22p3-s23p3)+ np.cos(s22p1-s21p1)+ np.cos(s22p2-s21p2)+ np.cos(s22p3-s21p3)

    H222 =- np.cos(s22p3e2-s22p1e2)- np.cos(s22p2e2-s22p3e2)- np.cos(s22p1e2-s22p2e2)+ np.cos(s22p1e2-s12p1e2)+ np.cos(s22p2e2-s12p2e2)+ np.cos(s22p3e2-s12p3e2)+ np.cos(s22p1e2-s32p1e2)+ np.cos(s22p2e2-s32p2e2)+ np.cos(s22p3e2-s32p3e2)+ np.cos(s22p1e2-s23p1e2)+ np.cos(s22p2e2-s23p2e2)+ np.cos(s22p3e2-s23p3e2)+ np.cos(s22p1e2-s21p1e2)+ np.cos(s22p2e2-s21p2e2)+ np.cos(s22p3e2-s21p3e2)

    r22 = prob(H222)/prob(H22)
    x22 = np.random.choice([random.uniform(0, 1)])
    if r22 >= x22:
        s22p1n = s22p1e2
        s22p2n = s22p2e2
        s22p3n = s22p3e2
        
        s22p1 = s22p1e2
        s22p2 = s22p2e2
        s22p3 = s22p3e2
        
    else:
        s22p1n = s22p1
        s22p2n = s22p2
        s22p3n = s22p3
    if s22p1n>=s22p2n>=s22p3n:
        s22= -1
    if s22p2n>=s22p1n>=s22p3n:    
        s22=1
    if s22p3n>=s22p2n>=s22p1n:   
        s22=1
    if s22p3n>=s22p1n>=s22p2n:    
        s22= -1     
    if s22p1n>=s22p3n>=s22p2n:
        s22=1    
    if s22p2n>=s22p3n>=s22p1n:    
        s22= -1    
    s.append(s22)  
    s22l.append(s22)
    s22p1e2 = s22p1
    s22p2e2 = s22p2
    s22p3e2 = s22p3  
    
    s23p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])   
#site23    
    H23 =- np.cos(s23p3-s23p1)- np.cos(s23p2-s23p3)- np.cos(s23p1-s23p2)+ np.cos(s23p1-s13p1)+ np.cos(s23p2-s13p2)+ np.cos(s23p3-s13p3)+ np.cos(s23p1-s33p1)+ np.cos(s23p2-s33p2)+ np.cos(s23p3-s33p3)+ np.cos(s23p1-s24p1)+ np.cos(s23p2-s24p2)+ np.cos(s23p3-s24p3)+ np.cos(s23p1-s22p1)+ np.cos(s23p2-s22p2)+ np.cos(s23p3-s22p3)

    H232 =- np.cos(s23p3e2-s23p1e2)- np.cos(s23p2e2-s23p3e2)- np.cos(s23p1e2-s23p2e2)+ np.cos(s23p1e2-s13p1e2)+ np.cos(s23p2e2-s13p2e2)+ np.cos(s23p3e2-s13p3e2)+ np.cos(s23p1e2-s33p1e2)+ np.cos(s23p2e2-s33p2e2)+ np.cos(s23p3e2-s33p3e2)+ np.cos(s23p1e2-s24p1e2)+ np.cos(s23p2e2-s24p2e2)+ np.cos(s23p3e2-s24p3e2)+ np.cos(s23p1e2-s22p1e2)+ np.cos(s23p2e2-s22p2e2)+ np.cos(s23p3e2-s22p3e2)

    r23 = prob(H232)/prob(H23)
    x23 = np.random.choice([random.uniform(0, 1)])
    if r23>=x23:
        s23p1n = s23p1e2
        s23p2n = s23p2e2
        s23p3n = s23p3e2
        
        s23p1 = s23p1e2
        s23p2 = s23p2e2
        s23p3 = s23p3e2

    else:
        s23p1n = s23p1
        s23p2n = s23p2
        s23p3n = s23p3
    if s23p1n>=s23p2n>=s23p3n:
        s23= -1
    if s23p2n>=s23p1n>=s23p3n:    
        s23=1
    if s23p3n>=s23p2n>=s23p1n:   
        s23=1
    if s23p3n>=s23p1n>=s23p2n:    
        s23= -1     
    if s23p1n>=s23p3n>=s23p2n:
        s23=1    
    if s23p2n>=s23p3n>=s23p1n:    
        s23= -1  
    s.append(s23)  
    s23l.append(s23)
    s23p1e2 = s23p1
    s23p2e2 = s23p2
    s23p3e2 = s23p3
    
    s24p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])           
#site24    
    H24 =- np.cos(s24p3-s24p1)- np.cos(s24p2-s24p3)- np.cos(s24p1-s24p2)+ np.cos(s24p1-s14p1)+ np.cos(s24p2-s14p2)+ np.cos(s24p3-s14p3)+ np.cos(s24p1-s34p1)+ np.cos(s24p2-s34p2)+ np.cos(s24p3-s34p3)+ np.cos(s24p1-s25p1)+ np.cos(s24p2-s25p2)+ np.cos(s24p3-s25p3)+ np.cos(s24p1-s23p1)+ np.cos(s24p2-s23p2)+ np.cos(s24p3-s23p3)

    H242 =- np.cos(s24p3e2-s24p1e2)- np.cos(s24p2e2-s24p3e2)- np.cos(s24p1e2-s24p2e2)+ np.cos(s24p1e2-s14p1e2)+ np.cos(s24p2e2-s14p2e2)+ np.cos(s24p3e2-s14p3e2)+ np.cos(s24p1e2-s34p1e2)+ np.cos(s24p2e2-s34p2e2)+ np.cos(s24p3e2-s34p3e2)+ np.cos(s24p1e2-s25p1e2)+ np.cos(s24p2e2-s25p2e2)+ np.cos(s24p3e2-s25p3e2)+ np.cos(s24p1e2-s23p1e2)+ np.cos(s24p2e2-s23p2e2)+ np.cos(s24p3e2-s23p3e2)

    r24 = prob(H242)/prob(H24)
    x24 = np.random.choice([random.uniform(0, 1)])
    if r24>=x24:
        s24p1n = s24p1e2
        s24p2n = s24p2e2
        s24p3n = s24p3e2
        
        s24p1 = s24p1e2
        s24p2 = s24p2e2
        s24p3 = s24p3e2

    else:
        s24p1n = s24p1
        s24p2n = s24p2
        s24p3n = s24p3 
    if s24p1n>=s24p2n>=s24p3n:
        s24= -1
    if s24p2n>=s24p1n>=s24p3n:    
        s24=1
    if s24p3n>=s24p2n>=s24p1n:   
        s24=1
    if s24p3n>=s24p1n>=s24p2n:    
        s24= -1     
    if s24p1n>=s24p3n>=s24p2n:
        s24=1    
    if s24p2n>=s24p3n>=s24p1n:    
        s24= -1  
    s.append(s24)
    s24l.append(s24)            
    s24p1e2 = s24p1
    s24p2e2 = s24p2
    s24p3e2 = s24p3 
    
    s25p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
#site25    
    H25 =- np.cos(s25p3-s25p1)- np.cos(s25p2-s25p3)- np.cos(s25p1-s25p2)+ np.cos(s25p1-s15p1)+ np.cos(s25p2-s15p2)+ np.cos(s25p3-s15p3)+ np.cos(s25p1-s35p1)+ np.cos(s25p2-s35p2)+ np.cos(s25p3-s35p3)+ np.cos(s25p1-s24p1)+ np.cos(s25p2-s24p2)+ np.cos(s25p3-s24p3)+ np.cos(s25p1-s21p1)+ np.cos(s25p2-s21p2)+ np.cos(s25p3-s21p3)

    H252 =- np.cos(s25p3e2-s25p1e2)- np.cos(s25p2e2-s25p3e2)- np.cos(s25p1e2-s25p2e2)+ np.cos(s25p1e2-s15p1e2)+ np.cos(s25p2e2-s15p2e2)+ np.cos(s25p3e2-s15p3e2)+ np.cos(s25p1e2-s35p1e2)+ np.cos(s25p2e2-s35p2e2)+ np.cos(s25p3e2-s35p3e2)+ np.cos(s25p1e2-s24p1e2)+ np.cos(s25p2e2-s24p2e2)+ np.cos(s25p3e2-s24p3e2)+ np.cos(s25p1e2-s21p1e2)+ np.cos(s25p2e2-s21p2e2)+ np.cos(s25p3e2-s21p3e2)

    r25 = prob(H252)/prob(H25)
    x25 = np.random.choice([random.uniform(0, 1)])
    if r25>=x25:
        s25p1n = s25p1e2
        s25p2n = s25p2e2
        s25p3n = s25p3e2
        
        s25p1 = s25p1e2
        s25p2 = s25p2e2
        s25p3 = s25p3e2

    else:
        s25p1n = s25p1
        s25p2n = s25p2
        s25p3n = s25p3
    if s25p1n>=s25p2n>=s25p3n:
        s25= -1
    if s25p2n>=s25p1n>=s25p3n:    
        s25=1
    if s25p3n>=s25p2n>=s25p1n:   
        s25=1
    if s25p3n>=s25p1n>=s25p2n:    
        s25= -1     
    if s25p1n>=s25p3n>=s25p2n:
        s25=1    
    if s25p2n>=s25p3n>=s25p1n:    
        s25= -1 
    s.append(s25) 
    s25l.append(s25)
    s25p1e2 = s25p1
    s25p2e2 = s25p2
    s25p3e2 = s25p3

    s31p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 

#site31    
    H31 =- np.cos(s31p3-s31p1)- np.cos(s31p2-s31p3)- np.cos(s31p1-s31p2)+ np.cos(s31p1-s21p1)+ np.cos(s31p2-s21p2)+ np.cos(s31p3-s21p3)+ np.cos(s31p1-s41p1)+ np.cos(s31p2-s41p2)+ np.cos(s31p3-s41p3)+ np.cos(s31p1-s32p1)+ np.cos(s31p2-s32p2)+ np.cos(s31p3-s32p3)+ np.cos(s31p1-s35p1)+ np.cos(s31p2-s35p2)+ np.cos(s31p3-s35p3)

    H312 =- np.cos(s31p3e2-s31p1e2)- np.cos(s31p2e2-s31p3e2)- np.cos(s31p1e2-s31p2e2)+ np.cos(s31p1e2-s21p1e2)+ np.cos(s31p2e2-s21p2e2)+ np.cos(s31p3e2-s21p3e2)+ np.cos(s31p1e2-s41p1e2)+ np.cos(s31p2e2-s41p2e2)+ np.cos(s31p3e2-s41p3e2)+ np.cos(s31p1e2-s32p1e2)+ np.cos(s31p2e2-s32p2e2)+ np.cos(s31p3e2-s32p3e2)+ np.cos(s31p1e2-s35p1e2)+ np.cos(s31p2e2-s35p2e2)+ np.cos(s31p3e2-s35p3e2)

    r31 = prob(H312)/prob(H31)
    x31 = np.random.choice([random.uniform(0, 1)])
    if r31>=x31:
        s31p1n = s31p1e2
        s31p2n = s31p2e2
        s31p3n = s31p3e2

        s31p1 = s31p1e2
        s31p2 = s31p2e2
        s31p3 = s31p3e2
    else:
        s31p1n = s31p1
        s31p2n = s31p2
        s31p3n = s31p3
    if s31p1n>=s31p2n>=s31p3n:
        s31= -1
    if s31p2n>=s31p1n>=s31p3n:    
        s31=1
    if s31p3n>=s31p2n>=s31p1n:   
        s31=1
    if s31p3n>=s31p1n>=s31p2n:    
        s31= -1     
    if s31p1n>=s31p3n>=s31p2n:
        s31=1    
    if s31p2n>=s31p3n>=s31p1n:    
        s31= -1
    s.append(s31) 
    s31l.append(s31)
    s31p1e2 = s31p1
    s31p2e2 = s31p2
    s31p3e2 = s31p3
    
    s32p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
    
#site32    
    H32 =- np.cos(s32p3-s32p1)- np.cos(s32p2-s32p3)- np.cos(s32p1-s32p2)+ np.cos(s32p1-s22p1)+ np.cos(s32p2-s22p2)+ np.cos(s32p3-s22p3)+ np.cos(s32p1-s42p1)+ np.cos(s32p2-s42p2)+ np.cos(s32p3-s42p3)+ np.cos(s32p1-s33p1)+ np.cos(s32p2-s33p2)+ np.cos(s32p3-s33p3)+ np.cos(s32p1-s31p1)+ np.cos(s32p2-s31p2)+ np.cos(s32p3-s31p3)

    H322 =- np.cos(s32p3e2-s32p1e2)- np.cos(s32p2e2-s32p3e2)- np.cos(s32p1e2-s32p2e2)+ np.cos(s32p1e2-s22p1e2)+ np.cos(s32p2e2-s22p2e2)+ np.cos(s32p3e2-s22p3e2)+ np.cos(s32p1e2-s42p1e2)+ np.cos(s32p2e2-s42p2e2)+ np.cos(s32p3e2-s42p3e2)+ np.cos(s32p1e2-s33p1e2)+ np.cos(s32p2e2-s33p2e2)+ np.cos(s32p3e2-s33p3e2)+ np.cos(s32p1e2-s31p1e2)+ np.cos(s32p2e2-s31p2e2)+ np.cos(s32p3e2-s31p3e2)

    r32 = prob(H322)/prob(H32)
    x32 = np.random.choice([random.uniform(0, 1)])
    if r32>=x32:
        s32p1n = s32p1e2
        s32p2n = s32p2e2
        s32p3n = s32p3e2

        s32p1 = s32p1e2
        s32p2 = s32p2e2
        s32p3 = s32p3e2
    else:
        s32p1n = s32p1
        s32p2n = s32p2
        s32p3n = s32p3
    if s32p1n>=s32p2n>=s32p3n:
        s32= -1
    if s32p2n>=s32p1n>=s32p3n:    
        s32=1
    if s32p3n>=s32p2n>=s32p1n:   
        s32=1
    if s32p3n>=s32p1n>=s32p2n:    
        s32= -1     
    if s32p1n>=s32p3n>=s32p2n:
        s32=1    
    if s32p2n>=s32p3n>=s32p1n:    
        s32= -1    
    s.append(s32) 
    s32l.append(s32)           
    s32p1e2 = s32p1
    s32p2e2 = s32p2
    s32p3e2 = s32p3        
    
    s33p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site33    
    H33 =- np.cos(s33p3-s33p1)- np.cos(s33p2-s33p3)- np.cos(s33p1-s33p2)+ np.cos(s33p1-s23p1)+ np.cos(s33p2-s23p2)+ np.cos(s33p3-s23p3)+ np.cos(s33p1-s43p1)+ np.cos(s33p2-s43p2)+ np.cos(s33p3-s43p3)+ np.cos(s33p1-s34p1)+ np.cos(s33p2-s34p2)+ np.cos(s33p3-s34p3)+ np.cos(s33p1-s32p1)+ np.cos(s33p2-s32p2)+ np.cos(s33p3-s32p3)

    H332 =- np.cos(s33p3e2-s33p1e2)- np.cos(s33p2e2-s33p3e2)- np.cos(s33p1e2-s33p2e2)+ np.cos(s33p1e2-s23p1e2)+ np.cos(s33p2e2-s23p2e2)+ np.cos(s33p3e2-s23p3e2)+ np.cos(s33p1e2-s43p1e2)+ np.cos(s33p2e2-s43p2e2)+ np.cos(s33p3e2-s43p3e2)+ np.cos(s33p1e2-s34p1e2)+ np.cos(s33p2e2-s34p2e2)+ np.cos(s33p3e2-s34p3e2)+ np.cos(s33p1e2-s32p1e2)+ np.cos(s33p2e2-s32p2e2)+ np.cos(s33p3e2-s32p3e2)

    r33 = prob(H332)/prob(H33)
    x33 = np.random.choice([random.uniform(0, 1)])
    if r33>=x33:
        s33p1n = s33p1e2
        s33p2n = s33p2e2
        s33p3n = s33p3e2
        
        s33p1 = s33p1e2
        s33p2 = s33p2e2
        s33p3 = s33p3e2
        
    else:
        s33p1n = s33p1
        s33p2n = s33p2
        s33p3n = s33p3
    if s33p1n>=s33p2n>=s33p3n:
        s33= -1
    if s33p2n>=s33p1n>=s33p3n:    
        s33=1
    if s33p3n>=s33p2n>=s33p1n:   
        s33=1
    if s33p3n>=s33p1n>=s33p2n:    
        s33= -1     
    if s33p1n>=s33p3n>=s33p2n:
        s33=1    
    if s33p2n>=s33p3n>=s33p1n:    
        s33= -1
    s.append(s33)
    s33l.append(s33)        
    s33p1e2 = s33p1
    s33p2e2 = s33p2
    s33p3e2 = s33p3

    s34p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site34    
    H34 =- np.cos(s34p3-s34p1)- np.cos(s34p2-s34p3)- np.cos(s34p1-s34p2)+ np.cos(s34p1-s24p1)+ np.cos(s34p2-s24p2)+ np.cos(s34p3-s24p3)+ np.cos(s34p1-s44p1)+ np.cos(s34p2-s44p2)+ np.cos(s34p3-s44p3)+ np.cos(s34p1-s35p1)+ np.cos(s34p2-s35p2)+ np.cos(s34p3-s35p3)+ np.cos(s34p1-s33p1)+ np.cos(s34p2-s33p2)+ np.cos(s34p3-s33p3)

    H342 =- np.cos(s34p3e2-s34p1e2)- np.cos(s34p2e2-s34p3e2)- np.cos(s34p1e2-s34p2e2)+ np.cos(s34p1e2-s24p1e2)+ np.cos(s34p2e2-s24p2e2)+ np.cos(s34p3e2-s24p3e2)+ np.cos(s34p1e2-s44p1e2)+ np.cos(s34p2e2-s44p2e2)+ np.cos(s34p3e2-s44p3e2)+ np.cos(s34p1e2-s35p1e2)+ np.cos(s34p2e2-s35p2e2)+ np.cos(s34p3e2-s35p3e2)+ np.cos(s34p1e2-s33p1e2)+ np.cos(s34p2e2-s33p2e2)+ np.cos(s34p3e2-s33p3e2)

    r34 = prob(H342)/prob(H34)
    x34 = np.random.choice([random.uniform(0, 1)])
    if r34>=x34:
        s34p1n = s34p1e2
        s34p2n = s34p2e2
        s34p3n = s34p3e2
        
        s34p1 = s34p1e2
        s34p2 = s34p2e2
        s34p3 = s34p3e2

    else:
        s34p1n = s34p1
        s34p2n = s34p2
        s34p3n = s34p3
    if s34p1n>=s34p2n>=s34p3n:
        s34= -1
    if s34p2n>=s34p1n>=s34p3n:    
        s34=1
    if s34p3n>=s34p2n>=s34p1n:   
        s34=1
    if s34p3n>=s34p1n>=s34p2n:    
        s34= -1     
    if s34p1n>=s34p3n>=s34p2n:
        s34=1    
    if s34p2n>=s34p3n>=s34p1n:    
        s34= -1    
    s.append(s34)  
    s34l.append(s34)      
    s34p1e2 = s34p1
    s34p2e2 = s34p2
    s34p3e2 = s34p3

    s35p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site35    
    H35 =- np.cos(s35p3-s35p1)- np.cos(s35p2-s35p3)- np.cos(s35p1-s35p2)+ np.cos(s35p1-s25p1)+ np.cos(s35p2-s25p2)+ np.cos(s35p3-s25p3)+ np.cos(s35p1-s45p1)+ np.cos(s35p2-s45p2)+ np.cos(s35p3-s45p3)+ np.cos(s35p1-s34p1)+ np.cos(s35p2-s34p2)+ np.cos(s35p3-s34p3)+ np.cos(s35p1-s31p1)+ np.cos(s35p2-s31p2)+ np.cos(s35p3-s31p3)

    H352 =- np.cos(s35p3e2-s35p1e2)- np.cos(s35p2e2-s35p3e2)- np.cos(s35p1e2-s35p2e2)+ np.cos(s35p1e2-s25p1e2)+ np.cos(s35p2e2-s25p2e2)+ np.cos(s35p3e2-s25p3e2)+ np.cos(s35p1e2-s45p1e2)+ np.cos(s35p2e2-s45p2e2)+ np.cos(s35p3e2-s45p3e2)+ np.cos(s35p1e2-s34p1e2)+ np.cos(s35p2e2-s34p2e2)+ np.cos(s35p3e2-s34p3e2)+ np.cos(s35p1e2-s31p1e2)+ np.cos(s35p2e2-s31p2e2)+ np.cos(s35p3e2-s31p3e2)

    r35 = prob(H352)/prob(H35)
    x35 = np.random.choice([random.uniform(0, 1)])
    if r35>=x35:
        s35p1n = s35p1e2
        s35p2n = s35p2e2
        s35p3n = s35p3e2
        
        s35p1 = s35p1e2
        s35p2 = s35p2e2
        s35p3 = s35p3e2

    else:
        s35p1n = s35p1
        s35p2n = s35p2
        s35p3n = s35p3
    if s35p1n>=s35p2n>=s35p3n:
        s35= -1
    if s35p2n>=s35p1n>=s35p3n:    
        s35=1
    if s35p3n>=s35p2n>=s35p1n:   
        s35=1
    if s35p3n>=s35p1n>=s35p2n:    
        s35= -1     
    if s35p1n>=s35p3n>=s35p2n:
        s35=1    
    if s35p2n>=s35p3n>=s35p1n:    
        s35= -1    
    s.append(s35) 
    s35l.append(s35)
    s35p1e2 = s35p1
    s35p2e2 = s35p2
    s35p3e2 = s35p3

    s41p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site41    
    H41 =- np.cos(s41p3-s41p1)- np.cos(s41p2-s41p3)- np.cos(s41p1-s41p2)+ np.cos(s41p1-s31p1)+ np.cos(s41p2-s31p2)+ np.cos(s41p3-s31p3)+ np.cos(s41p1-s1p1)+ np.cos(s41p2-s1p2)+ np.cos(s41p3-s1p3)+ np.cos(s41p1-s42p1)+ np.cos(s41p2-s42p2)+ np.cos(s41p3-s42p3)+ np.cos(s41p1-s45p1)+ np.cos(s41p2-s45p2)+ np.cos(s41p3-s45p3)

    H412 =- np.cos(s41p3e2-s41p1e2)- np.cos(s41p2e2-s41p3e2)- np.cos(s41p1e2-s41p2e2)+ np.cos(s41p1e2-s31p1e2)+ np.cos(s41p2e2-s31p2e2)+ np.cos(s41p3e2-s31p3e2)+ np.cos(s41p1e2-s1p1e2)+ np.cos(s41p2e2-s1p2e2)+ np.cos(s41p3e2-s1p3e2)+ np.cos(s41p1e2-s42p1e2)+ np.cos(s41p2e2-s42p2e2)+ np.cos(s41p3e2-s42p3e2)+ np.cos(s41p1e2-s45p1e2)+ np.cos(s41p2e2-s45p2e2)+ np.cos(s41p3e2-s45p3e2)

    r41 = prob(H412)/prob(H41)
    x41 = np.random.choice([random.uniform(0, 1)])
    if r41>=x41:
        s41p1n = s41p1e2
        s41p2n = s41p2e2
        s41p3n = s41p3e2
        
        s41p1 = s41p1e2
        s41p2 = s41p2e2
        s41p3 = s41p3e2

    else:
        s41p1n = s41p1
        s41p2n = s41p2
        s41p3n = s41p3
    if s41p1n>=s41p2n>=s41p3n:
        s41= -1
    if s41p2n>=s41p1n>=s41p3n:    
        s41=1
    if s41p3n>=s41p2n>=s41p1n:   
        s41=1
    if s41p3n>=s41p1n>=s41p2n:    
        s41= -1     
    if s41p1n>=s41p3n>=s41p2n:
        s41=1    
    if s41p2n>=s41p3n>=s41p1n:    
        s41= -1  
    s.append(s41)  
    s41l.append(s41)
    s41p1e2 = s41p1
    s41p2e2 = s41p2
    s41p3e2 = s42p3

    s42p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site42    
    H42 =- np.cos(s42p3-s42p1)- np.cos(s42p2-s42p3)- np.cos(s42p1-s42p2)+ np.cos(s42p1-s32p1)+ np.cos(s42p2-s32p2)+ np.cos(s42p3-s32p3)+ np.cos(s42p1-s2p1)+ np.cos(s42p2-s2p2)+ np.cos(s42p3-s2p3)+ np.cos(s42p1-s43p1)+ np.cos(s42p2-s43p2)+ np.cos(s42p3-s43p3)+ np.cos(s42p1-s41p1)+ np.cos(s42p2-s41p2)+ np.cos(s42p3-s41p3)

    H422 =- np.cos(s42p3e2-s42p1e2)- np.cos(s42p2e2-s42p3e2)- np.cos(s42p1e2-s42p2e2)+ np.cos(s42p1e2-s32p1e2)+ np.cos(s42p2e2-s32p2e2)+ np.cos(s42p3e2-s32p3e2)+ np.cos(s42p1e2-s2p1e2)+ np.cos(s42p2e2-s2p2e2)+ np.cos(s42p3e2-s2p3e2)+ np.cos(s42p1e2-s43p1e2)+ np.cos(s42p2e2-s43p2e2)+ np.cos(s42p3e2-s43p3e2)+ np.cos(s42p1e2-s41p1e2)+ np.cos(s42p2e2-s41p2e2)+ np.cos(s42p3e2-s41p3e2)

    r42 = prob(H422)/prob(H42)
    x42 = np.random.choice([random.uniform(0, 1)])
    if r42>=x42:
        s42p1n = s42p1e2
        s42p2n = s42p2e2
        s42p3n = s42p3e2
        
        s42p1 = s42p1e2
        s42p2 = s42p2e2
        s42p3 = s42p3e2

    else:
        s42p1n = s42p1
        s42p2n = s42p2
        s42p3n = s42p3
    if s42p1n>=s42p2n>=s42p3n:
        s42= -1
    if s42p2n>=s42p1n>=s42p3n:    
        s42=1
    if s42p3n>=s42p2n>=s42p1n:   
        s42=1
    if s42p3n>=s42p1n>=s42p2n:    
        s42= -1     
    if s42p1n>=s42p3n>=s42p2n:
        s42=1    
    if s42p2n>=s42p3n>=s42p1n:    
        s42= -1    
    s.append(s42)  
    s42l.append(s42)
    s42p1e2 = s42p1
    s42p2e2 = s42p2
    s42p3e2 = s42p3

    s43p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site43    
    H43 =- np.cos(s43p3-s43p1)- np.cos(s43p2-s43p3)- np.cos(s43p1-s43p2)+ np.cos(s43p1-s33p1)+ np.cos(s43p2-s33p2)+ np.cos(s43p3-s33p3)+ np.cos(s43p1-s3p1)+ np.cos(s43p2-s3p2)+ np.cos(s43p3-s3p3)+ np.cos(s43p1-s44p1)+ np.cos(s43p2-s44p2)+ np.cos(s43p3-s44p3)+ np.cos(s43p1-s42p1)+ np.cos(s43p2-s42p2)+ np.cos(s43p3-s42p3)

    H432 =- np.cos(s43p3e2-s43p1e2)- np.cos(s43p2e2-s43p3e2)- np.cos(s43p1e2-s43p2e2)+ np.cos(s43p1e2-s33p1e2)+ np.cos(s43p2e2-s33p2e2)+ np.cos(s43p3e2-s33p3e2)+ np.cos(s43p1e2-s3p1e2)+ np.cos(s43p2e2-s3p2e2)+ np.cos(s43p3e2-s3p3e2)+ np.cos(s43p1e2-s44p1e2)+ np.cos(s43p2e2-s44p2e2)+ np.cos(s43p3e2-s44p3e2)+ np.cos(s43p1e2-s42p1e2)+ np.cos(s43p2e2-s42p2e2)+ np.cos(s43p3e2-s42p3e2)

    r43 = prob(H432)/prob(H43)
    x43 = np.random.choice([random.uniform(0, 1)])
    if r43>=x43:
        s43p1n = s43p1e2
        s43p2n = s43p2e2
        s43p3n = s43p3e2
        
        s43p1 = s43p1e2
        s43p2 = s43p2e2
        s43p3 = s43p3e2

    else:
        s43p1n = s43p1
        s43p2n = s43p2
        s43p3n = s43p3
    if s43p1n>=s43p2n>=s43p3n:
        s43= -1
    if s43p2n>=s43p1n>=s43p3n:    
        s43=1
    if s43p3n>=s43p2n>=s43p1n:   
        s43=1
    if s43p3n>=s43p1n>=s43p2n:    
        s43= -1     
    if s43p1n>=s43p3n>=s43p2n:
        s43=1    
    if s43p2n>=s43p3n>=s43p1n:    
        s43= -1 
    s.append(s43) 
    s43l.append(s43)
    s43p1e2 = s43p1
    s43p2e2 = s43p2
    s43p3e2 = s43p3

    s44p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site44    
    H44 =- np.cos(s44p3-s44p1)- np.cos(s44p2-s44p3)- np.cos(s44p1-s44p2)+ np.cos(s44p1-s34p1)+ np.cos(s44p2-s34p2)+ np.cos(s44p3-s34p3)+ np.cos(s44p1-s4p1)+ np.cos(s44p2-s4p2)+ np.cos(s44p3-s4p3)+ np.cos(s44p1-s45p1)+ np.cos(s44p2-s45p2)+ np.cos(s44p3-s45p3)+ np.cos(s44p1-s43p1)+ np.cos(s44p2-s43p2)+ np.cos(s44p3-s43p3)

    H442 =- np.cos(s44p3e2-s44p1e2)- np.cos(s44p2e2-s44p3e2)- np.cos(s44p1e2-s44p2e2)+ np.cos(s44p1e2-s34p1e2)+ np.cos(s44p2e2-s34p2e2)+ np.cos(s44p3e2-s34p3e2)+ np.cos(s44p1e2-s4p1e2)+ np.cos(s44p2e2-s4p2e2)+ np.cos(s44p3e2-s4p3e2)+ np.cos(s44p1e2-s45p1e2)+ np.cos(s44p2e2-s45p2e2)+ np.cos(s44p3e2-s45p3e2)+ np.cos(s44p1e2-s43p1e2)+ np.cos(s44p2e2-s43p2e2)+ np.cos(s44p3e2-s43p3e2)

    r44 = prob(H442)/prob(H44)
    x44 = np.random.choice([random.uniform(0, 1)])
    if r44>=x44:
        s44p1n = s44p1e2
        s44p2n = s44p2e2
        s44p3n = s44p3e2
        
        s44p1 = s44p1e2
        s44p2 = s44p2e2
        s44p3 = s44p3e2
 
    else:
        s44p1n = s44p1
        s44p2n = s44p2
        s44p3n = s44p3
    if s44p1n>=s44p2n>=s44p3n:
        s44= -1
    if s44p2n>=s44p1n>=s44p3n:    
        s44=1
    if s44p3n>=s44p2n>=s44p1n:   
        s44=1
    if s44p3n>=s44p1n>=s44p2n:    
        s44= -1     
    if s44p1n>=s44p3n>=s44p2n:
        s44=1    
    if s44p2n>=s44p3n>=s44p1n:    
        s44= -1 
    s.append(s44)   
    s44l.append(s44)         
    s44p1e2 = s44p1
    s44p2e2 = s44p2
    s44p3e2 = s44p3
    
    s45p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])        
#site45    
    H45 =- np.cos(s45p3-s45p1)- np.cos(s45p2-s45p3)- np.cos(s45p1-s45p2)+ np.cos(s45p1-s35p1)+ np.cos(s45p2-s35p2)+ np.cos(s45p3-s35p3)+ np.cos(s45p1-s5p1)+ np.cos(s45p2-s5p2)+ np.cos(s45p3-s5p3)+ np.cos(s45p1-s44p1)+ np.cos(s45p2-s44p2)+ np.cos(s45p3-s44p3)+ np.cos(s45p1-s41p1)+ np.cos(s45p2-s41p2)+ np.cos(s45p3-s41p3)

    H452 =- np.cos(s45p3e2-s45p1e2)- np.cos(s45p2e2-s45p3e2)- np.cos(s45p1e2-s45p2e2)+ np.cos(s45p1e2-s35p1e2)+ np.cos(s45p2e2-s35p2e2)+ np.cos(s45p3e2-s35p3e2)+ np.cos(s45p1e2-s5p1e2)+ np.cos(s45p2e2-s5p2e2)+ np.cos(s45p3e2-s5p3e2)+ np.cos(s45p1e2-s44p1e2)+ np.cos(s45p2e2-s44p2e2)+ np.cos(s45p3e2-s44p3e2)+ np.cos(s45p1e2-s41p1e2)+ np.cos(s45p2e2-s41p2e2)+ np.cos(s45p3e2-s41p3e2)

    r45 = prob(H452)/prob(H45)
    x45 = np.random.choice([random.uniform(0, 1)])
    if r45>=x45:
        s45p1n = s45p1e2
        s45p2n = s45p2e2
        s45p3n = s45p3e2
        
        s45p1 = s45p1e2
        s45p2 = s45p2e2
        s45p3 = s45p3e2

    else:
        s45p1n = s45p1
        s45p2n = s45p2
        s45p3n = s45p3
    if s45p1n>=s45p2n>=s45p3n:
        s45= -1
    if s45p2n>=s45p1n>=s45p3n:    
        s45=1
    if s45p3n>=s45p2n>=s45p1n:   
        s45=1
    if s45p3n>=s45p1n>=s45p2n:    
        s45= -1     
    if s45p1n>=s45p3n>=s45p2n:
        s45=1    
    if s45p2n>=s45p3n>=s45p1n:    
        s45= -1  
    s.append(s45)
    s45l.append(s45)
    S.append(abs(mean(s)))
                                                          
print(abs(mean(S)))

fs1l= mean(s1l)

fs2l= mean(s2l)
   
fs3l= mean(s3l)

fs4l= mean(s4l)
  
fs5l= mean(s5l)
 
fs11l= mean(s11l)
   
fs12l= mean(s12l)
  
fs13l= mean(s13l)
  
fs14l= mean(s14l)
   
fs15l= mean(s15l)
  
fs21l= mean(s21l)
   
fs22l= mean(s22l)
  
fs23l= mean(s23l)

fs24l= mean(s24l)
  
fs25l= mean(s25l)
  
fs31l= mean(s31l)
  
fs32l= mean(s32l)

fs33l= mean(s33l)
  
fs34l= mean(s34l)
  
fs35l= mean(s35l)
 
fs41l= mean(s41l)
 
fs42l= mean(s42l)
 
fs43l= mean(s43l)
 
fs44l= mean(s44l)
  
fs45l= mean(s45l)
    


if fs1l>0:
    j1=90
else:
    j1=270
if fs2l>0:
    j2=90
else:
    j2=270    
if fs3l>0:
    j3=90
else:
    j3=270
if fs4l>0:
    j4=90
else:
    j4=270
if fs5l>0:
    j5=90
else:
    j5=270    
if fs11l>0:
    j11=90
else:
    j11=270
if fs12l>0:
    j12=90
else:
    j12=270
if fs13l>0:
    j13=90
else:
    j13=270    
if fs14l>0:
    j14=90
else:
    j14=270
if fs15l>0:
    j15=90
else:
    j15=270
if fs21l>0:
    j21=90
else:
    j21=270    
if fs22l>0:
    j22=90
else:
    j22=270
if fs23l>0:
    j23=90
else:
    j23=270
if fs24l>0:
    j24=90
else:
    j24=270    
if fs25l>0:
    j25=90
else:
    j25=270
if fs31l>0:
    j31=90
else:
    j31=270
if fs32l>0:
    j32=90
else:
    j32=270    
if fs33l>0:
    j33=90
else:
    j33=270
if fs34l>0:
    j34=90
else:
    j34=270
if fs35l>0:
    j35=90
else:
    j35=270    
if fs41l>0:
    j41=90
else:
    j41=270
if fs42l>0:
    j42=90
else:
    j42=270
if fs43l>0:
    j43=90
else:
    j43=270    
if fs44l>0:
    j44=90
else:
    j44=270
if fs45l>0:
    j45=90
else:
    j45=270 
x=1
y=5
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j1)
if j1 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
    
x=1
y=4
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j2)
if j2 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
x=1
y=3
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j3)
if j3 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
    
x=1
y=2
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j4)
if j4 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)

x=1
y=1
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j5)
if j5 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)    
    
    
    
x=2
y=5
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j11)
if j11 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
    
x=2
y=4
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j12)
if j12 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
x=2
y=3
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j13)
if j13 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
    
x=2
y=2
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j14)
if j14 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)

x=2
y=1
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j15)
if j15 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)       
    
    
    
x=3
y=5
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j21)
if j21 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
    
x=3
y=4
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j22)
if j22 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
x=3
y=3
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j23)
if j23 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
    
x=3
y=2
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j24)
if j24 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)

x=3
y=1
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j25)
if j25 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)       
    
    
    
x=4
y=5
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j31)
if j31 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
    
x=4
y=4
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j32)
if j32 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
x=4
y=3
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j33)
if j33 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
    
x=4
y=2
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j34)
if j34 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)

x=4
y=1
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j35)
if j35 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)       
    
x=5
y=5
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j41)
if j41 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
    
x=5
y=4
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j42)
if j42 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
x=5
y=3
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j43)
if j43 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
    
    
x=5
y=2
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j44)
if j44 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)

x=5
y=1
[X,Y]=np.meshgrid(x,y)    
t = mpl.markers.MarkerStyle(marker='‎$‎->$')
t._transform = t.get_transform().rotate_deg(j45)
if j45 == 90:
    plt.scatter((X), (Y), marker=t, color='b', s=100)
else:
    plt.scatter((X), (Y), marker=t, color='r', s=100)
# Out:
# 0.748934655233124

# %% [markdown]
# <h1 style="font-size:100px; text-align:center;">STANDARD DEVIATION</h1>

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import random
from statistics import mean 

k=1
s1p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s2p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s11p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s31p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s41p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s32p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s42p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s43p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s44p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s33p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s34p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s35p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s45p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s12p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s3p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s13p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s14p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s15p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s21p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s22p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s23p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s24p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s25p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s4p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s5p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p3 = np.random.choice([random.uniform(0, 2*np.pi)])
T=0.1
b= k/T
s = []
def prob(H):
    return np.exp(H*b) 

S = []
T1=[]


for i in range(500):
    s1p1e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    s1p2e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    s1p3e2 =np.random.choice([random.uniform(0, 2*np.pi)])

    s2p1e2 =s2p1
    s2p2e2 =s2p2
    s2p3e2 =s2p3
    
    s11p1e2 = s11p1
    s11p2e2 = s11p2
    s11p3e2 = s11p3
    
    s31p1e2 = s31p1
    s31p2e2 = s31p2
    s31p3e2 = s31p3
    
    s41p1e2 = s41p1
    s41p2e2 = s41p2
    s41p3e2 = s41p3
    
    s42p1e2 = s42p1
    s42p2e2 = s42p2
    s42p3e2 = s42p3
    
    s43p1e2 = s43p1
    s43p2e2 = s43p2
    s43p3e2 = s43p3
    
    s44p1e2 = s44p1
    s44p2e2 = s44p2
    s44p3e2 = s44p3
    
    s32p1e2 = s32p1
    s32p2e2 = s32p2
    s32p3e2 = s32p3
    
    s33p1e2 = s33p1
    s33p2e2 = s33p2
    s33p3e2 = s33p3
    
    s34p1e2 = s34p1
    s34p2e2 = s34p2
    s34p3e2 = s34p3
    
    s35p1e2 = s35p1
    s35p2e2 = s35p2
    s35p3e2 = s35p3
    
    s45p1e2 = s45p1
    s45p2e2 = s45p2
    s45p3e2 = s45p3
    
    s12p1e2 = s12p1
    s12p2e2 = s12p2
    s12p3e2 = s12p3
    
    s13p1e2 = s13p1
    s13p2e2 = s13p2
    s13p3e2 = s13p3
    
    s3p1e2 = s3p1
    s3p2e2 = s3p2
    s3p3e2 = s3p3
    
    s4p1e2 = s4p1
    s4p2e2 = s4p2
    s4p3e2 = s4p3
    
    s14p1e2 = s14p1
    s14p2e2 = s14p2
    s14p3e2 = s14p3
    
    s15p1e2 = s15p1
    s15p2e2 = s15p2
    s15p3e2 = s15p3
    
    s21p1e2 = s21p1
    s21p2e2 = s21p2
    s21p3e2 = s21p3
    
    s5p1e2 = s5p1
    s5p2e2 = s5p2
    s5p3e2 = s5p3
    
    s22p1e2 = s22p1
    s22p2e2 = s22p2
    s22p3e2 = s22p3
    
    s23p1e2 = s23p1
    s23p2e2 = s23p2
    s23p3e2 = s23p3
    
    s24p1e2 = s24p1
    s24p2e2 = s24p2
    s24p3e2 = s24p3
    
    s25p1e2 = s25p1
    s25p2e2 = s25p2
    s25p3e2 = s25p3
#site1        
    H1 = - np.cos(s1p1-s1p2) - np.cos(s1p2-s1p3)- np.cos(s1p3-s1p1)+ np.cos(s1p1-s2p1)+ np.cos(s1p2-s2p2)+ np.cos(s1p3-s2p3)+ np.cos(s1p1-s11p1)+ np.cos(s1p2-s11p2)+ np.cos(s1p3-s11p3)+ np.cos(s1p1-s41p1)+ np.cos(s1p2-s41p2)+ np.cos(s1p3-s41p3)+ np.cos(s1p1-s5p1)+ np.cos(s1p2-s5p2)+ np.cos(s1p3-s5p3)
    
    H12 = - np.cos(s1p1e2-s1p2e2)- np.cos(s1p3e2-s1p1e2)- np.cos(s1p2e2-s1p3e2)+ np.cos(s1p1e2-s2p1e2)+ np.cos(s1p2e2-s2p2e2)+ np.cos(s1p3e2-s2p3e2)+ np.cos(s1p1e2-s11p1e2)+ np.cos(s1p2e2-s11p2e2)+ np.cos(s1p3e2-s11p3e2)+ np.cos(s1p1e2-s41p1e2)+ np.cos(s1p2e2-s41p2e2)+ np.cos(s1p3e2-s41p3e2)+ np.cos(s1p1e2-s5p1e2)+ np.cos(s1p2e2-s5p2e2)+ np.cos(s1p3e2-s5p3e2)

    r= prob(H12)/prob(H1)
    x= np.random.choice([random.uniform(0, 1)])
    if r >= x:
        s1p1n = s1p1e2
        s1p2n = s1p2e2
        s1p3n = s1p3e2
        
        s1p1 = s1p1e2
        s1p2 = s1p2e2
        s1p3 = s1p3e2
        
    else:
        s1p1n = s1p1
        s1p2n = s1p2
        s1p3n = s1p3
    if s1p1n>=s1p2n>=s1p3n:
        s1= -1
    if s1p2n>=s1p1n>=s1p3n:    
        s1=1
    if s1p3n>=s1p2n>=s1p1n:   
        s1=1
    if s1p3n>=s1p1n>=s1p2n:    
        s1= -1     
    if s1p1n>=s1p3n>=s1p2n:
        s1=1    
    if s1p2n>=s1p3n>=s1p1n:    
        s1= -1    
    s.append(s1)    
    s1p1e2 =s1p1
    s1p2e2 =s1p2
    s1p3e2 =s1p3
    
    s2p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site2    
    H2 = - np.cos(s2p2-s2p3)- np.cos(s2p3-s2p1)- np.cos(s2p1-s2p2)+ np.cos(s2p1-s12p1)+ np.cos(s2p2-s12p2)+ np.cos(s2p3-s12p3)+ np.cos(s2p1-s1p1)+ np.cos(s2p2-s1p2)+ np.cos(s2p3-s1p2)+ np.cos(s2p1-s3p1)+ np.cos(s2p2-s3p2)+ np.cos(s2p3-s3p3)+ np.cos(s2p1-s42p1)+ np.cos(s2p2-s42p2)+ np.cos(s2p3-s42p3)

    H22 =- np.cos(s2p3e2-s2p1e2)- np.cos(s2p2e2-s2p3e2)- np.cos(s2p1e2-s2p2e2)+ np.cos(s2p1e2-s1p1e2)+ np.cos(s2p2e2-s1p2e2)+ np.cos(s2p3e2-s1p3e2)+ np.cos(s2p1e2-s12p1e2)+ np.cos(s2p2e2-s12p2e2)+ np.cos(s2p3e2-s12p3e2)+ np.cos(s2p1e2-s3p1e2)+ np.cos(s2p2e2-s3p2e2)+ np.cos(s2p3e2-s3p3e2)+ np.cos(s2p1e2-s42p1e2)+ np.cos(s2p2e2-s42p2e2)+ np.cos(s2p3e2-s42p3e2)

    r1 = prob(H22)/prob(H2)
    x1 = np.random.choice([random.uniform(0, 1)])
    if r1 >= x1:
        s2p1n = s2p1e2
        s2p2n = s2p2e2
        s2p3n = s2p3e2
        
        s2p1 = s2p1e2
        s2p2 = s2p2e2
        s2p3 = s2p3e2
        
    else:
        s2p1n = s2p1
        s2p2n = s2p2
        s2p3n = s2p3
        
    if s2p1n>=s2p2n>=s2p3n:
        s2= -1
    if s2p2n>=s2p1n>=s2p3n:    
        s2=1
    if s2p3n>=s2p2n>=s2p1n:   
        s2=1
    if s2p3n>=s2p1n>=s2p2n:    
        s2= -1     
    if s2p1n>=s2p3n>=s2p2n:
        s2=1    
    if s2p2n>=s2p3n>=s2p1n:    
        s2= -1    
    s.append(s2) 
    s2p1e2 = s2p1
    s2p2e2 = s2p2
    s2p3e2 = s2p3
    
    s3p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site3    
    H3 = -np.cos(s3p2-s3p3)- np.cos(s3p3-s3p1)- np.cos(s3p1-s3p2)+ np.cos(s3p1-s2p1)+ np.cos(s3p2-s2p2)+ np.cos(s3p3-s2p3)+ np.cos(s3p1-s13p1)+ np.cos(s3p2-s13p2)+ np.cos(s3p3-s13p3)+ np.cos(s3p1-s4p1)+ np.cos(s3p2-s4p2)+ np.cos(s3p3-s4p3)+ np.cos(s3p1-s43p1)+ np.cos(s3p2-s43p2)+ np.cos(s3p3-s43p3)

    H32 = - np.cos(s3p2e2-s3p3e2)- np.cos(s3p3e2-s3p1e2)- np.cos(s3p1e2-s3p2e2)+ np.cos(s3p1e2-s2p1e2)+ np.cos(s3p2e2-s2p2e2)+ np.cos(s3p3e2-s2p3e2)+ np.cos(s3p1e2-s13p1e2)+ np.cos(s3p2e2-s13p2e2)+ np.cos(s3p3e2-s13p3e2)+ np.cos(s3p1e2-s4p1e2)+ np.cos(s3p2e2-s4p2e2)+ np.cos(s3p3e2-s4p3e2)+ np.cos(s3p1e2-s43p1e2)+ np.cos(s3p2e2-s43p2e2)+ np.cos(s3p3e2-s43p3e2)
  
    r2 = prob(H32)/prob(H3)
    x2 = np.random.choice([random.uniform(0, 1)])
    if r2 >= x2:
        s3p1n = s3p1e2
        s3p2n = s3p2e2
        s3p3n = s3p3e2
        
        s3p1 = s3p1e2
        s3p2 = s3p2e2
        s3p3 = s3p3e2
    else:
        s3p1n = s3p1
        s3p2n = s3p2
        s3p3n = s3p3
    if s3p1n>=s3p2n>=s3p3n:
        s3= -1
    if s3p2n>=s3p1n>=s3p3n:    
        s3=1
    if s3p3n>=s3p2n>=s3p1n:   
        s3=1
    if s3p3n>=s3p1n>=s3p2n:    
        s3= -1     
    if s3p1n>=s3p3n>=s3p2n:
        s3=1    
    if s3p2n>=s3p3n>=s3p1n:    
        s3= -1  
    s.append(s3)    
    s3p1e2 = s3p1
    s3p2e2 = s3p2
    s3p3e2 = s3p3
    
    s4p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site4    
    H4 = - np.cos(s4p2-s4p3)- np.cos(s4p3-s4p1)- np.cos(s4p1-s4p2)+ np.cos(s4p1-s3p1)+ np.cos(s4p2-s3p2)+ np.cos(s4p3-s3p3)+ np.cos(s4p1-s14p1)+ np.cos(s4p2-s14p2)+ np.cos(s4p3-s14p3)+ np.cos(s4p1-s5p1)+ np.cos(s4p2-s5p2)+ np.cos(s4p3-s5p3)+ np.cos(s4p1-s44p1)+ np.cos(s4p2-s44p2)+ np.cos(s4p3-s44p3)

    H42 = - np.cos(s4p3e2-s4p1e2)- np.cos(s4p2e2-s3p3e2)- np.cos(s4p1e2-s4p2e2)+ np.cos(s4p1e2-s3p1e2)+ np.cos(s4p2e2-s3p2e2)+ np.cos(s4p3e2-s3p3e2)+ np.cos(s4p1e2-s14p1e2)+ np.cos(s4p2e2-s14p2e2)+ np.cos(s4p3e2-s14p3e2)+ np.cos(s4p1e2-s5p1e2)+ np.cos(s4p2e2-s5p2e2)+ np.cos(s4p3e2-s5p3e2)+ np.cos(s4p1e2-s44p1e2)+ np.cos(s4p2e2-s44p2e2)+ np.cos(s4p3e2-s44p3e2)

    r3 = prob(H42)/prob(H4)
    x3 = np.random.choice([random.uniform(0, 1)])
    if r3 >= x3:
        s4p1n = s4p1e2
        s4p2n = s4p2e2
        s4p3n = s4p3e2
        
        s4p1 = s4p1e2
        s4p2 = s4p2e2
        s4p3 = s4p3e2
    else:
        s4p1n = s4p1
        s4p2n = s4p2
        s4p3n = s4p3
    if s4p1n>=s4p2n>=s4p3n:
        s4= -1
    if s4p2n>=s4p1n>=s4p3n:    
        s4=1
    if s4p3n>=s4p2n>=s4p1n:   
        s4=1
    if s4p3n>=s4p1n>=s4p2n:    
        s4= -1     
    if s4p1n>=s4p3n>=s4p2n:
        s4=1    
    if s4p2n>=s4p3n>=s4p1n:    
        s4= -1    
    s.append(s4)
    s4p1e2 = s4p1
    s4p2e2 = s4p2
    s4p3e2 = s4p3
    
    s5p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site5    
    H5 =- np.cos(s5p2-s5p3)- np.cos(s5p3-s5p1)- np.cos(s5p1-s5p2)+ np.cos(s5p1-s4p1)+ np.cos(s5p2-s4p2)+ np.cos(s5p3-s4p3)+ np.cos(s5p1-s15p1)+ np.cos(s5p2-s15p2)+ np.cos(s5p3-s15p3)+ np.cos(s5p1-s45p1)+ np.cos(s5p2-s45p2)+ np.cos(s5p3-s45p3)+ np.cos(s5p1-s1p1)+ np.cos(s5p2-s1p2)+ np.cos(s5p3-s1p3)

    H52 = - np.cos(s5p3e2-s5p1e2)- np.cos(s5p2e2-s5p3e2)- np.cos(s5p1e2-s5p2e2)+ np.cos(s5p1e2-s4p1e2)+ np.cos(s5p2e2-s4p2e2)+ np.cos(s5p3e2-s4p3e2)+ np.cos(s5p1e2-s15p1e2)+ np.cos(s5p2e2-s15p2e2)+ np.cos(s5p3e2-s15p3e2)+ np.cos(s5p1e2-s45p1e2)+ np.cos(s5p2e2-s45p2e2)+ np.cos(s5p3e2-s45p3e2)+ np.cos(s5p1e2-s1p1e2)+ np.cos(s5p2e2-s1p2e2)+ np.cos(s5p3e2-s1p3e2)

    r4 = prob(H52)/prob(H5)
    x4 = np.random.choice([random.uniform(0, 1)])
    if r4 >= x4:
        s5p1n = s5p1e2
        s5p2n = s5p2e2
        s5p3n = s5p3e2
        
        s5p1 = s5p1e2
        s5p2 = s5p2e2
        s5p3 = s5p3e2
    else:
        s5p1n = s5p1
        s5p2n = s5p2
        s5p3n = s5p3
    if s5p1n>=s5p2n>=s5p3n:
        s5= -1
    if s5p2n>=s5p1n>=s5p3n:    
        s5=1
    if s5p3n>=s5p2n>=s5p1n:   
        s5=1
    if s5p3n>=s5p1n>=s5p2n:    
        s5= -1     
    if s5p1n>=s5p3n>=s5p2n:
        s5=1    
    if s5p2n>=s5p3n>=s5p1n:    
        s5= -1   
    s.append(s5)            
    s5p1e2 = s5p1
    s5p2e2 = s5p2
    s5p3e2 = s5p3
    
    s11p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site11    
    H11 =- np.cos(s11p3-s11p1)- np.cos(s11p2-s11p3)- np.cos(s11p1-s11p2)+ np.cos(s11p1-s1p1)+ np.cos(s11p2-s1p2)+ np.cos(s11p3-s1p3)+ np.cos(s11p1-s12p1)+ np.cos(s11p2-s12p2)+ np.cos(s11p3-s12p3)+ np.cos(s11p1-s21p1)+ np.cos(s11p2-s21p2)+ np.cos(s11p3-s21p3)+ np.cos(s11p1-s15p1)+ np.cos(s11p2-s15p2)+ np.cos(s11p3-s15p3)

    H112 =- np.cos(s11p3e2-s11p1e2)- np.cos(s11p2e2-s11p3e2)- np.cos(s11p1e2-s11p2e2)+ np.cos(s11p1e2-s1p1e2)+ np.cos(s11p2e2-s1p2e2)+ np.cos(s11p3e2-s1p3e2)+ np.cos(s11p1e2-s12p1e2)+ np.cos(s11p2e2-s12p2e2)+ np.cos(s11p3e2-s12p3e2)+ np.cos(s11p1e2-s21p1e2)+ np.cos(s11p2e2-s21p2e2)+ np.cos(s11p3e2-s21p3e2)+ np.cos(s11p1e2-s15p1e2)+ np.cos(s11p2e2-s15p2e2)+ np.cos(s11p3e2-s15p3e2)

    r11 = prob(H112)/prob(H11)
    x11 = np.random.choice([random.uniform(0, 1)])
    if r11 >= x11:
        s11p1n = s11p1e2
        s11p2n = s11p2e2
        s11p3n = s11p3e2
        
        s11p1 = s11p1e2
        s11p2 = s11p2e2
        s11p3 = s11p3e2
        
    else:
        s11p1n = s11p1
        s11p2n = s11p2
        s11p3n = s11p3
    if s11p1n>=s11p2n>=s11p3n:
        s11= -1
    if s11p2n>=s11p1n>=s11p3n:    
        s11=1
    if s11p3n>=s11p2n>=s11p1n:   
        s11=1
    if s11p3n>=s11p1n>=s11p2n:    
        s11= -1     
    if s11p1n>=s11p3n>=s11p2n:
        s11=1    
    if s11p2n>=s11p3n>=s11p1n:    
        s11= -1   
    s.append(s11)            
    s11p1e2 = s11p1
    s11p2e2 = s11p2
    s11p3e2 = s11p3
    
    s12p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site12    
    H12s =- np.cos(s12p3-s12p1)- np.cos(s12p2-s12p3)- np.cos(s12p1-s12p2)+ np.cos(s12p1-s2p1)+ np.cos(s12p2-s2p2)+ np.cos(s12p3-s2p3)+ np.cos(s12p1-s13p1)+ np.cos(s12p2-s13p2)+ np.cos(s12p3-s13p3)+ np.cos(s12p1-s22p1)+ np.cos(s12p2-s22p2)+ np.cos(s12p3-s22p3)+ np.cos(s12p1-s11p1)+ np.cos(s12p2-s11p2)+ np.cos(s12p3-s11p3)

    H122 =- np.cos(s12p3e2-s12p1e2)- np.cos(s12p2e2-s12p3e2)- np.cos(s12p1e2-s12p2e2)+ np.cos(s12p1e2-s2p1e2)+ np.cos(s12p2e2-s2p2e2)+ np.cos(s12p3e2-s2p3e2)+ np.cos(s12p1e2-s13p1e2)+ np.cos(s12p2e2-s13p2e2)+ np.cos(s12p3e2-s13p3e2)+ np.cos(s12p1e2-s22p1e2)+ np.cos(s12p2e2-s22p2e2)+ np.cos(s12p3e2-s22p3e2)+ np.cos(s12p1e2-s11p1e2)+ np.cos(s12p2e2-s11p2e2)+ np.cos(s12p3e2-s11p3e2)

    r12 = prob(H122)/prob(H12s)
    x12 = np.random.choice([random.uniform(0, 1)])
    if r12 >= x12:
        s12p1n = s12p1e2
        s12p2n = s12p2e2
        s12p3n = s12p3e2
        
        s12p1 = s12p1e2
        s12p2 = s12p2e2
        s12p3 = s12p3e2
        
    else:
        s12p1n = s12p1
        s12p2n = s12p2
        s12p3n = s12p3
    if s12p1n>=s12p2n>=s12p3n:
        s12= -1
    if s12p2n>=s12p1n>=s12p3n:    
        s12=1
    if s12p3n>=s12p2n>=s12p1n:   
        s12=1
    if s12p3n>=s12p1n>=s12p2n:    
        s12= -1     
    if s12p1n>=s12p3n>=s12p2n:
        s12=1    
    if s12p2n>=s12p3n>=s12p1n:    
        s12= -1    
    s.append(s12)      
    s12p1e2 = s12p1
    s12p2e2 = s12p2
    s12p3e2 = s12p3
    
    s13p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site13    
    H13 =- np.cos(s13p3-s13p1)- np.cos(s13p2-s13p3)- np.cos(s13p1-s13p2)+ np.cos(s13p1-s3p1)+ np.cos(s13p2-s3p2)+ np.cos(s13p3-s3p3)+ np.cos(s13p1-s14p1)+ np.cos(s13p2-s14p2)+ np.cos(s13p3-s14p3)+ np.cos(s13p1-s23p1)+ np.cos(s13p2-s23p2)+ np.cos(s13p3-s23p3)+ np.cos(s13p1-s12p1)+ np.cos(s13p2-s12p2)+ np.cos(s13p3-s12p3)

    H132 =- np.cos(s13p3e2-s13p1e2)- np.cos(s13p2e2-s13p3e2)- np.cos(s13p1e2-s13p2e2)+ np.cos(s13p1e2-s3p1e2)+ np.cos(s13p2e2-s3p2e2)+ np.cos(s13p3e2-s3p3e2)+ np.cos(s13p1e2-s14p1e2)+ np.cos(s13p2e2-s14p2e2)+ np.cos(s13p3e2-s14p3e2)+ np.cos(s13p1e2-s23p1e2)+ np.cos(s13p2e2-s23p2e2)+ np.cos(s13p3e2-s23p3e2)+ np.cos(s13p1e2-s12p1e2)+ np.cos(s13p2e2-s12p2e2)+ np.cos(s13p3e2-s12p3e2)

    r13 = prob(H132)/prob(H13)
    x13 = np.random.choice([random.uniform(0, 1)])
    if r13 >= x13:
        s13p1n = s13p1e2
        s13p2n = s13p2e2
        s13p3n = s13p3e2
        
        s13p1 = s13p1e2
        s13p2 = s13p2e2
        s13p3 = s13p3e2
        
    else:
        s13p1n = s13p1
        s13p2n = s13p2
        s13p3n = s13p3
    if s13p1n>=s13p2n>=s13p3n:
        s13= -1
    if s13p2n>=s13p1n>=s13p3n:    
        s13=1
    if s13p3n>=s13p2n>=s13p1n:   
        s13=1
    if s13p3n>=s13p1n>=s13p2n:    
        s13= -1     
    if s13p1n>=s13p3n>=s13p2n:
        s13=1    
    if s13p2n>=s13p3n>=s13p1n:    
        s13= -1  
    s.append(s13)    
    s13p1e2 = s13p1
    s13p2e2 = s13p2
    s13p3e2 = s13p3
    
    s14p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site14    
    H14 =- np.cos(s14p3-s14p1)- np.cos(s14p2-s14p3)- np.cos(s14p1-s14p2)+ np.cos(s14p1-s4p1)+ np.cos(s14p2-s4p2)+ np.cos(s14p3-s4p3)+ np.cos(s14p1-s15p1)+ np.cos(s14p2-s15p2)+ np.cos(s14p3-s15p3)+ np.cos(s14p1-s24p1)+ np.cos(s14p2-s24p2)+ np.cos(s14p3-s24p3)+ np.cos(s14p1-s13p1)+ np.cos(s14p2-s13p2)+ np.cos(s14p3-s13p3)

    H142 =- np.cos(s14p3e2-s14p1e2)- np.cos(s14p2e2-s14p3e2)- np.cos(s14p1e2-s14p2e2)+ np.cos(s14p1e2-s4p1e2)+ np.cos(s14p2e2-s4p2e2)+ np.cos(s14p3e2-s4p3e2)+ np.cos(s14p1e2-s15p1e2)+ np.cos(s14p2e2-s15p2e2)+ np.cos(s14p3e2-s15p3e2)+ np.cos(s14p1e2-s24p1e2)+ np.cos(s14p2e2-s24p2e2)+ np.cos(s14p3e2-s24p3e2)+ np.cos(s14p1e2-s13p1e2)+ np.cos(s14p2e2-s13p2e2)+ np.cos(s14p3e2-s13p3e2)

    r14 = prob(H142)/prob(H14)
    x14 = np.random.choice([random.uniform(0, 1)])
    if r14 >= x14:
        s14p1n = s14p1e2
        s14p2n = s14p2e2
        s14p3n = s14p3e2
        
        s14p1 = s14p1e2
        s14p2 = s14p2e2
        s14p3 = s14p3e2
        
    else:
        s14p1n = s14p1
        s14p2n = s14p2
        s14p3n = s14p3
    if s14p1n>=s14p2n>=s14p3n:
        s14= -1
    if s14p2n>=s14p1n>=s14p3n:    
        s14=1
    if s14p3n>=s14p2n>=s14p1n:   
        s14=1
    if s14p3n>=s14p1n>=s14p2n:    
        s14= -1     
    if s14p1n>=s14p3n>=s14p2n:
        s14=1    
    if s14p2n>=s14p3n>=s14p1n:    
        s14= -1  
    s.append(s14)
    s14p1e2 = s14p1
    s14p2e2 = s14p2
    s14p3e2 = s14p3

    s15p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])                  
#site15    
    H15 =- np.cos(s15p3-s15p1)- np.cos(s15p2-s15p3)- np.cos(s15p1-s15p2)+ np.cos(s15p1-s5p1)+ np.cos(s15p2-s5p2)+ np.cos(s15p3-s5p3)+ np.cos(s15p1-s25p1)+ np.cos(s15p2-s25p2)+ np.cos(s15p3-s25p3)+ np.cos(s15p1-s14p1)+ np.cos(s15p2-s14p2)+ np.cos(s15p3-s14p3)+ np.cos(s15p1-s11p1)+ np.cos(s15p2-s11p2)+ np.cos(s15p3-s11p3)

    H152 =- np.cos(s15p3e2-s15p1e2)- np.cos(s15p2e2-s15p3e2)- np.cos(s15p1e2-s15p2e2)+ np.cos(s15p1e2-s5p1e2)+ np.cos(s15p2e2-s5p2e2)+ np.cos(s15p3e2-s5p3e2)+ np.cos(s15p1e2-s25p1e2)+ np.cos(s15p2e2-s25p2e2)+ np.cos(s15p3e2-s25p3e2)+ np.cos(s15p1e2-s14p1e2)+ np.cos(s15p2e2-s14p2e2)+ np.cos(s15p3e2-s14p3e2)+ np.cos(s15p1e2-s11p1e2)+ np.cos(s15p2e2-s11p2e2)+ np.cos(s15p3e2-s11p3e2)

    r15 = prob(H152)/prob(H15)
    x15 = np.random.choice([random.uniform(0, 1)])
    if r15 >= x15:
        s15p1n = s15p1e2
        s15p2n = s15p2e2
        s15p3n = s15p3e2
        
        s15p1 = s15p1e2
        s15p2 = s15p2e2
        s15p3 = s15p3e2
    else:
        s15p1n = s15p1
        s15p2n = s15p2
        s15p3n = s15p3
    if s15p1n>=s15p2n>=s15p3n:
        s15= -1
    if s15p2n>=s15p1n>=s15p3n:    
        s15=1
    if s15p3n>=s15p2n>=s15p1n:   
        s15=1
    if s15p3n>=s15p1n>=s15p2n:    
        s15= -1     
    if s15p1n>=s15p3n>=s15p2n:
        s15=1    
    if s15p2n>=s15p3n>=s15p1n:    
        s15= -1    
    s.append(s15) 
    s15p1e2 = s15p1
    s15p2e2 = s15p2
    s15p3e2 = s15p3

    s21p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
#site21    
    H21 =- np.cos(s21p3-s21p1)- np.cos(s21p2-s21p3)- np.cos(s21p1-s21p2)+ np.cos(s21p1-s11p1)+ np.cos(s21p2-s11p2)+ np.cos(s21p3-s11p3)+ np.cos(s21p1-s31p1)+ np.cos(s21p2-s31p2)+ np.cos(s21p3-s31p3)+ np.cos(s21p1-s22p1)+ np.cos(s21p2-s22p2)+ np.cos(s21p3-s22p3)+ np.cos(s21p1-s25p1)+ np.cos(s21p2-s25p2)+ np.cos(s21p3-s25p3)

    H212 =- np.cos(s21p3e2-s21p1e2)- np.cos(s21p2e2-s21p3e2)- np.cos(s21p1e2-s21p2e2)+ np.cos(s21p1e2-s11p1e2)+ np.cos(s21p2e2-s11p2e2)+ np.cos(s21p3e2-s11p3e2)+ np.cos(s21p1e2-s31p1e2)+ np.cos(s21p2e2-s31p2e2)+ np.cos(s21p3e2-s31p3e2)+ np.cos(s21p1e2-s22p1e2)+ np.cos(s21p2e2-s22p2e2)+ np.cos(s21p3e2-s22p3e2)+ np.cos(s21p1e2-s25p1e2)+ np.cos(s21p2e2-s25p2e2)+ np.cos(s21p3e2-s25p3e2)

    r21 = prob(H212)/prob(H21)
    x21 = np.random.choice([random.uniform(0, 1)])
    if r21 >= x21:
        s21p1n = s21p1e2
        s21p2n = s21p2e2
        s21p3n = s21p3e2
        
        s21p1 = s21p1e2
        s21p2 = s21p2e2
        s21p3 = s21p3e2
  
    else:
        s21p1n = s21p1
        s21p2n = s21p2
        s21p3n = s21p3
    if s21p1n>=s21p2n>=s21p3n:
        s21= -1
    if s21p2n>=s21p1n>=s21p3n:    
        s21=1
    if s21p3n>=s21p2n>=s21p1n:   
        s21=1
    if s21p3n>=s21p1n>=s21p2n:    
        s21= -1     
    if s21p1n>=s21p3n>=s21p2n:
        s21=1    
    if s21p2n>=s21p3n>=s21p1n:    
        s21= -1
    s.append(s21)
    s21p1e2 = s21p1
    s21p2e2 = s21p2
    s21p3e2 = s22p3   

    s22p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])            
#site22    
    H22 =- np.cos(s22p3-s22p1)- np.cos(s22p2-s22p3)- np.cos(s22p1-s22p2)+ np.cos(s22p1-s12p1)+ np.cos(s22p2-s12p2)+ np.cos(s22p3-s12p3)+ np.cos(s22p1-s32p1)+ np.cos(s22p2-s32p2)+ np.cos(s22p3-s32p3)+ np.cos(s22p1-s23p1)+ np.cos(s22p2-s23p2)+ np.cos(s22p3-s23p3)+ np.cos(s22p1-s21p1)+ np.cos(s22p2-s21p2)+ np.cos(s22p3-s21p3)

    H222 =- np.cos(s22p3e2-s22p1e2)- np.cos(s22p2e2-s22p3e2)- np.cos(s22p1e2-s22p2e2)+ np.cos(s22p1e2-s12p1e2)+ np.cos(s22p2e2-s12p2e2)+ np.cos(s22p3e2-s12p3e2)+ np.cos(s22p1e2-s32p1e2)+ np.cos(s22p2e2-s32p2e2)+ np.cos(s22p3e2-s32p3e2)+ np.cos(s22p1e2-s23p1e2)+ np.cos(s22p2e2-s23p2e2)+ np.cos(s22p3e2-s23p3e2)+ np.cos(s22p1e2-s21p1e2)+ np.cos(s22p2e2-s21p2e2)+ np.cos(s22p3e2-s21p3e2)

    r22 = prob(H222)/prob(H22)
    x22 = np.random.choice([random.uniform(0, 1)])
    if r22 >= x22:
        s22p1n = s22p1e2
        s22p2n = s22p2e2
        s22p3n = s22p3e2
        
        s22p1 = s22p1e2
        s22p2 = s22p2e2
        s22p3 = s22p3e2
        
    else:
        s22p1n = s22p1
        s22p2n = s22p2
        s22p3n = s22p3
    if s22p1n>=s22p2n>=s22p3n:
        s22= -1
    if s22p2n>=s22p1n>=s22p3n:    
        s22=1
    if s22p3n>=s22p2n>=s22p1n:   
        s22=1
    if s22p3n>=s22p1n>=s22p2n:    
        s22= -1     
    if s22p1n>=s22p3n>=s22p2n:
        s22=1    
    if s22p2n>=s22p3n>=s22p1n:    
        s22= -1    
    s.append(s22)    
    s22p1e2 = s22p1
    s22p2e2 = s22p2
    s22p3e2 = s22p3  
    
    s23p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])   
#site23    
    H23 =- np.cos(s23p3-s23p1)- np.cos(s23p2-s23p3)- np.cos(s23p1-s23p2)+ np.cos(s23p1-s13p1)+ np.cos(s23p2-s13p2)+ np.cos(s23p3-s13p3)+ np.cos(s23p1-s33p1)+ np.cos(s23p2-s33p2)+ np.cos(s23p3-s33p3)+ np.cos(s23p1-s24p1)+ np.cos(s23p2-s24p2)+ np.cos(s23p3-s24p3)+ np.cos(s23p1-s22p1)+ np.cos(s23p2-s22p2)+ np.cos(s23p3-s22p3)

    H232 =- np.cos(s23p3e2-s23p1e2)- np.cos(s23p2e2-s23p3e2)- np.cos(s23p1e2-s23p2e2)+ np.cos(s23p1e2-s13p1e2)+ np.cos(s23p2e2-s13p2e2)+ np.cos(s23p3e2-s13p3e2)+ np.cos(s23p1e2-s33p1e2)+ np.cos(s23p2e2-s33p2e2)+ np.cos(s23p3e2-s33p3e2)+ np.cos(s23p1e2-s24p1e2)+ np.cos(s23p2e2-s24p2e2)+ np.cos(s23p3e2-s24p3e2)+ np.cos(s23p1e2-s22p1e2)+ np.cos(s23p2e2-s22p2e2)+ np.cos(s23p3e2-s22p3e2)

    r23 = prob(H232)/prob(H23)
    x23 = np.random.choice([random.uniform(0, 1)])
    if r23>=x23:
        s23p1n = s23p1e2
        s23p2n = s23p2e2
        s23p3n = s23p3e2
        
        s23p1 = s23p1e2
        s23p2 = s23p2e2
        s23p3 = s23p3e2

    else:
        s23p1n = s23p1
        s23p2n = s23p2
        s23p3n = s23p3
    if s23p1n>=s23p2n>=s23p3n:
        s23= -1
    if s23p2n>=s23p1n>=s23p3n:    
        s23=1
    if s23p3n>=s23p2n>=s23p1n:   
        s23=1
    if s23p3n>=s23p1n>=s23p2n:    
        s23= -1     
    if s23p1n>=s23p3n>=s23p2n:
        s23=1    
    if s23p2n>=s23p3n>=s23p1n:    
        s23= -1  
    s.append(s23)    
    s23p1e2 = s23p1
    s23p2e2 = s23p2
    s23p3e2 = s23p3
    
    s24p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])           
#site24    
    H24 =- np.cos(s24p3-s24p1)- np.cos(s24p2-s24p3)- np.cos(s24p1-s24p2)+ np.cos(s24p1-s14p1)+ np.cos(s24p2-s14p2)+ np.cos(s24p3-s14p3)+ np.cos(s24p1-s34p1)+ np.cos(s24p2-s34p2)+ np.cos(s24p3-s34p3)+ np.cos(s24p1-s25p1)+ np.cos(s24p2-s25p2)+ np.cos(s24p3-s25p3)+ np.cos(s24p1-s23p1)+ np.cos(s24p2-s23p2)+ np.cos(s24p3-s23p3)

    H242 =- np.cos(s24p3e2-s24p1e2)- np.cos(s24p2e2-s24p3e2)- np.cos(s24p1e2-s24p2e2)+ np.cos(s24p1e2-s14p1e2)+ np.cos(s24p2e2-s14p2e2)+ np.cos(s24p3e2-s14p3e2)+ np.cos(s24p1e2-s34p1e2)+ np.cos(s24p2e2-s34p2e2)+ np.cos(s24p3e2-s34p3e2)+ np.cos(s24p1e2-s25p1e2)+ np.cos(s24p2e2-s25p2e2)+ np.cos(s24p3e2-s25p3e2)+ np.cos(s24p1e2-s23p1e2)+ np.cos(s24p2e2-s23p2e2)+ np.cos(s24p3e2-s23p3e2)

    r24 = prob(H242)/prob(H24)
    x24 = np.random.choice([random.uniform(0, 1)])
    if r24>=x24:
        s24p1n = s24p1e2
        s24p2n = s24p2e2
        s24p3n = s24p3e2
        
        s24p1 = s24p1e2
        s24p2 = s24p2e2
        s24p3 = s24p3e2

    else:
        s24p1n = s24p1
        s24p2n = s24p2
        s24p3n = s24p3 
    if s24p1n>=s24p2n>=s24p3n:
        s24= -1
    if s24p2n>=s24p1n>=s24p3n:    
        s24=1
    if s24p3n>=s24p2n>=s24p1n:   
        s24=1
    if s24p3n>=s24p1n>=s24p2n:    
        s24= -1     
    if s24p1n>=s24p3n>=s24p2n:
        s24=1    
    if s24p2n>=s24p3n>=s24p1n:    
        s24= -1  
    s.append(s24)            
    s24p1e2 = s24p1
    s24p2e2 = s24p2
    s24p3e2 = s24p3 
    
    s25p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
#site25    
    H25 =- np.cos(s25p3-s25p1)- np.cos(s25p2-s25p3)- np.cos(s25p1-s25p2)+ np.cos(s25p1-s15p1)+ np.cos(s25p2-s15p2)+ np.cos(s25p3-s15p3)+ np.cos(s25p1-s35p1)+ np.cos(s25p2-s35p2)+ np.cos(s25p3-s35p3)+ np.cos(s25p1-s24p1)+ np.cos(s25p2-s24p2)+ np.cos(s25p3-s24p3)+ np.cos(s25p1-s21p1)+ np.cos(s25p2-s21p2)+ np.cos(s25p3-s21p3)

    H252 =- np.cos(s25p3e2-s25p1e2)- np.cos(s25p2e2-s25p3e2)- np.cos(s25p1e2-s25p2e2)+ np.cos(s25p1e2-s15p1e2)+ np.cos(s25p2e2-s15p2e2)+ np.cos(s25p3e2-s15p3e2)+ np.cos(s25p1e2-s35p1e2)+ np.cos(s25p2e2-s35p2e2)+ np.cos(s25p3e2-s35p3e2)+ np.cos(s25p1e2-s24p1e2)+ np.cos(s25p2e2-s24p2e2)+ np.cos(s25p3e2-s24p3e2)+ np.cos(s25p1e2-s21p1e2)+ np.cos(s25p2e2-s21p2e2)+ np.cos(s25p3e2-s21p3e2)

    r25 = prob(H252)/prob(H25)
    x25 = np.random.choice([random.uniform(0, 1)])
    if r25>=x25:
        s25p1n = s25p1e2
        s25p2n = s25p2e2
        s25p3n = s25p3e2
        
        s25p1 = s25p1e2
        s25p2 = s25p2e2
        s25p3 = s25p3e2

    else:
        s25p1n = s25p1
        s25p2n = s25p2
        s25p3n = s25p3
    if s25p1n>=s25p2n>=s25p3n:
        s25= -1
    if s25p2n>=s25p1n>=s25p3n:    
        s25=1
    if s25p3n>=s25p2n>=s25p1n:   
        s25=1
    if s25p3n>=s25p1n>=s25p2n:    
        s25= -1     
    if s25p1n>=s25p3n>=s25p2n:
        s25=1    
    if s25p2n>=s25p3n>=s25p1n:    
        s25= -1 
    s.append(s25)    
    s25p1e2 = s25p1
    s25p2e2 = s25p2
    s25p3e2 = s25p3

    s31p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 

#site31    
    H31 =- np.cos(s31p3-s31p1)- np.cos(s31p2-s31p3)- np.cos(s31p1-s31p2)+ np.cos(s31p1-s21p1)+ np.cos(s31p2-s21p2)+ np.cos(s31p3-s21p3)+ np.cos(s31p1-s41p1)+ np.cos(s31p2-s41p2)+ np.cos(s31p3-s41p3)+ np.cos(s31p1-s32p1)+ np.cos(s31p2-s32p2)+ np.cos(s31p3-s32p3)+ np.cos(s31p1-s35p1)+ np.cos(s31p2-s35p2)+ np.cos(s31p3-s35p3)

    H312 =- np.cos(s31p3e2-s31p1e2)- np.cos(s31p2e2-s31p3e2)- np.cos(s31p1e2-s31p2e2)+ np.cos(s31p1e2-s21p1e2)+ np.cos(s31p2e2-s21p2e2)+ np.cos(s31p3e2-s21p3e2)+ np.cos(s31p1e2-s41p1e2)+ np.cos(s31p2e2-s41p2e2)+ np.cos(s31p3e2-s41p3e2)+ np.cos(s31p1e2-s32p1e2)+ np.cos(s31p2e2-s32p2e2)+ np.cos(s31p3e2-s32p3e2)+ np.cos(s31p1e2-s35p1e2)+ np.cos(s31p2e2-s35p2e2)+ np.cos(s31p3e2-s35p3e2)

    r31 = prob(H312)/prob(H31)
    x31 = np.random.choice([random.uniform(0, 1)])
    if r31>=x31:
        s31p1n = s31p1e2
        s31p2n = s31p2e2
        s31p3n = s31p3e2

        s31p1 = s31p1e2
        s31p2 = s31p2e2
        s31p3 = s31p3e2
    else:
        s31p1n = s31p1
        s31p2n = s31p2
        s31p3n = s31p3
    if s31p1n>=s31p2n>=s31p3n:
        s31= -1
    if s31p2n>=s31p1n>=s31p3n:    
        s31=1
    if s31p3n>=s31p2n>=s31p1n:   
        s31=1
    if s31p3n>=s31p1n>=s31p2n:    
        s31= -1     
    if s31p1n>=s31p3n>=s31p2n:
        s31=1    
    if s31p2n>=s31p3n>=s31p1n:    
        s31= -1
    s.append(s31)  
    s31p1e2 = s31p1
    s31p2e2 = s31p2
    s31p3e2 = s31p3
    
    s32p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
    
#site32    
    H32 =- np.cos(s32p3-s32p1)- np.cos(s32p2-s32p3)- np.cos(s32p1-s32p2)+ np.cos(s32p1-s22p1)+ np.cos(s32p2-s22p2)+ np.cos(s32p3-s22p3)+ np.cos(s32p1-s42p1)+ np.cos(s32p2-s42p2)+ np.cos(s32p3-s42p3)+ np.cos(s32p1-s33p1)+ np.cos(s32p2-s33p2)+ np.cos(s32p3-s33p3)+ np.cos(s32p1-s31p1)+ np.cos(s32p2-s31p2)+ np.cos(s32p3-s31p3)

    H322 =- np.cos(s32p3e2-s32p1e2)- np.cos(s32p2e2-s32p3e2)- np.cos(s32p1e2-s32p2e2)+ np.cos(s32p1e2-s22p1e2)+ np.cos(s32p2e2-s22p2e2)+ np.cos(s32p3e2-s22p3e2)+ np.cos(s32p1e2-s42p1e2)+ np.cos(s32p2e2-s42p2e2)+ np.cos(s32p3e2-s42p3e2)+ np.cos(s32p1e2-s33p1e2)+ np.cos(s32p2e2-s33p2e2)+ np.cos(s32p3e2-s33p3e2)+ np.cos(s32p1e2-s31p1e2)+ np.cos(s32p2e2-s31p2e2)+ np.cos(s32p3e2-s31p3e2)

    r32 = prob(H322)/prob(H32)
    x32 = np.random.choice([random.uniform(0, 1)])
    if r32>=x32:
        s32p1n = s32p1e2
        s32p2n = s32p2e2
        s32p3n = s32p3e2

        s32p1 = s32p1e2
        s32p2 = s32p2e2
        s32p3 = s32p3e2
    else:
        s32p1n = s32p1
        s32p2n = s32p2
        s32p3n = s32p3
    if s32p1n>=s32p2n>=s32p3n:
        s32= -1
    if s32p2n>=s32p1n>=s32p3n:    
        s32=1
    if s32p3n>=s32p2n>=s32p1n:   
        s32=1
    if s32p3n>=s32p1n>=s32p2n:    
        s32= -1     
    if s32p1n>=s32p3n>=s32p2n:
        s32=1    
    if s32p2n>=s32p3n>=s32p1n:    
        s32= -1    
    s.append(s32)            
    s32p1e2 = s32p1
    s32p2e2 = s32p2
    s32p3e2 = s32p3        
    
    s33p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site33    
    H33 =- np.cos(s33p3-s33p1)- np.cos(s33p2-s33p3)- np.cos(s33p1-s33p2)+ np.cos(s33p1-s23p1)+ np.cos(s33p2-s23p2)+ np.cos(s33p3-s23p3)+ np.cos(s33p1-s43p1)+ np.cos(s33p2-s43p2)+ np.cos(s33p3-s43p3)+ np.cos(s33p1-s34p1)+ np.cos(s33p2-s34p2)+ np.cos(s33p3-s34p3)+ np.cos(s33p1-s32p1)+ np.cos(s33p2-s32p2)+ np.cos(s33p3-s32p3)

    H332 =- np.cos(s33p3e2-s33p1e2)- np.cos(s33p2e2-s33p3e2)- np.cos(s33p1e2-s33p2e2)+ np.cos(s33p1e2-s23p1e2)+ np.cos(s33p2e2-s23p2e2)+ np.cos(s33p3e2-s23p3e2)+ np.cos(s33p1e2-s43p1e2)+ np.cos(s33p2e2-s43p2e2)+ np.cos(s33p3e2-s43p3e2)+ np.cos(s33p1e2-s34p1e2)+ np.cos(s33p2e2-s34p2e2)+ np.cos(s33p3e2-s34p3e2)+ np.cos(s33p1e2-s32p1e2)+ np.cos(s33p2e2-s32p2e2)+ np.cos(s33p3e2-s32p3e2)

    r33 = prob(H332)/prob(H33)
    x33 = np.random.choice([random.uniform(0, 1)])
    if r33>=x33:
        s33p1n = s33p1e2
        s33p2n = s33p2e2
        s33p3n = s33p3e2
        
        s33p1 = s33p1e2
        s33p2 = s33p2e2
        s33p3 = s33p3e2
        
    else:
        s33p1n = s33p1
        s33p2n = s33p2
        s33p3n = s33p3
    if s33p1n>=s33p2n>=s33p3n:
        s33= -1
    if s33p2n>=s33p1n>=s33p3n:    
        s33=1
    if s33p3n>=s33p2n>=s33p1n:   
        s33=1
    if s33p3n>=s33p1n>=s33p2n:    
        s33= -1     
    if s33p1n>=s33p3n>=s33p2n:
        s33=1    
    if s33p2n>=s33p3n>=s33p1n:    
        s33= -1
    s.append(s33)        
    s33p1e2 = s33p1
    s33p2e2 = s33p2
    s33p3e2 = s33p3

    s34p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site34    
    H34 =- np.cos(s34p3-s34p1)- np.cos(s34p2-s34p3)- np.cos(s34p1-s34p2)+ np.cos(s34p1-s24p1)+ np.cos(s34p2-s24p2)+ np.cos(s34p3-s24p3)+ np.cos(s34p1-s44p1)+ np.cos(s34p2-s44p2)+ np.cos(s34p3-s44p3)+ np.cos(s34p1-s35p1)+ np.cos(s34p2-s35p2)+ np.cos(s34p3-s35p3)+ np.cos(s34p1-s33p1)+ np.cos(s34p2-s33p2)+ np.cos(s34p3-s33p3)

    H342 =- np.cos(s34p3e2-s34p1e2)- np.cos(s34p2e2-s34p3e2)- np.cos(s34p1e2-s34p2e2)+ np.cos(s34p1e2-s24p1e2)+ np.cos(s34p2e2-s24p2e2)+ np.cos(s34p3e2-s24p3e2)+ np.cos(s34p1e2-s44p1e2)+ np.cos(s34p2e2-s44p2e2)+ np.cos(s34p3e2-s44p3e2)+ np.cos(s34p1e2-s35p1e2)+ np.cos(s34p2e2-s35p2e2)+ np.cos(s34p3e2-s35p3e2)+ np.cos(s34p1e2-s33p1e2)+ np.cos(s34p2e2-s33p2e2)+ np.cos(s34p3e2-s33p3e2)

    r34 = prob(H342)/prob(H34)
    x34 = np.random.choice([random.uniform(0, 1)])
    if r34>=x34:
        s34p1n = s34p1e2
        s34p2n = s34p2e2
        s34p3n = s34p3e2
        
        s34p1 = s34p1e2
        s34p2 = s34p2e2
        s34p3 = s34p3e2

    else:
        s34p1n = s34p1
        s34p2n = s34p2
        s34p3n = s34p3
    if s34p1n>=s34p2n>=s34p3n:
        s34= -1
    if s34p2n>=s34p1n>=s34p3n:    
        s34=1
    if s34p3n>=s34p2n>=s34p1n:   
        s34=1
    if s34p3n>=s34p1n>=s34p2n:    
        s34= -1     
    if s34p1n>=s34p3n>=s34p2n:
        s34=1    
    if s34p2n>=s34p3n>=s34p1n:    
        s34= -1    
    s.append(s34)        
    s34p1e2 = s34p1
    s34p2e2 = s34p2
    s34p3e2 = s34p3

    s35p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site35    
    H35 =- np.cos(s35p3-s35p1)- np.cos(s35p2-s35p3)- np.cos(s35p1-s35p2)+ np.cos(s35p1-s25p1)+ np.cos(s35p2-s25p2)+ np.cos(s35p3-s25p3)+ np.cos(s35p1-s45p1)+ np.cos(s35p2-s45p2)+ np.cos(s35p3-s45p3)+ np.cos(s35p1-s34p1)+ np.cos(s35p2-s34p2)+ np.cos(s35p3-s34p3)+ np.cos(s35p1-s31p1)+ np.cos(s35p2-s31p2)+ np.cos(s35p3-s31p3)

    H352 =- np.cos(s35p3e2-s35p1e2)- np.cos(s35p2e2-s35p3e2)- np.cos(s35p1e2-s35p2e2)+ np.cos(s35p1e2-s25p1e2)+ np.cos(s35p2e2-s25p2e2)+ np.cos(s35p3e2-s25p3e2)+ np.cos(s35p1e2-s45p1e2)+ np.cos(s35p2e2-s45p2e2)+ np.cos(s35p3e2-s45p3e2)+ np.cos(s35p1e2-s34p1e2)+ np.cos(s35p2e2-s34p2e2)+ np.cos(s35p3e2-s34p3e2)+ np.cos(s35p1e2-s31p1e2)+ np.cos(s35p2e2-s31p2e2)+ np.cos(s35p3e2-s31p3e2)

    r35 = prob(H352)/prob(H35)
    x35 = np.random.choice([random.uniform(0, 1)])
    if r35>=x35:
        s35p1n = s35p1e2
        s35p2n = s35p2e2
        s35p3n = s35p3e2
        
        s35p1 = s35p1e2
        s35p2 = s35p2e2
        s35p3 = s35p3e2

    else:
        s35p1n = s35p1
        s35p2n = s35p2
        s35p3n = s35p3
    if s35p1n>=s35p2n>=s35p3n:
        s35= -1
    if s35p2n>=s35p1n>=s35p3n:    
        s35=1
    if s35p3n>=s35p2n>=s35p1n:   
        s35=1
    if s35p3n>=s35p1n>=s35p2n:    
        s35= -1     
    if s35p1n>=s35p3n>=s35p2n:
        s35=1    
    if s35p2n>=s35p3n>=s35p1n:    
        s35= -1    
    s.append(s35)    
    s35p1e2 = s35p1
    s35p2e2 = s35p2
    s35p3e2 = s35p3

    s41p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site41    
    H41 =- np.cos(s41p3-s41p1)- np.cos(s41p2-s41p3)- np.cos(s41p1-s41p2)+ np.cos(s41p1-s31p1)+ np.cos(s41p2-s31p2)+ np.cos(s41p3-s31p3)+ np.cos(s41p1-s1p1)+ np.cos(s41p2-s1p2)+ np.cos(s41p3-s1p3)+ np.cos(s41p1-s42p1)+ np.cos(s41p2-s42p2)+ np.cos(s41p3-s42p3)+ np.cos(s41p1-s45p1)+ np.cos(s41p2-s45p2)+ np.cos(s41p3-s45p3)

    H412 =- np.cos(s41p3e2-s41p1e2)- np.cos(s41p2e2-s41p3e2)- np.cos(s41p1e2-s41p2e2)+ np.cos(s41p1e2-s31p1e2)+ np.cos(s41p2e2-s31p2e2)+ np.cos(s41p3e2-s31p3e2)+ np.cos(s41p1e2-s1p1e2)+ np.cos(s41p2e2-s1p2e2)+ np.cos(s41p3e2-s1p3e2)+ np.cos(s41p1e2-s42p1e2)+ np.cos(s41p2e2-s42p2e2)+ np.cos(s41p3e2-s42p3e2)+ np.cos(s41p1e2-s45p1e2)+ np.cos(s41p2e2-s45p2e2)+ np.cos(s41p3e2-s45p3e2)

    r41 = prob(H412)/prob(H41)
    x41 = np.random.choice([random.uniform(0, 1)])
    if r41>=x41:
        s41p1n = s41p1e2
        s41p2n = s41p2e2
        s41p3n = s41p3e2
        
        s41p1 = s41p1e2
        s41p2 = s41p2e2
        s41p3 = s41p3e2

    else:
        s41p1n = s41p1
        s41p2n = s41p2
        s41p3n = s41p3
    if s41p1n>=s41p2n>=s41p3n:
        s41= -1
    if s41p2n>=s41p1n>=s41p3n:    
        s41=1
    if s41p3n>=s41p2n>=s41p1n:   
        s41=1
    if s41p3n>=s41p1n>=s41p2n:    
        s41= -1     
    if s41p1n>=s41p3n>=s41p2n:
        s41=1    
    if s41p2n>=s41p3n>=s41p1n:    
        s41= -1  
    s.append(s41)    
    s41p1e2 = s41p1
    s41p2e2 = s41p2
    s41p3e2 = s42p3

    s42p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site42    
    H42 =- np.cos(s42p3-s42p1)- np.cos(s42p2-s42p3)- np.cos(s42p1-s42p2)+ np.cos(s42p1-s32p1)+ np.cos(s42p2-s32p2)+ np.cos(s42p3-s32p3)+ np.cos(s42p1-s2p1)+ np.cos(s42p2-s2p2)+ np.cos(s42p3-s2p3)+ np.cos(s42p1-s43p1)+ np.cos(s42p2-s43p2)+ np.cos(s42p3-s43p3)+ np.cos(s42p1-s41p1)+ np.cos(s42p2-s41p2)+ np.cos(s42p3-s41p3)

    H422 =- np.cos(s42p3e2-s42p1e2)- np.cos(s42p2e2-s42p3e2)- np.cos(s42p1e2-s42p2e2)+ np.cos(s42p1e2-s32p1e2)+ np.cos(s42p2e2-s32p2e2)+ np.cos(s42p3e2-s32p3e2)+ np.cos(s42p1e2-s2p1e2)+ np.cos(s42p2e2-s2p2e2)+ np.cos(s42p3e2-s2p3e2)+ np.cos(s42p1e2-s43p1e2)+ np.cos(s42p2e2-s43p2e2)+ np.cos(s42p3e2-s43p3e2)+ np.cos(s42p1e2-s41p1e2)+ np.cos(s42p2e2-s41p2e2)+ np.cos(s42p3e2-s41p3e2)

    r42 = prob(H422)/prob(H42)
    x42 = np.random.choice([random.uniform(0, 1)])
    if r42>=x42:
        s42p1n = s42p1e2
        s42p2n = s42p2e2
        s42p3n = s42p3e2
        
        s42p1 = s42p1e2
        s42p2 = s42p2e2
        s42p3 = s42p3e2

    else:
        s42p1n = s42p1
        s42p2n = s42p2
        s42p3n = s42p3
    if s42p1n>=s42p2n>=s42p3n:
        s42= -1
    if s42p2n>=s42p1n>=s42p3n:    
        s42=1
    if s42p3n>=s42p2n>=s42p1n:   
        s42=1
    if s42p3n>=s42p1n>=s42p2n:    
        s42= -1     
    if s42p1n>=s42p3n>=s42p2n:
        s42=1    
    if s42p2n>=s42p3n>=s42p1n:    
        s42= -1    
    s.append(s42)    
    s42p1e2 = s42p1
    s42p2e2 = s42p2
    s42p3e2 = s42p3

    s43p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site43    
    H43 =- np.cos(s43p3-s43p1)- np.cos(s43p2-s43p3)- np.cos(s43p1-s43p2)+ np.cos(s43p1-s33p1)+ np.cos(s43p2-s33p2)+ np.cos(s43p3-s33p3)+ np.cos(s43p1-s3p1)+ np.cos(s43p2-s3p2)+ np.cos(s43p3-s3p3)+ np.cos(s43p1-s44p1)+ np.cos(s43p2-s44p2)+ np.cos(s43p3-s44p3)+ np.cos(s43p1-s42p1)+ np.cos(s43p2-s42p2)+ np.cos(s43p3-s42p3)

    H432 =- np.cos(s43p3e2-s43p1e2)- np.cos(s43p2e2-s43p3e2)- np.cos(s43p1e2-s43p2e2)+ np.cos(s43p1e2-s33p1e2)+ np.cos(s43p2e2-s33p2e2)+ np.cos(s43p3e2-s33p3e2)+ np.cos(s43p1e2-s3p1e2)+ np.cos(s43p2e2-s3p2e2)+ np.cos(s43p3e2-s3p3e2)+ np.cos(s43p1e2-s44p1e2)+ np.cos(s43p2e2-s44p2e2)+ np.cos(s43p3e2-s44p3e2)+ np.cos(s43p1e2-s42p1e2)+ np.cos(s43p2e2-s42p2e2)+ np.cos(s43p3e2-s42p3e2)

    r43 = prob(H432)/prob(H43)
    x43 = np.random.choice([random.uniform(0, 1)])
    if r43>=x43:
        s43p1n = s43p1e2
        s43p2n = s43p2e2
        s43p3n = s43p3e2
        
        s43p1 = s43p1e2
        s43p2 = s43p2e2
        s43p3 = s43p3e2

    else:
        s43p1n = s43p1
        s43p2n = s43p2
        s43p3n = s43p3
    if s43p1n>=s43p2n>=s43p3n:
        s43= -1
    if s43p2n>=s43p1n>=s43p3n:    
        s43=1
    if s43p3n>=s43p2n>=s43p1n:   
        s43=1
    if s43p3n>=s43p1n>=s43p2n:    
        s43= -1     
    if s43p1n>=s43p3n>=s43p2n:
        s43=1    
    if s43p2n>=s43p3n>=s43p1n:    
        s43= -1 
    s.append(s43)    
    s43p1e2 = s43p1
    s43p2e2 = s43p2
    s43p3e2 = s43p3

    s44p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site44    
    H44 =- np.cos(s44p3-s44p1)- np.cos(s44p2-s44p3)- np.cos(s44p1-s44p2)+ np.cos(s44p1-s34p1)+ np.cos(s44p2-s34p2)+ np.cos(s44p3-s34p3)+ np.cos(s44p1-s4p1)+ np.cos(s44p2-s4p2)+ np.cos(s44p3-s4p3)+ np.cos(s44p1-s45p1)+ np.cos(s44p2-s45p2)+ np.cos(s44p3-s45p3)+ np.cos(s44p1-s43p1)+ np.cos(s44p2-s43p2)+ np.cos(s44p3-s43p3)

    H442 =- np.cos(s44p3e2-s44p1e2)- np.cos(s44p2e2-s44p3e2)- np.cos(s44p1e2-s44p2e2)+ np.cos(s44p1e2-s34p1e2)+ np.cos(s44p2e2-s34p2e2)+ np.cos(s44p3e2-s34p3e2)+ np.cos(s44p1e2-s4p1e2)+ np.cos(s44p2e2-s4p2e2)+ np.cos(s44p3e2-s4p3e2)+ np.cos(s44p1e2-s45p1e2)+ np.cos(s44p2e2-s45p2e2)+ np.cos(s44p3e2-s45p3e2)+ np.cos(s44p1e2-s43p1e2)+ np.cos(s44p2e2-s43p2e2)+ np.cos(s44p3e2-s43p3e2)

    r44 = prob(H442)/prob(H44)
    x44 = np.random.choice([random.uniform(0, 1)])
    if r44>=x44:
        s44p1n = s44p1e2
        s44p2n = s44p2e2
        s44p3n = s44p3e2
        
        s44p1 = s44p1e2
        s44p2 = s44p2e2
        s44p3 = s44p3e2
 
    else:
        s44p1n = s44p1
        s44p2n = s44p2
        s44p3n = s44p3
    if s44p1n>=s44p2n>=s44p3n:
        s44= -1
    if s44p2n>=s44p1n>=s44p3n:    
        s44=1
    if s44p3n>=s44p2n>=s44p1n:   
        s44=1
    if s44p3n>=s44p1n>=s44p2n:    
        s44= -1     
    if s44p1n>=s44p3n>=s44p2n:
        s44=1    
    if s44p2n>=s44p3n>=s44p1n:    
        s44= -1 
    s.append(s44)            
    s44p1e2 = s44p1
    s44p2e2 = s44p2
    s44p3e2 = s44p3
    
    s45p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])        
#site45    
    H45 =- np.cos(s45p3-s45p1)- np.cos(s45p2-s45p3)- np.cos(s45p1-s45p2)+ np.cos(s45p1-s35p1)+ np.cos(s45p2-s35p2)+ np.cos(s45p3-s35p3)+ np.cos(s45p1-s5p1)+ np.cos(s45p2-s5p2)+ np.cos(s45p3-s5p3)+ np.cos(s45p1-s44p1)+ np.cos(s45p2-s44p2)+ np.cos(s45p3-s44p3)+ np.cos(s45p1-s41p1)+ np.cos(s45p2-s41p2)+ np.cos(s45p3-s41p3)

    H452 =- np.cos(s45p3e2-s45p1e2)- np.cos(s45p2e2-s45p3e2)- np.cos(s45p1e2-s45p2e2)+ np.cos(s45p1e2-s35p1e2)+ np.cos(s45p2e2-s35p2e2)+ np.cos(s45p3e2-s35p3e2)+ np.cos(s45p1e2-s5p1e2)+ np.cos(s45p2e2-s5p2e2)+ np.cos(s45p3e2-s5p3e2)+ np.cos(s45p1e2-s44p1e2)+ np.cos(s45p2e2-s44p2e2)+ np.cos(s45p3e2-s44p3e2)+ np.cos(s45p1e2-s41p1e2)+ np.cos(s45p2e2-s41p2e2)+ np.cos(s45p3e2-s41p3e2)

    r45 = prob(H452)/prob(H45)
    x45 = np.random.choice([random.uniform(0, 1)])
    if r45>=x45:
        s45p1n = s45p1e2
        s45p2n = s45p2e2
        s45p3n = s45p3e2
        
        s45p1 = s45p1e2
        s45p2 = s45p2e2
        s45p3 = s45p3e2

    else:
        s45p1n = s45p1
        s45p2n = s45p2
        s45p3n = s45p3
    if s45p1n>=s45p2n>=s45p3n:
        s45= -1
    if s45p2n>=s45p1n>=s45p3n:    
        s45=1
    if s45p3n>=s45p2n>=s45p1n:   
        s45=1
    if s45p3n>=s45p1n>=s45p2n:    
        s45= -1     
    if s45p1n>=s45p3n>=s45p2n:
        s45=1    
    if s45p2n>=s45p3n>=s45p1n:    
        s45= -1  
    s.append(s45)
    S.append(abs(mean(s)))
C=0
C1=[]
s1s=0
while s1s<=499:
    S1= S[s1s]
    s1s=s1s+1
    C=C+np.sqrt(abs(-(1/500)*((1/500)*S1**2)-((1/500)*S1)**2))
print(C)
C1.append(C)

k=1
s1p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s2p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s11p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s31p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s41p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s32p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s42p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s43p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s44p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s33p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s34p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s35p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s45p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s12p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s3p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s13p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s14p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s15p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s21p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s22p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s23p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s24p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s25p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s4p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s5p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p3 = np.random.choice([random.uniform(0, 2*np.pi)])
T=0.1
b= k/T
s = []
def prob(H):
    return np.exp(H*b) 

S = []
T1=[]
J=0

for i in range(2500):
    s1p1e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    s1p2e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    s1p3e2 =np.random.choice([random.uniform(0, 2*np.pi)])

    s2p1e2 =s2p1
    s2p2e2 =s2p2
    s2p3e2 =s2p3
    
    s11p1e2 = s11p1
    s11p2e2 = s11p2
    s11p3e2 = s11p3
    
    s31p1e2 = s31p1
    s31p2e2 = s31p2
    s31p3e2 = s31p3
    
    s41p1e2 = s41p1
    s41p2e2 = s41p2
    s41p3e2 = s41p3
    
    s42p1e2 = s42p1
    s42p2e2 = s42p2
    s42p3e2 = s42p3
    
    s43p1e2 = s43p1
    s43p2e2 = s43p2
    s43p3e2 = s43p3
    
    s44p1e2 = s44p1
    s44p2e2 = s44p2
    s44p3e2 = s44p3
    
    s32p1e2 = s32p1
    s32p2e2 = s32p2
    s32p3e2 = s32p3
    
    s33p1e2 = s33p1
    s33p2e2 = s33p2
    s33p3e2 = s33p3
    
    s34p1e2 = s34p1
    s34p2e2 = s34p2
    s34p3e2 = s34p3
    
    s35p1e2 = s35p1
    s35p2e2 = s35p2
    s35p3e2 = s35p3
    
    s45p1e2 = s45p1
    s45p2e2 = s45p2
    s45p3e2 = s45p3
    
    s12p1e2 = s12p1
    s12p2e2 = s12p2
    s12p3e2 = s12p3
    
    s13p1e2 = s13p1
    s13p2e2 = s13p2
    s13p3e2 = s13p3
    
    s3p1e2 = s3p1
    s3p2e2 = s3p2
    s3p3e2 = s3p3
    
    s4p1e2 = s4p1
    s4p2e2 = s4p2
    s4p3e2 = s4p3
    
    s14p1e2 = s14p1
    s14p2e2 = s14p2
    s14p3e2 = s14p3
    
    s15p1e2 = s15p1
    s15p2e2 = s15p2
    s15p3e2 = s15p3
    
    s21p1e2 = s21p1
    s21p2e2 = s21p2
    s21p3e2 = s21p3
    
    s5p1e2 = s5p1
    s5p2e2 = s5p2
    s5p3e2 = s5p3
    
    s22p1e2 = s22p1
    s22p2e2 = s22p2
    s22p3e2 = s22p3
    
    s23p1e2 = s23p1
    s23p2e2 = s23p2
    s23p3e2 = s23p3
    
    s24p1e2 = s24p1
    s24p2e2 = s24p2
    s24p3e2 = s24p3
    
    s25p1e2 = s25p1
    s25p2e2 = s25p2
    s25p3e2 = s25p3
#site1        
    H1 = - np.cos(s1p1-s1p2) - np.cos(s1p2-s1p3)- np.cos(s1p3-s1p1)+ np.cos(s1p1-s2p1)+ np.cos(s1p2-s2p2)+ np.cos(s1p3-s2p3)+ np.cos(s1p1-s11p1)+ np.cos(s1p2-s11p2)+ np.cos(s1p3-s11p3)+ np.cos(s1p1-s41p1)+ np.cos(s1p2-s41p2)+ np.cos(s1p3-s41p3)+ np.cos(s1p1-s5p1)+ np.cos(s1p2-s5p2)+ np.cos(s1p3-s5p3)
    
    H12 = - np.cos(s1p1e2-s1p2e2)- np.cos(s1p3e2-s1p1e2)- np.cos(s1p2e2-s1p3e2)+ np.cos(s1p1e2-s2p1e2)+ np.cos(s1p2e2-s2p2e2)+ np.cos(s1p3e2-s2p3e2)+ np.cos(s1p1e2-s11p1e2)+ np.cos(s1p2e2-s11p2e2)+ np.cos(s1p3e2-s11p3e2)+ np.cos(s1p1e2-s41p1e2)+ np.cos(s1p2e2-s41p2e2)+ np.cos(s1p3e2-s41p3e2)+ np.cos(s1p1e2-s5p1e2)+ np.cos(s1p2e2-s5p2e2)+ np.cos(s1p3e2-s5p3e2)

    r= prob(H12)/prob(H1)
    x= np.random.choice([random.uniform(0, 1)])
    if r >= x:
        s1p1n = s1p1e2
        s1p2n = s1p2e2
        s1p3n = s1p3e2
        
        s1p1 = s1p1e2
        s1p2 = s1p2e2
        s1p3 = s1p3e2
        
    else:
        s1p1n = s1p1
        s1p2n = s1p2
        s1p3n = s1p3
    if s1p1n>=s1p2n>=s1p3n:
        s1= -1
    if s1p2n>=s1p1n>=s1p3n:    
        s1=1
    if s1p3n>=s1p2n>=s1p1n:   
        s1=1
    if s1p3n>=s1p1n>=s1p2n:    
        s1= -1     
    if s1p1n>=s1p3n>=s1p2n:
        s1=1    
    if s1p2n>=s1p3n>=s1p1n:    
        s1= -1    
  
    s1p1e2 =s1p1
    s1p2e2 =s1p2
    s1p3e2 =s1p3
    
    s2p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site2    
    H2 = - np.cos(s2p2-s2p3)- np.cos(s2p3-s2p1)- np.cos(s2p1-s2p2)+ np.cos(s2p1-s12p1)+ np.cos(s2p2-s12p2)+ np.cos(s2p3-s12p3)+ np.cos(s2p1-s1p1)+ np.cos(s2p2-s1p2)+ np.cos(s2p3-s1p2)+ np.cos(s2p1-s3p1)+ np.cos(s2p2-s3p2)+ np.cos(s2p3-s3p3)+ np.cos(s2p1-s42p1)+ np.cos(s2p2-s42p2)+ np.cos(s2p3-s42p3)

    H22 =- np.cos(s2p3e2-s2p1e2)- np.cos(s2p2e2-s2p3e2)- np.cos(s2p1e2-s2p2e2)+ np.cos(s2p1e2-s1p1e2)+ np.cos(s2p2e2-s1p2e2)+ np.cos(s2p3e2-s1p3e2)+ np.cos(s2p1e2-s12p1e2)+ np.cos(s2p2e2-s12p2e2)+ np.cos(s2p3e2-s12p3e2)+ np.cos(s2p1e2-s3p1e2)+ np.cos(s2p2e2-s3p2e2)+ np.cos(s2p3e2-s3p3e2)+ np.cos(s2p1e2-s42p1e2)+ np.cos(s2p2e2-s42p2e2)+ np.cos(s2p3e2-s42p3e2)

    r1 = prob(H22)/prob(H2)
    x1 = np.random.choice([random.uniform(0, 1)])
    if r1 >= x1:
        s2p1n = s2p1e2
        s2p2n = s2p2e2
        s2p3n = s2p3e2
        
        s2p1 = s2p1e2
        s2p2 = s2p2e2
        s2p3 = s2p3e2
        
    else:
        s2p1n = s2p1
        s2p2n = s2p2
        s2p3n = s2p3
        
    if s2p1n>=s2p2n>=s2p3n:
        s2= -1
    if s2p2n>=s2p1n>=s2p3n:    
        s2=1
    if s2p3n>=s2p2n>=s2p1n:   
        s2=1
    if s2p3n>=s2p1n>=s2p2n:    
        s2= -1     
    if s2p1n>=s2p3n>=s2p2n:
        s2=1    
    if s2p2n>=s2p3n>=s2p1n:    
        s2= -1    

    s2p1e2 = s2p1
    s2p2e2 = s2p2
    s2p3e2 = s2p3
    
    s3p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site3    
    H3 = -np.cos(s3p2-s3p3)- np.cos(s3p3-s3p1)- np.cos(s3p1-s3p2)+ np.cos(s3p1-s2p1)+ np.cos(s3p2-s2p2)+ np.cos(s3p3-s2p3)+ np.cos(s3p1-s13p1)+ np.cos(s3p2-s13p2)+ np.cos(s3p3-s13p3)+ np.cos(s3p1-s4p1)+ np.cos(s3p2-s4p2)+ np.cos(s3p3-s4p3)+ np.cos(s3p1-s43p1)+ np.cos(s3p2-s43p2)+ np.cos(s3p3-s43p3)

    H32 = - np.cos(s3p2e2-s3p3e2)- np.cos(s3p3e2-s3p1e2)- np.cos(s3p1e2-s3p2e2)+ np.cos(s3p1e2-s2p1e2)+ np.cos(s3p2e2-s2p2e2)+ np.cos(s3p3e2-s2p3e2)+ np.cos(s3p1e2-s13p1e2)+ np.cos(s3p2e2-s13p2e2)+ np.cos(s3p3e2-s13p3e2)+ np.cos(s3p1e2-s4p1e2)+ np.cos(s3p2e2-s4p2e2)+ np.cos(s3p3e2-s4p3e2)+ np.cos(s3p1e2-s43p1e2)+ np.cos(s3p2e2-s43p2e2)+ np.cos(s3p3e2-s43p3e2)
  
    r2 = prob(H32)/prob(H3)
    x2 = np.random.choice([random.uniform(0, 1)])
    if r2 >= x2:
        s3p1n = s3p1e2
        s3p2n = s3p2e2
        s3p3n = s3p3e2
        
        s3p1 = s3p1e2
        s3p2 = s3p2e2
        s3p3 = s3p3e2
    else:
        s3p1n = s3p1
        s3p2n = s3p2
        s3p3n = s3p3
    if s3p1n>=s3p2n>=s3p3n:
        s3= -1
    if s3p2n>=s3p1n>=s3p3n:    
        s3=1
    if s3p3n>=s3p2n>=s3p1n:   
        s3=1
    if s3p3n>=s3p1n>=s3p2n:    
        s3= -1     
    if s3p1n>=s3p3n>=s3p2n:
        s3=1    
    if s3p2n>=s3p3n>=s3p1n:    
        s3= -1  
  
    s3p1e2 = s3p1
    s3p2e2 = s3p2
    s3p3e2 = s3p3
    
    s4p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site4    
    H4 = - np.cos(s4p2-s4p3)- np.cos(s4p3-s4p1)- np.cos(s4p1-s4p2)+ np.cos(s4p1-s3p1)+ np.cos(s4p2-s3p2)+ np.cos(s4p3-s3p3)+ np.cos(s4p1-s14p1)+ np.cos(s4p2-s14p2)+ np.cos(s4p3-s14p3)+ np.cos(s4p1-s5p1)+ np.cos(s4p2-s5p2)+ np.cos(s4p3-s5p3)+ np.cos(s4p1-s44p1)+ np.cos(s4p2-s44p2)+ np.cos(s4p3-s44p3)

    H42 = - np.cos(s4p3e2-s4p1e2)- np.cos(s4p2e2-s3p3e2)- np.cos(s4p1e2-s4p2e2)+ np.cos(s4p1e2-s3p1e2)+ np.cos(s4p2e2-s3p2e2)+ np.cos(s4p3e2-s3p3e2)+ np.cos(s4p1e2-s14p1e2)+ np.cos(s4p2e2-s14p2e2)+ np.cos(s4p3e2-s14p3e2)+ np.cos(s4p1e2-s5p1e2)+ np.cos(s4p2e2-s5p2e2)+ np.cos(s4p3e2-s5p3e2)+ np.cos(s4p1e2-s44p1e2)+ np.cos(s4p2e2-s44p2e2)+ np.cos(s4p3e2-s44p3e2)

    r3 = prob(H42)/prob(H4)
    x3 = np.random.choice([random.uniform(0, 1)])
    if r3 >= x3:
        s4p1n = s4p1e2
        s4p2n = s4p2e2
        s4p3n = s4p3e2
        
        s4p1 = s4p1e2
        s4p2 = s4p2e2
        s4p3 = s4p3e2
    else:
        s4p1n = s4p1
        s4p2n = s4p2
        s4p3n = s4p3
    if s4p1n>=s4p2n>=s4p3n:
        s4= -1
    if s4p2n>=s4p1n>=s4p3n:    
        s4=1
    if s4p3n>=s4p2n>=s4p1n:   
        s4=1
    if s4p3n>=s4p1n>=s4p2n:    
        s4= -1     
    if s4p1n>=s4p3n>=s4p2n:
        s4=1    
    if s4p2n>=s4p3n>=s4p1n:    
        s4= -1    

    s4p1e2 = s4p1
    s4p2e2 = s4p2
    s4p3e2 = s4p3
    
    s5p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site5    
    H5 =- np.cos(s5p2-s5p3)- np.cos(s5p3-s5p1)- np.cos(s5p1-s5p2)+ np.cos(s5p1-s4p1)+ np.cos(s5p2-s4p2)+ np.cos(s5p3-s4p3)+ np.cos(s5p1-s15p1)+ np.cos(s5p2-s15p2)+ np.cos(s5p3-s15p3)+ np.cos(s5p1-s45p1)+ np.cos(s5p2-s45p2)+ np.cos(s5p3-s45p3)+ np.cos(s5p1-s1p1)+ np.cos(s5p2-s1p2)+ np.cos(s5p3-s1p3)

    H52 = - np.cos(s5p3e2-s5p1e2)- np.cos(s5p2e2-s5p3e2)- np.cos(s5p1e2-s5p2e2)+ np.cos(s5p1e2-s4p1e2)+ np.cos(s5p2e2-s4p2e2)+ np.cos(s5p3e2-s4p3e2)+ np.cos(s5p1e2-s15p1e2)+ np.cos(s5p2e2-s15p2e2)+ np.cos(s5p3e2-s15p3e2)+ np.cos(s5p1e2-s45p1e2)+ np.cos(s5p2e2-s45p2e2)+ np.cos(s5p3e2-s45p3e2)+ np.cos(s5p1e2-s1p1e2)+ np.cos(s5p2e2-s1p2e2)+ np.cos(s5p3e2-s1p3e2)

    r4 = prob(H52)/prob(H5)
    x4 = np.random.choice([random.uniform(0, 1)])
    if r4 >= x4:
        s5p1n = s5p1e2
        s5p2n = s5p2e2
        s5p3n = s5p3e2
        
        s5p1 = s5p1e2
        s5p2 = s5p2e2
        s5p3 = s5p3e2
    else:
        s5p1n = s5p1
        s5p2n = s5p2
        s5p3n = s5p3
    if s5p1n>=s5p2n>=s5p3n:
        s5= -1
    if s5p2n>=s5p1n>=s5p3n:    
        s5=1
    if s5p3n>=s5p2n>=s5p1n:   
        s5=1
    if s5p3n>=s5p1n>=s5p2n:    
        s5= -1     
    if s5p1n>=s5p3n>=s5p2n:
        s5=1    
    if s5p2n>=s5p3n>=s5p1n:    
        s5= -1   
          
    s5p1e2 = s5p1
    s5p2e2 = s5p2
    s5p3e2 = s5p3
    
    s11p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site11    
    H11 =- np.cos(s11p3-s11p1)- np.cos(s11p2-s11p3)- np.cos(s11p1-s11p2)+ np.cos(s11p1-s1p1)+ np.cos(s11p2-s1p2)+ np.cos(s11p3-s1p3)+ np.cos(s11p1-s12p1)+ np.cos(s11p2-s12p2)+ np.cos(s11p3-s12p3)+ np.cos(s11p1-s21p1)+ np.cos(s11p2-s21p2)+ np.cos(s11p3-s21p3)+ np.cos(s11p1-s15p1)+ np.cos(s11p2-s15p2)+ np.cos(s11p3-s15p3)

    H112 =- np.cos(s11p3e2-s11p1e2)- np.cos(s11p2e2-s11p3e2)- np.cos(s11p1e2-s11p2e2)+ np.cos(s11p1e2-s1p1e2)+ np.cos(s11p2e2-s1p2e2)+ np.cos(s11p3e2-s1p3e2)+ np.cos(s11p1e2-s12p1e2)+ np.cos(s11p2e2-s12p2e2)+ np.cos(s11p3e2-s12p3e2)+ np.cos(s11p1e2-s21p1e2)+ np.cos(s11p2e2-s21p2e2)+ np.cos(s11p3e2-s21p3e2)+ np.cos(s11p1e2-s15p1e2)+ np.cos(s11p2e2-s15p2e2)+ np.cos(s11p3e2-s15p3e2)

    r11 = prob(H112)/prob(H11)
    x11 = np.random.choice([random.uniform(0, 1)])
    if r11 >= x11:
        s11p1n = s11p1e2
        s11p2n = s11p2e2
        s11p3n = s11p3e2
        
        s11p1 = s11p1e2
        s11p2 = s11p2e2
        s11p3 = s11p3e2
        
    else:
        s11p1n = s11p1
        s11p2n = s11p2
        s11p3n = s11p3
    if s11p1n>=s11p2n>=s11p3n:
        s11= -1
    if s11p2n>=s11p1n>=s11p3n:    
        s11=1
    if s11p3n>=s11p2n>=s11p1n:   
        s11=1
    if s11p3n>=s11p1n>=s11p2n:    
        s11= -1     
    if s11p1n>=s11p3n>=s11p2n:
        s11=1    
    if s11p2n>=s11p3n>=s11p1n:    
        s11= -1   
         
    s11p1e2 = s11p1
    s11p2e2 = s11p2
    s11p3e2 = s11p3
    
    s12p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site12    
    H12s =- np.cos(s12p3-s12p1)- np.cos(s12p2-s12p3)- np.cos(s12p1-s12p2)+ np.cos(s12p1-s2p1)+ np.cos(s12p2-s2p2)+ np.cos(s12p3-s2p3)+ np.cos(s12p1-s13p1)+ np.cos(s12p2-s13p2)+ np.cos(s12p3-s13p3)+ np.cos(s12p1-s22p1)+ np.cos(s12p2-s22p2)+ np.cos(s12p3-s22p3)+ np.cos(s12p1-s11p1)+ np.cos(s12p2-s11p2)+ np.cos(s12p3-s11p3)

    H122 =- np.cos(s12p3e2-s12p1e2)- np.cos(s12p2e2-s12p3e2)- np.cos(s12p1e2-s12p2e2)+ np.cos(s12p1e2-s2p1e2)+ np.cos(s12p2e2-s2p2e2)+ np.cos(s12p3e2-s2p3e2)+ np.cos(s12p1e2-s13p1e2)+ np.cos(s12p2e2-s13p2e2)+ np.cos(s12p3e2-s13p3e2)+ np.cos(s12p1e2-s22p1e2)+ np.cos(s12p2e2-s22p2e2)+ np.cos(s12p3e2-s22p3e2)+ np.cos(s12p1e2-s11p1e2)+ np.cos(s12p2e2-s11p2e2)+ np.cos(s12p3e2-s11p3e2)

    r12 = prob(H122)/prob(H12s)
    x12 = np.random.choice([random.uniform(0, 1)])
    if r12 >= x12:
        s12p1n = s12p1e2
        s12p2n = s12p2e2
        s12p3n = s12p3e2
        
        s12p1 = s12p1e2
        s12p2 = s12p2e2
        s12p3 = s12p3e2
        
    else:
        s12p1n = s12p1
        s12p2n = s12p2
        s12p3n = s12p3
    if s12p1n>=s12p2n>=s12p3n:
        s12= -1
    if s12p2n>=s12p1n>=s12p3n:    
        s12=1
    if s12p3n>=s12p2n>=s12p1n:   
        s12=1
    if s12p3n>=s12p1n>=s12p2n:    
        s12= -1     
    if s12p1n>=s12p3n>=s12p2n:
        s12=1    
    if s12p2n>=s12p3n>=s12p1n:    
        s12= -1    
    
    s12p1e2 = s12p1
    s12p2e2 = s12p2
    s12p3e2 = s12p3
    
    s13p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site13    
    H13 =- np.cos(s13p3-s13p1)- np.cos(s13p2-s13p3)- np.cos(s13p1-s13p2)+ np.cos(s13p1-s3p1)+ np.cos(s13p2-s3p2)+ np.cos(s13p3-s3p3)+ np.cos(s13p1-s14p1)+ np.cos(s13p2-s14p2)+ np.cos(s13p3-s14p3)+ np.cos(s13p1-s23p1)+ np.cos(s13p2-s23p2)+ np.cos(s13p3-s23p3)+ np.cos(s13p1-s12p1)+ np.cos(s13p2-s12p2)+ np.cos(s13p3-s12p3)

    H132 =- np.cos(s13p3e2-s13p1e2)- np.cos(s13p2e2-s13p3e2)- np.cos(s13p1e2-s13p2e2)+ np.cos(s13p1e2-s3p1e2)+ np.cos(s13p2e2-s3p2e2)+ np.cos(s13p3e2-s3p3e2)+ np.cos(s13p1e2-s14p1e2)+ np.cos(s13p2e2-s14p2e2)+ np.cos(s13p3e2-s14p3e2)+ np.cos(s13p1e2-s23p1e2)+ np.cos(s13p2e2-s23p2e2)+ np.cos(s13p3e2-s23p3e2)+ np.cos(s13p1e2-s12p1e2)+ np.cos(s13p2e2-s12p2e2)+ np.cos(s13p3e2-s12p3e2)

    r13 = prob(H132)/prob(H13)
    x13 = np.random.choice([random.uniform(0, 1)])
    if r13 >= x13:
        s13p1n = s13p1e2
        s13p2n = s13p2e2
        s13p3n = s13p3e2
        
        s13p1 = s13p1e2
        s13p2 = s13p2e2
        s13p3 = s13p3e2
        
    else:
        s13p1n = s13p1
        s13p2n = s13p2
        s13p3n = s13p3
    if s13p1n>=s13p2n>=s13p3n:
        s13= -1
    if s13p2n>=s13p1n>=s13p3n:    
        s13=1
    if s13p3n>=s13p2n>=s13p1n:   
        s13=1
    if s13p3n>=s13p1n>=s13p2n:    
        s13= -1     
    if s13p1n>=s13p3n>=s13p2n:
        s13=1    
    if s13p2n>=s13p3n>=s13p1n:    
        s13= -1  
   
    s13p1e2 = s13p1
    s13p2e2 = s13p2
    s13p3e2 = s13p3
    
    s14p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site14    
    H14 =- np.cos(s14p3-s14p1)- np.cos(s14p2-s14p3)- np.cos(s14p1-s14p2)+ np.cos(s14p1-s4p1)+ np.cos(s14p2-s4p2)+ np.cos(s14p3-s4p3)+ np.cos(s14p1-s15p1)+ np.cos(s14p2-s15p2)+ np.cos(s14p3-s15p3)+ np.cos(s14p1-s24p1)+ np.cos(s14p2-s24p2)+ np.cos(s14p3-s24p3)+ np.cos(s14p1-s13p1)+ np.cos(s14p2-s13p2)+ np.cos(s14p3-s13p3)

    H142 =- np.cos(s14p3e2-s14p1e2)- np.cos(s14p2e2-s14p3e2)- np.cos(s14p1e2-s14p2e2)+ np.cos(s14p1e2-s4p1e2)+ np.cos(s14p2e2-s4p2e2)+ np.cos(s14p3e2-s4p3e2)+ np.cos(s14p1e2-s15p1e2)+ np.cos(s14p2e2-s15p2e2)+ np.cos(s14p3e2-s15p3e2)+ np.cos(s14p1e2-s24p1e2)+ np.cos(s14p2e2-s24p2e2)+ np.cos(s14p3e2-s24p3e2)+ np.cos(s14p1e2-s13p1e2)+ np.cos(s14p2e2-s13p2e2)+ np.cos(s14p3e2-s13p3e2)

    r14 = prob(H142)/prob(H14)
    x14 = np.random.choice([random.uniform(0, 1)])
    if r14 >= x14:
        s14p1n = s14p1e2
        s14p2n = s14p2e2
        s14p3n = s14p3e2
        
        s14p1 = s14p1e2
        s14p2 = s14p2e2
        s14p3 = s14p3e2
        
    else:
        s14p1n = s14p1
        s14p2n = s14p2
        s14p3n = s14p3
    if s14p1n>=s14p2n>=s14p3n:
        s14= -1
    if s14p2n>=s14p1n>=s14p3n:    
        s14=1
    if s14p3n>=s14p2n>=s14p1n:   
        s14=1
    if s14p3n>=s14p1n>=s14p2n:    
        s14= -1     
    if s14p1n>=s14p3n>=s14p2n:
        s14=1    
    if s14p2n>=s14p3n>=s14p1n:    
        s14= -1  

    s14p1e2 = s14p1
    s14p2e2 = s14p2
    s14p3e2 = s14p3

    s15p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])                  
#site15    
    H15 =- np.cos(s15p3-s15p1)- np.cos(s15p2-s15p3)- np.cos(s15p1-s15p2)+ np.cos(s15p1-s5p1)+ np.cos(s15p2-s5p2)+ np.cos(s15p3-s5p3)+ np.cos(s15p1-s25p1)+ np.cos(s15p2-s25p2)+ np.cos(s15p3-s25p3)+ np.cos(s15p1-s14p1)+ np.cos(s15p2-s14p2)+ np.cos(s15p3-s14p3)+ np.cos(s15p1-s11p1)+ np.cos(s15p2-s11p2)+ np.cos(s15p3-s11p3)

    H152 =- np.cos(s15p3e2-s15p1e2)- np.cos(s15p2e2-s15p3e2)- np.cos(s15p1e2-s15p2e2)+ np.cos(s15p1e2-s5p1e2)+ np.cos(s15p2e2-s5p2e2)+ np.cos(s15p3e2-s5p3e2)+ np.cos(s15p1e2-s25p1e2)+ np.cos(s15p2e2-s25p2e2)+ np.cos(s15p3e2-s25p3e2)+ np.cos(s15p1e2-s14p1e2)+ np.cos(s15p2e2-s14p2e2)+ np.cos(s15p3e2-s14p3e2)+ np.cos(s15p1e2-s11p1e2)+ np.cos(s15p2e2-s11p2e2)+ np.cos(s15p3e2-s11p3e2)

    r15 = prob(H152)/prob(H15)
    x15 = np.random.choice([random.uniform(0, 1)])
    if r15 >= x15:
        s15p1n = s15p1e2
        s15p2n = s15p2e2
        s15p3n = s15p3e2
        
        s15p1 = s15p1e2
        s15p2 = s15p2e2
        s15p3 = s15p3e2
    else:
        s15p1n = s15p1
        s15p2n = s15p2
        s15p3n = s15p3
    if s15p1n>=s15p2n>=s15p3n:
        s15= -1
    if s15p2n>=s15p1n>=s15p3n:    
        s15=1
    if s15p3n>=s15p2n>=s15p1n:   
        s15=1
    if s15p3n>=s15p1n>=s15p2n:    
        s15= -1     
    if s15p1n>=s15p3n>=s15p2n:
        s15=1    
    if s15p2n>=s15p3n>=s15p1n:    
        s15= -1    

    s15p1e2 = s15p1
    s15p2e2 = s15p2
    s15p3e2 = s15p3

    s21p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
#site21    
    H21 =- np.cos(s21p3-s21p1)- np.cos(s21p2-s21p3)- np.cos(s21p1-s21p2)+ np.cos(s21p1-s11p1)+ np.cos(s21p2-s11p2)+ np.cos(s21p3-s11p3)+ np.cos(s21p1-s31p1)+ np.cos(s21p2-s31p2)+ np.cos(s21p3-s31p3)+ np.cos(s21p1-s22p1)+ np.cos(s21p2-s22p2)+ np.cos(s21p3-s22p3)+ np.cos(s21p1-s25p1)+ np.cos(s21p2-s25p2)+ np.cos(s21p3-s25p3)

    H212 =- np.cos(s21p3e2-s21p1e2)- np.cos(s21p2e2-s21p3e2)- np.cos(s21p1e2-s21p2e2)+ np.cos(s21p1e2-s11p1e2)+ np.cos(s21p2e2-s11p2e2)+ np.cos(s21p3e2-s11p3e2)+ np.cos(s21p1e2-s31p1e2)+ np.cos(s21p2e2-s31p2e2)+ np.cos(s21p3e2-s31p3e2)+ np.cos(s21p1e2-s22p1e2)+ np.cos(s21p2e2-s22p2e2)+ np.cos(s21p3e2-s22p3e2)+ np.cos(s21p1e2-s25p1e2)+ np.cos(s21p2e2-s25p2e2)+ np.cos(s21p3e2-s25p3e2)

    r21 = prob(H212)/prob(H21)
    x21 = np.random.choice([random.uniform(0, 1)])
    if r21 >= x21:
        s21p1n = s21p1e2
        s21p2n = s21p2e2
        s21p3n = s21p3e2
        
        s21p1 = s21p1e2
        s21p2 = s21p2e2
        s21p3 = s21p3e2
  
    else:
        s21p1n = s21p1
        s21p2n = s21p2
        s21p3n = s21p3
    if s21p1n>=s21p2n>=s21p3n:
        s21= -1
    if s21p2n>=s21p1n>=s21p3n:    
        s21=1
    if s21p3n>=s21p2n>=s21p1n:   
        s21=1
    if s21p3n>=s21p1n>=s21p2n:    
        s21= -1     
    if s21p1n>=s21p3n>=s21p2n:
        s21=1    
    if s21p2n>=s21p3n>=s21p1n:    
        s21= -1

    s21p1e2 = s21p1
    s21p2e2 = s21p2
    s21p3e2 = s22p3   

    s22p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])            
#site22    
    H22 =- np.cos(s22p3-s22p1)- np.cos(s22p2-s22p3)- np.cos(s22p1-s22p2)+ np.cos(s22p1-s12p1)+ np.cos(s22p2-s12p2)+ np.cos(s22p3-s12p3)+ np.cos(s22p1-s32p1)+ np.cos(s22p2-s32p2)+ np.cos(s22p3-s32p3)+ np.cos(s22p1-s23p1)+ np.cos(s22p2-s23p2)+ np.cos(s22p3-s23p3)+ np.cos(s22p1-s21p1)+ np.cos(s22p2-s21p2)+ np.cos(s22p3-s21p3)

    H222 =- np.cos(s22p3e2-s22p1e2)- np.cos(s22p2e2-s22p3e2)- np.cos(s22p1e2-s22p2e2)+ np.cos(s22p1e2-s12p1e2)+ np.cos(s22p2e2-s12p2e2)+ np.cos(s22p3e2-s12p3e2)+ np.cos(s22p1e2-s32p1e2)+ np.cos(s22p2e2-s32p2e2)+ np.cos(s22p3e2-s32p3e2)+ np.cos(s22p1e2-s23p1e2)+ np.cos(s22p2e2-s23p2e2)+ np.cos(s22p3e2-s23p3e2)+ np.cos(s22p1e2-s21p1e2)+ np.cos(s22p2e2-s21p2e2)+ np.cos(s22p3e2-s21p3e2)

    r22 = prob(H222)/prob(H22)
    x22 = np.random.choice([random.uniform(0, 1)])
    if r22 >= x22:
        s22p1n = s22p1e2
        s22p2n = s22p2e2
        s22p3n = s22p3e2
        
        s22p1 = s22p1e2
        s22p2 = s22p2e2
        s22p3 = s22p3e2
        
    else:
        s22p1n = s22p1
        s22p2n = s22p2
        s22p3n = s22p3
    if s22p1n>=s22p2n>=s22p3n:
        s22= -1
    if s22p2n>=s22p1n>=s22p3n:    
        s22=1
    if s22p3n>=s22p2n>=s22p1n:   
        s22=1
    if s22p3n>=s22p1n>=s22p2n:    
        s22= -1     
    if s22p1n>=s22p3n>=s22p2n:
        s22=1    
    if s22p2n>=s22p3n>=s22p1n:    
        s22= -1    
  
    s22p1e2 = s22p1
    s22p2e2 = s22p2
    s22p3e2 = s22p3  
    
    s23p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])   
#site23    
    H23 =- np.cos(s23p3-s23p1)- np.cos(s23p2-s23p3)- np.cos(s23p1-s23p2)+ np.cos(s23p1-s13p1)+ np.cos(s23p2-s13p2)+ np.cos(s23p3-s13p3)+ np.cos(s23p1-s33p1)+ np.cos(s23p2-s33p2)+ np.cos(s23p3-s33p3)+ np.cos(s23p1-s24p1)+ np.cos(s23p2-s24p2)+ np.cos(s23p3-s24p3)+ np.cos(s23p1-s22p1)+ np.cos(s23p2-s22p2)+ np.cos(s23p3-s22p3)

    H232 =- np.cos(s23p3e2-s23p1e2)- np.cos(s23p2e2-s23p3e2)- np.cos(s23p1e2-s23p2e2)+ np.cos(s23p1e2-s13p1e2)+ np.cos(s23p2e2-s13p2e2)+ np.cos(s23p3e2-s13p3e2)+ np.cos(s23p1e2-s33p1e2)+ np.cos(s23p2e2-s33p2e2)+ np.cos(s23p3e2-s33p3e2)+ np.cos(s23p1e2-s24p1e2)+ np.cos(s23p2e2-s24p2e2)+ np.cos(s23p3e2-s24p3e2)+ np.cos(s23p1e2-s22p1e2)+ np.cos(s23p2e2-s22p2e2)+ np.cos(s23p3e2-s22p3e2)

    r23 = prob(H232)/prob(H23)
    x23 = np.random.choice([random.uniform(0, 1)])
    if r23>=x23:
        s23p1n = s23p1e2
        s23p2n = s23p2e2
        s23p3n = s23p3e2
        
        s23p1 = s23p1e2
        s23p2 = s23p2e2
        s23p3 = s23p3e2

    else:
        s23p1n = s23p1
        s23p2n = s23p2
        s23p3n = s23p3
    if s23p1n>=s23p2n>=s23p3n:
        s23= -1
    if s23p2n>=s23p1n>=s23p3n:    
        s23=1
    if s23p3n>=s23p2n>=s23p1n:   
        s23=1
    if s23p3n>=s23p1n>=s23p2n:    
        s23= -1     
    if s23p1n>=s23p3n>=s23p2n:
        s23=1    
    if s23p2n>=s23p3n>=s23p1n:    
        s23= -1  
   
    s23p1e2 = s23p1
    s23p2e2 = s23p2
    s23p3e2 = s23p3
    
    s24p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])           
#site24    
    H24 =- np.cos(s24p3-s24p1)- np.cos(s24p2-s24p3)- np.cos(s24p1-s24p2)+ np.cos(s24p1-s14p1)+ np.cos(s24p2-s14p2)+ np.cos(s24p3-s14p3)+ np.cos(s24p1-s34p1)+ np.cos(s24p2-s34p2)+ np.cos(s24p3-s34p3)+ np.cos(s24p1-s25p1)+ np.cos(s24p2-s25p2)+ np.cos(s24p3-s25p3)+ np.cos(s24p1-s23p1)+ np.cos(s24p2-s23p2)+ np.cos(s24p3-s23p3)

    H242 =- np.cos(s24p3e2-s24p1e2)- np.cos(s24p2e2-s24p3e2)- np.cos(s24p1e2-s24p2e2)+ np.cos(s24p1e2-s14p1e2)+ np.cos(s24p2e2-s14p2e2)+ np.cos(s24p3e2-s14p3e2)+ np.cos(s24p1e2-s34p1e2)+ np.cos(s24p2e2-s34p2e2)+ np.cos(s24p3e2-s34p3e2)+ np.cos(s24p1e2-s25p1e2)+ np.cos(s24p2e2-s25p2e2)+ np.cos(s24p3e2-s25p3e2)+ np.cos(s24p1e2-s23p1e2)+ np.cos(s24p2e2-s23p2e2)+ np.cos(s24p3e2-s23p3e2)

    r24 = prob(H242)/prob(H24)
    x24 = np.random.choice([random.uniform(0, 1)])
    if r24>=x24:
        s24p1n = s24p1e2
        s24p2n = s24p2e2
        s24p3n = s24p3e2
        
        s24p1 = s24p1e2
        s24p2 = s24p2e2
        s24p3 = s24p3e2

    else:
        s24p1n = s24p1
        s24p2n = s24p2
        s24p3n = s24p3 
    if s24p1n>=s24p2n>=s24p3n:
        s24= -1
    if s24p2n>=s24p1n>=s24p3n:    
        s24=1
    if s24p3n>=s24p2n>=s24p1n:   
        s24=1
    if s24p3n>=s24p1n>=s24p2n:    
        s24= -1     
    if s24p1n>=s24p3n>=s24p2n:
        s24=1    
    if s24p2n>=s24p3n>=s24p1n:    
        s24= -1  
          
    s24p1e2 = s24p1
    s24p2e2 = s24p2
    s24p3e2 = s24p3 
    
    s25p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
#site25    
    H25 =- np.cos(s25p3-s25p1)- np.cos(s25p2-s25p3)- np.cos(s25p1-s25p2)+ np.cos(s25p1-s15p1)+ np.cos(s25p2-s15p2)+ np.cos(s25p3-s15p3)+ np.cos(s25p1-s35p1)+ np.cos(s25p2-s35p2)+ np.cos(s25p3-s35p3)+ np.cos(s25p1-s24p1)+ np.cos(s25p2-s24p2)+ np.cos(s25p3-s24p3)+ np.cos(s25p1-s21p1)+ np.cos(s25p2-s21p2)+ np.cos(s25p3-s21p3)

    H252 =- np.cos(s25p3e2-s25p1e2)- np.cos(s25p2e2-s25p3e2)- np.cos(s25p1e2-s25p2e2)+ np.cos(s25p1e2-s15p1e2)+ np.cos(s25p2e2-s15p2e2)+ np.cos(s25p3e2-s15p3e2)+ np.cos(s25p1e2-s35p1e2)+ np.cos(s25p2e2-s35p2e2)+ np.cos(s25p3e2-s35p3e2)+ np.cos(s25p1e2-s24p1e2)+ np.cos(s25p2e2-s24p2e2)+ np.cos(s25p3e2-s24p3e2)+ np.cos(s25p1e2-s21p1e2)+ np.cos(s25p2e2-s21p2e2)+ np.cos(s25p3e2-s21p3e2)

    r25 = prob(H252)/prob(H25)
    x25 = np.random.choice([random.uniform(0, 1)])
    if r25>=x25:
        s25p1n = s25p1e2
        s25p2n = s25p2e2
        s25p3n = s25p3e2
        
        s25p1 = s25p1e2
        s25p2 = s25p2e2
        s25p3 = s25p3e2

    else:
        s25p1n = s25p1
        s25p2n = s25p2
        s25p3n = s25p3
    if s25p1n>=s25p2n>=s25p3n:
        s25= -1
    if s25p2n>=s25p1n>=s25p3n:    
        s25=1
    if s25p3n>=s25p2n>=s25p1n:   
        s25=1
    if s25p3n>=s25p1n>=s25p2n:    
        s25= -1     
    if s25p1n>=s25p3n>=s25p2n:
        s25=1    
    if s25p2n>=s25p3n>=s25p1n:    
        s25= -1 
   
    s25p1e2 = s25p1
    s25p2e2 = s25p2
    s25p3e2 = s25p3

    s31p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 

#site31    
    H31 =- np.cos(s31p3-s31p1)- np.cos(s31p2-s31p3)- np.cos(s31p1-s31p2)+ np.cos(s31p1-s21p1)+ np.cos(s31p2-s21p2)+ np.cos(s31p3-s21p3)+ np.cos(s31p1-s41p1)+ np.cos(s31p2-s41p2)+ np.cos(s31p3-s41p3)+ np.cos(s31p1-s32p1)+ np.cos(s31p2-s32p2)+ np.cos(s31p3-s32p3)+ np.cos(s31p1-s35p1)+ np.cos(s31p2-s35p2)+ np.cos(s31p3-s35p3)

    H312 =- np.cos(s31p3e2-s31p1e2)- np.cos(s31p2e2-s31p3e2)- np.cos(s31p1e2-s31p2e2)+ np.cos(s31p1e2-s21p1e2)+ np.cos(s31p2e2-s21p2e2)+ np.cos(s31p3e2-s21p3e2)+ np.cos(s31p1e2-s41p1e2)+ np.cos(s31p2e2-s41p2e2)+ np.cos(s31p3e2-s41p3e2)+ np.cos(s31p1e2-s32p1e2)+ np.cos(s31p2e2-s32p2e2)+ np.cos(s31p3e2-s32p3e2)+ np.cos(s31p1e2-s35p1e2)+ np.cos(s31p2e2-s35p2e2)+ np.cos(s31p3e2-s35p3e2)

    r31 = prob(H312)/prob(H31)
    x31 = np.random.choice([random.uniform(0, 1)])
    if r31>=x31:
        s31p1n = s31p1e2
        s31p2n = s31p2e2
        s31p3n = s31p3e2

        s31p1 = s31p1e2
        s31p2 = s31p2e2
        s31p3 = s31p3e2
    else:
        s31p1n = s31p1
        s31p2n = s31p2
        s31p3n = s31p3
    if s31p1n>=s31p2n>=s31p3n:
        s31= -1
    if s31p2n>=s31p1n>=s31p3n:    
        s31=1
    if s31p3n>=s31p2n>=s31p1n:   
        s31=1
    if s31p3n>=s31p1n>=s31p2n:    
        s31= -1     
    if s31p1n>=s31p3n>=s31p2n:
        s31=1    
    if s31p2n>=s31p3n>=s31p1n:    
        s31= -1

    s31p1e2 = s31p1
    s31p2e2 = s31p2
    s31p3e2 = s31p3
    
    s32p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
    
#site32    
    H32 =- np.cos(s32p3-s32p1)- np.cos(s32p2-s32p3)- np.cos(s32p1-s32p2)+ np.cos(s32p1-s22p1)+ np.cos(s32p2-s22p2)+ np.cos(s32p3-s22p3)+ np.cos(s32p1-s42p1)+ np.cos(s32p2-s42p2)+ np.cos(s32p3-s42p3)+ np.cos(s32p1-s33p1)+ np.cos(s32p2-s33p2)+ np.cos(s32p3-s33p3)+ np.cos(s32p1-s31p1)+ np.cos(s32p2-s31p2)+ np.cos(s32p3-s31p3)

    H322 =- np.cos(s32p3e2-s32p1e2)- np.cos(s32p2e2-s32p3e2)- np.cos(s32p1e2-s32p2e2)+ np.cos(s32p1e2-s22p1e2)+ np.cos(s32p2e2-s22p2e2)+ np.cos(s32p3e2-s22p3e2)+ np.cos(s32p1e2-s42p1e2)+ np.cos(s32p2e2-s42p2e2)+ np.cos(s32p3e2-s42p3e2)+ np.cos(s32p1e2-s33p1e2)+ np.cos(s32p2e2-s33p2e2)+ np.cos(s32p3e2-s33p3e2)+ np.cos(s32p1e2-s31p1e2)+ np.cos(s32p2e2-s31p2e2)+ np.cos(s32p3e2-s31p3e2)

    r32 = prob(H322)/prob(H32)
    x32 = np.random.choice([random.uniform(0, 1)])
    if r32>=x32:
        s32p1n = s32p1e2
        s32p2n = s32p2e2
        s32p3n = s32p3e2

        s32p1 = s32p1e2
        s32p2 = s32p2e2
        s32p3 = s32p3e2
    else:
        s32p1n = s32p1
        s32p2n = s32p2
        s32p3n = s32p3
    if s32p1n>=s32p2n>=s32p3n:
        s32= -1
    if s32p2n>=s32p1n>=s32p3n:    
        s32=1
    if s32p3n>=s32p2n>=s32p1n:   
        s32=1
    if s32p3n>=s32p1n>=s32p2n:    
        s32= -1     
    if s32p1n>=s32p3n>=s32p2n:
        s32=1    
    if s32p2n>=s32p3n>=s32p1n:    
        s32= -1    
         
    s32p1e2 = s32p1
    s32p2e2 = s32p2
    s32p3e2 = s32p3        
    
    s33p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site33    
    H33 =- np.cos(s33p3-s33p1)- np.cos(s33p2-s33p3)- np.cos(s33p1-s33p2)+ np.cos(s33p1-s23p1)+ np.cos(s33p2-s23p2)+ np.cos(s33p3-s23p3)+ np.cos(s33p1-s43p1)+ np.cos(s33p2-s43p2)+ np.cos(s33p3-s43p3)+ np.cos(s33p1-s34p1)+ np.cos(s33p2-s34p2)+ np.cos(s33p3-s34p3)+ np.cos(s33p1-s32p1)+ np.cos(s33p2-s32p2)+ np.cos(s33p3-s32p3)

    H332 =- np.cos(s33p3e2-s33p1e2)- np.cos(s33p2e2-s33p3e2)- np.cos(s33p1e2-s33p2e2)+ np.cos(s33p1e2-s23p1e2)+ np.cos(s33p2e2-s23p2e2)+ np.cos(s33p3e2-s23p3e2)+ np.cos(s33p1e2-s43p1e2)+ np.cos(s33p2e2-s43p2e2)+ np.cos(s33p3e2-s43p3e2)+ np.cos(s33p1e2-s34p1e2)+ np.cos(s33p2e2-s34p2e2)+ np.cos(s33p3e2-s34p3e2)+ np.cos(s33p1e2-s32p1e2)+ np.cos(s33p2e2-s32p2e2)+ np.cos(s33p3e2-s32p3e2)

    r33 = prob(H332)/prob(H33)
    x33 = np.random.choice([random.uniform(0, 1)])
    if r33>=x33:
        s33p1n = s33p1e2
        s33p2n = s33p2e2
        s33p3n = s33p3e2
        
        s33p1 = s33p1e2
        s33p2 = s33p2e2
        s33p3 = s33p3e2
        
    else:
        s33p1n = s33p1
        s33p2n = s33p2
        s33p3n = s33p3
    if s33p1n>=s33p2n>=s33p3n:
        s33= -1
    if s33p2n>=s33p1n>=s33p3n:    
        s33=1
    if s33p3n>=s33p2n>=s33p1n:   
        s33=1
    if s33p3n>=s33p1n>=s33p2n:    
        s33= -1     
    if s33p1n>=s33p3n>=s33p2n:
        s33=1    
    if s33p2n>=s33p3n>=s33p1n:    
        s33= -1
      
    s33p1e2 = s33p1
    s33p2e2 = s33p2
    s33p3e2 = s33p3

    s34p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site34    
    H34 =- np.cos(s34p3-s34p1)- np.cos(s34p2-s34p3)- np.cos(s34p1-s34p2)+ np.cos(s34p1-s24p1)+ np.cos(s34p2-s24p2)+ np.cos(s34p3-s24p3)+ np.cos(s34p1-s44p1)+ np.cos(s34p2-s44p2)+ np.cos(s34p3-s44p3)+ np.cos(s34p1-s35p1)+ np.cos(s34p2-s35p2)+ np.cos(s34p3-s35p3)+ np.cos(s34p1-s33p1)+ np.cos(s34p2-s33p2)+ np.cos(s34p3-s33p3)

    H342 =- np.cos(s34p3e2-s34p1e2)- np.cos(s34p2e2-s34p3e2)- np.cos(s34p1e2-s34p2e2)+ np.cos(s34p1e2-s24p1e2)+ np.cos(s34p2e2-s24p2e2)+ np.cos(s34p3e2-s24p3e2)+ np.cos(s34p1e2-s44p1e2)+ np.cos(s34p2e2-s44p2e2)+ np.cos(s34p3e2-s44p3e2)+ np.cos(s34p1e2-s35p1e2)+ np.cos(s34p2e2-s35p2e2)+ np.cos(s34p3e2-s35p3e2)+ np.cos(s34p1e2-s33p1e2)+ np.cos(s34p2e2-s33p2e2)+ np.cos(s34p3e2-s33p3e2)

    r34 = prob(H342)/prob(H34)
    x34 = np.random.choice([random.uniform(0, 1)])
    if r34>=x34:
        s34p1n = s34p1e2
        s34p2n = s34p2e2
        s34p3n = s34p3e2
        
        s34p1 = s34p1e2
        s34p2 = s34p2e2
        s34p3 = s34p3e2

    else:
        s34p1n = s34p1
        s34p2n = s34p2
        s34p3n = s34p3
    if s34p1n>=s34p2n>=s34p3n:
        s34= -1
    if s34p2n>=s34p1n>=s34p3n:    
        s34=1
    if s34p3n>=s34p2n>=s34p1n:   
        s34=1
    if s34p3n>=s34p1n>=s34p2n:    
        s34= -1     
    if s34p1n>=s34p3n>=s34p2n:
        s34=1    
    if s34p2n>=s34p3n>=s34p1n:    
        s34= -1    
       
    s34p1e2 = s34p1
    s34p2e2 = s34p2
    s34p3e2 = s34p3

    s35p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site35    
    H35 =- np.cos(s35p3-s35p1)- np.cos(s35p2-s35p3)- np.cos(s35p1-s35p2)+ np.cos(s35p1-s25p1)+ np.cos(s35p2-s25p2)+ np.cos(s35p3-s25p3)+ np.cos(s35p1-s45p1)+ np.cos(s35p2-s45p2)+ np.cos(s35p3-s45p3)+ np.cos(s35p1-s34p1)+ np.cos(s35p2-s34p2)+ np.cos(s35p3-s34p3)+ np.cos(s35p1-s31p1)+ np.cos(s35p2-s31p2)+ np.cos(s35p3-s31p3)

    H352 =- np.cos(s35p3e2-s35p1e2)- np.cos(s35p2e2-s35p3e2)- np.cos(s35p1e2-s35p2e2)+ np.cos(s35p1e2-s25p1e2)+ np.cos(s35p2e2-s25p2e2)+ np.cos(s35p3e2-s25p3e2)+ np.cos(s35p1e2-s45p1e2)+ np.cos(s35p2e2-s45p2e2)+ np.cos(s35p3e2-s45p3e2)+ np.cos(s35p1e2-s34p1e2)+ np.cos(s35p2e2-s34p2e2)+ np.cos(s35p3e2-s34p3e2)+ np.cos(s35p1e2-s31p1e2)+ np.cos(s35p2e2-s31p2e2)+ np.cos(s35p3e2-s31p3e2)

    r35 = prob(H352)/prob(H35)
    x35 = np.random.choice([random.uniform(0, 1)])
    if r35>=x35:
        s35p1n = s35p1e2
        s35p2n = s35p2e2
        s35p3n = s35p3e2
        
        s35p1 = s35p1e2
        s35p2 = s35p2e2
        s35p3 = s35p3e2

    else:
        s35p1n = s35p1
        s35p2n = s35p2
        s35p3n = s35p3
    if s35p1n>=s35p2n>=s35p3n:
        s35= -1
    if s35p2n>=s35p1n>=s35p3n:    
        s35=1
    if s35p3n>=s35p2n>=s35p1n:   
        s35=1
    if s35p3n>=s35p1n>=s35p2n:    
        s35= -1     
    if s35p1n>=s35p3n>=s35p2n:
        s35=1    
    if s35p2n>=s35p3n>=s35p1n:    
        s35= -1    
   
    s35p1e2 = s35p1
    s35p2e2 = s35p2
    s35p3e2 = s35p3

    s41p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site41    
    H41 =- np.cos(s41p3-s41p1)- np.cos(s41p2-s41p3)- np.cos(s41p1-s41p2)+ np.cos(s41p1-s31p1)+ np.cos(s41p2-s31p2)+ np.cos(s41p3-s31p3)+ np.cos(s41p1-s1p1)+ np.cos(s41p2-s1p2)+ np.cos(s41p3-s1p3)+ np.cos(s41p1-s42p1)+ np.cos(s41p2-s42p2)+ np.cos(s41p3-s42p3)+ np.cos(s41p1-s45p1)+ np.cos(s41p2-s45p2)+ np.cos(s41p3-s45p3)

    H412 =- np.cos(s41p3e2-s41p1e2)- np.cos(s41p2e2-s41p3e2)- np.cos(s41p1e2-s41p2e2)+ np.cos(s41p1e2-s31p1e2)+ np.cos(s41p2e2-s31p2e2)+ np.cos(s41p3e2-s31p3e2)+ np.cos(s41p1e2-s1p1e2)+ np.cos(s41p2e2-s1p2e2)+ np.cos(s41p3e2-s1p3e2)+ np.cos(s41p1e2-s42p1e2)+ np.cos(s41p2e2-s42p2e2)+ np.cos(s41p3e2-s42p3e2)+ np.cos(s41p1e2-s45p1e2)+ np.cos(s41p2e2-s45p2e2)+ np.cos(s41p3e2-s45p3e2)

    r41 = prob(H412)/prob(H41)
    x41 = np.random.choice([random.uniform(0, 1)])
    if r41>=x41:
        s41p1n = s41p1e2
        s41p2n = s41p2e2
        s41p3n = s41p3e2
        
        s41p1 = s41p1e2
        s41p2 = s41p2e2
        s41p3 = s41p3e2

    else:
        s41p1n = s41p1
        s41p2n = s41p2
        s41p3n = s41p3
    if s41p1n>=s41p2n>=s41p3n:
        s41= -1
    if s41p2n>=s41p1n>=s41p3n:    
        s41=1
    if s41p3n>=s41p2n>=s41p1n:   
        s41=1
    if s41p3n>=s41p1n>=s41p2n:    
        s41= -1     
    if s41p1n>=s41p3n>=s41p2n:
        s41=1    
    if s41p2n>=s41p3n>=s41p1n:    
        s41= -1  
   
    s41p1e2 = s41p1
    s41p2e2 = s41p2
    s41p3e2 = s42p3

    s42p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site42    
    H42 =- np.cos(s42p3-s42p1)- np.cos(s42p2-s42p3)- np.cos(s42p1-s42p2)+ np.cos(s42p1-s32p1)+ np.cos(s42p2-s32p2)+ np.cos(s42p3-s32p3)+ np.cos(s42p1-s2p1)+ np.cos(s42p2-s2p2)+ np.cos(s42p3-s2p3)+ np.cos(s42p1-s43p1)+ np.cos(s42p2-s43p2)+ np.cos(s42p3-s43p3)+ np.cos(s42p1-s41p1)+ np.cos(s42p2-s41p2)+ np.cos(s42p3-s41p3)

    H422 =- np.cos(s42p3e2-s42p1e2)- np.cos(s42p2e2-s42p3e2)- np.cos(s42p1e2-s42p2e2)+ np.cos(s42p1e2-s32p1e2)+ np.cos(s42p2e2-s32p2e2)+ np.cos(s42p3e2-s32p3e2)+ np.cos(s42p1e2-s2p1e2)+ np.cos(s42p2e2-s2p2e2)+ np.cos(s42p3e2-s2p3e2)+ np.cos(s42p1e2-s43p1e2)+ np.cos(s42p2e2-s43p2e2)+ np.cos(s42p3e2-s43p3e2)+ np.cos(s42p1e2-s41p1e2)+ np.cos(s42p2e2-s41p2e2)+ np.cos(s42p3e2-s41p3e2)

    r42 = prob(H422)/prob(H42)
    x42 = np.random.choice([random.uniform(0, 1)])
    if r42>=x42:
        s42p1n = s42p1e2
        s42p2n = s42p2e2
        s42p3n = s42p3e2
        
        s42p1 = s42p1e2
        s42p2 = s42p2e2
        s42p3 = s42p3e2

    else:
        s42p1n = s42p1
        s42p2n = s42p2
        s42p3n = s42p3
    if s42p1n>=s42p2n>=s42p3n:
        s42= -1
    if s42p2n>=s42p1n>=s42p3n:    
        s42=1
    if s42p3n>=s42p2n>=s42p1n:   
        s42=1
    if s42p3n>=s42p1n>=s42p2n:    
        s42= -1     
    if s42p1n>=s42p3n>=s42p2n:
        s42=1    
    if s42p2n>=s42p3n>=s42p1n:    
        s42= -1    
  
    s42p1e2 = s42p1
    s42p2e2 = s42p2
    s42p3e2 = s42p3

    s43p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site43    
    H43 =- np.cos(s43p3-s43p1)- np.cos(s43p2-s43p3)- np.cos(s43p1-s43p2)+ np.cos(s43p1-s33p1)+ np.cos(s43p2-s33p2)+ np.cos(s43p3-s33p3)+ np.cos(s43p1-s3p1)+ np.cos(s43p2-s3p2)+ np.cos(s43p3-s3p3)+ np.cos(s43p1-s44p1)+ np.cos(s43p2-s44p2)+ np.cos(s43p3-s44p3)+ np.cos(s43p1-s42p1)+ np.cos(s43p2-s42p2)+ np.cos(s43p3-s42p3)

    H432 =- np.cos(s43p3e2-s43p1e2)- np.cos(s43p2e2-s43p3e2)- np.cos(s43p1e2-s43p2e2)+ np.cos(s43p1e2-s33p1e2)+ np.cos(s43p2e2-s33p2e2)+ np.cos(s43p3e2-s33p3e2)+ np.cos(s43p1e2-s3p1e2)+ np.cos(s43p2e2-s3p2e2)+ np.cos(s43p3e2-s3p3e2)+ np.cos(s43p1e2-s44p1e2)+ np.cos(s43p2e2-s44p2e2)+ np.cos(s43p3e2-s44p3e2)+ np.cos(s43p1e2-s42p1e2)+ np.cos(s43p2e2-s42p2e2)+ np.cos(s43p3e2-s42p3e2)

    r43 = prob(H432)/prob(H43)
    x43 = np.random.choice([random.uniform(0, 1)])
    if r43>=x43:
        s43p1n = s43p1e2
        s43p2n = s43p2e2
        s43p3n = s43p3e2
        
        s43p1 = s43p1e2
        s43p2 = s43p2e2
        s43p3 = s43p3e2

    else:
        s43p1n = s43p1
        s43p2n = s43p2
        s43p3n = s43p3
    if s43p1n>=s43p2n>=s43p3n:
        s43= -1
    if s43p2n>=s43p1n>=s43p3n:    
        s43=1
    if s43p3n>=s43p2n>=s43p1n:   
        s43=1
    if s43p3n>=s43p1n>=s43p2n:    
        s43= -1     
    if s43p1n>=s43p3n>=s43p2n:
        s43=1    
    if s43p2n>=s43p3n>=s43p1n:    
        s43= -1 
   
    s43p1e2 = s43p1
    s43p2e2 = s43p2
    s43p3e2 = s43p3

    s44p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site44    
    H44 =- np.cos(s44p3-s44p1)- np.cos(s44p2-s44p3)- np.cos(s44p1-s44p2)+ np.cos(s44p1-s34p1)+ np.cos(s44p2-s34p2)+ np.cos(s44p3-s34p3)+ np.cos(s44p1-s4p1)+ np.cos(s44p2-s4p2)+ np.cos(s44p3-s4p3)+ np.cos(s44p1-s45p1)+ np.cos(s44p2-s45p2)+ np.cos(s44p3-s45p3)+ np.cos(s44p1-s43p1)+ np.cos(s44p2-s43p2)+ np.cos(s44p3-s43p3)

    H442 =- np.cos(s44p3e2-s44p1e2)- np.cos(s44p2e2-s44p3e2)- np.cos(s44p1e2-s44p2e2)+ np.cos(s44p1e2-s34p1e2)+ np.cos(s44p2e2-s34p2e2)+ np.cos(s44p3e2-s34p3e2)+ np.cos(s44p1e2-s4p1e2)+ np.cos(s44p2e2-s4p2e2)+ np.cos(s44p3e2-s4p3e2)+ np.cos(s44p1e2-s45p1e2)+ np.cos(s44p2e2-s45p2e2)+ np.cos(s44p3e2-s45p3e2)+ np.cos(s44p1e2-s43p1e2)+ np.cos(s44p2e2-s43p2e2)+ np.cos(s44p3e2-s43p3e2)

    r44 = prob(H442)/prob(H44)
    x44 = np.random.choice([random.uniform(0, 1)])
    if r44>=x44:
        s44p1n = s44p1e2
        s44p2n = s44p2e2
        s44p3n = s44p3e2
        
        s44p1 = s44p1e2
        s44p2 = s44p2e2
        s44p3 = s44p3e2
 
    else:
        s44p1n = s44p1
        s44p2n = s44p2
        s44p3n = s44p3
    if s44p1n>=s44p2n>=s44p3n:
        s44= -1
    if s44p2n>=s44p1n>=s44p3n:    
        s44=1
    if s44p3n>=s44p2n>=s44p1n:   
        s44=1
    if s44p3n>=s44p1n>=s44p2n:    
        s44= -1     
    if s44p1n>=s44p3n>=s44p2n:
        s44=1    
    if s44p2n>=s44p3n>=s44p1n:    
        s44= -1            
    s44p1e2 = s44p1
    s44p2e2 = s44p2
    s44p3e2 = s44p3
    
    s45p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])        
#site45    
    H45 =- np.cos(s45p3-s45p1)- np.cos(s45p2-s45p3)- np.cos(s45p1-s45p2)+ np.cos(s45p1-s35p1)+ np.cos(s45p2-s35p2)+ np.cos(s45p3-s35p3)+ np.cos(s45p1-s5p1)+ np.cos(s45p2-s5p2)+ np.cos(s45p3-s5p3)+ np.cos(s45p1-s44p1)+ np.cos(s45p2-s44p2)+ np.cos(s45p3-s44p3)+ np.cos(s45p1-s41p1)+ np.cos(s45p2-s41p2)+ np.cos(s45p3-s41p3)

    H452 =- np.cos(s45p3e2-s45p1e2)- np.cos(s45p2e2-s45p3e2)- np.cos(s45p1e2-s45p2e2)+ np.cos(s45p1e2-s35p1e2)+ np.cos(s45p2e2-s35p2e2)+ np.cos(s45p3e2-s35p3e2)+ np.cos(s45p1e2-s5p1e2)+ np.cos(s45p2e2-s5p2e2)+ np.cos(s45p3e2-s5p3e2)+ np.cos(s45p1e2-s44p1e2)+ np.cos(s45p2e2-s44p2e2)+ np.cos(s45p3e2-s44p3e2)+ np.cos(s45p1e2-s41p1e2)+ np.cos(s45p2e2-s41p2e2)+ np.cos(s45p3e2-s41p3e2)

    r45 = prob(H452)/prob(H45)
    x45 = np.random.choice([random.uniform(0, 1)])
    if r45>=x45:
        s45p1n = s45p1e2
        s45p2n = s45p2e2
        s45p3n = s45p3e2
        
        s45p1 = s45p1e2
        s45p2 = s45p2e2
        s45p3 = s45p3e2

    else:
        s45p1n = s45p1
        s45p2n = s45p2
        s45p3n = s45p3
    if s45p1n>=s45p2n>=s45p3n:
        s45= -1
    if s45p2n>=s45p1n>=s45p3n:    
        s45=1
    if s45p3n>=s45p2n>=s45p1n:   
        s45=1
    if s45p3n>=s45p1n>=s45p2n:    
        s45= -1     
    if s45p1n>=s45p3n>=s45p2n:
        s45=1    
    if s45p2n>=s45p3n>=s45p1n:    
        s45= -1  
    if J<2000:
        J=J+1
    else:
        s.append(s1)
        s.append(s2)
        s.append(s3)
        s.append(s4)
        s.append(s5)
        s.append(s11)
        s.append(s12)
        s.append(s13)
        s.append(s14)
        s.append(s15)
        s.append(s21)
        s.append(s22)
        s.append(s23)
        s.append(s24)
        s.append(s25)
        s.append(s31)
        s.append(s32)
        s.append(s33)
        s.append(s34)
        s.append(s35)
        s.append(s41)
        s.append(s42)
        s.append(s43)
        s.append(s44)
        s.append(s45)
        S.append(abs(mean(s)))
C=0
s1s=0
while s1s<=499:
    S1= S[s1s]
    s1s=s1s+1
    C=C+np.sqrt(abs(-(1/2500)*((1/2500)*S1**2)-((1/2500)*S1)**2))
print(C)
C1.append(C)

k=1
s1p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s2p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s11p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s31p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s41p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s32p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s42p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s43p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s44p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s33p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s34p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s35p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s45p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s12p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s3p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s13p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s14p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s15p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s21p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s22p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s23p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s24p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s25p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s4p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s5p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p3 = np.random.choice([random.uniform(0, 2*np.pi)])
T=0.1
b= k/T
s = []
def prob(H):
    return np.exp(H*b) 

S = []
T1=[]
J=0

for i in range(5000):
    s1p1e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    s1p2e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    s1p3e2 =np.random.choice([random.uniform(0, 2*np.pi)])

    s2p1e2 =s2p1
    s2p2e2 =s2p2
    s2p3e2 =s2p3
    
    s11p1e2 = s11p1
    s11p2e2 = s11p2
    s11p3e2 = s11p3
    
    s31p1e2 = s31p1
    s31p2e2 = s31p2
    s31p3e2 = s31p3
    
    s41p1e2 = s41p1
    s41p2e2 = s41p2
    s41p3e2 = s41p3
    
    s42p1e2 = s42p1
    s42p2e2 = s42p2
    s42p3e2 = s42p3
    
    s43p1e2 = s43p1
    s43p2e2 = s43p2
    s43p3e2 = s43p3
    
    s44p1e2 = s44p1
    s44p2e2 = s44p2
    s44p3e2 = s44p3
    
    s32p1e2 = s32p1
    s32p2e2 = s32p2
    s32p3e2 = s32p3
    
    s33p1e2 = s33p1
    s33p2e2 = s33p2
    s33p3e2 = s33p3
    
    s34p1e2 = s34p1
    s34p2e2 = s34p2
    s34p3e2 = s34p3
    
    s35p1e2 = s35p1
    s35p2e2 = s35p2
    s35p3e2 = s35p3
    
    s45p1e2 = s45p1
    s45p2e2 = s45p2
    s45p3e2 = s45p3
    
    s12p1e2 = s12p1
    s12p2e2 = s12p2
    s12p3e2 = s12p3
    
    s13p1e2 = s13p1
    s13p2e2 = s13p2
    s13p3e2 = s13p3
    
    s3p1e2 = s3p1
    s3p2e2 = s3p2
    s3p3e2 = s3p3
    
    s4p1e2 = s4p1
    s4p2e2 = s4p2
    s4p3e2 = s4p3
    
    s14p1e2 = s14p1
    s14p2e2 = s14p2
    s14p3e2 = s14p3
    
    s15p1e2 = s15p1
    s15p2e2 = s15p2
    s15p3e2 = s15p3
    
    s21p1e2 = s21p1
    s21p2e2 = s21p2
    s21p3e2 = s21p3
    
    s5p1e2 = s5p1
    s5p2e2 = s5p2
    s5p3e2 = s5p3
    
    s22p1e2 = s22p1
    s22p2e2 = s22p2
    s22p3e2 = s22p3
    
    s23p1e2 = s23p1
    s23p2e2 = s23p2
    s23p3e2 = s23p3
    
    s24p1e2 = s24p1
    s24p2e2 = s24p2
    s24p3e2 = s24p3
    
    s25p1e2 = s25p1
    s25p2e2 = s25p2
    s25p3e2 = s25p3
#site1        
    H1 = - np.cos(s1p1-s1p2) - np.cos(s1p2-s1p3)- np.cos(s1p3-s1p1)+ np.cos(s1p1-s2p1)+ np.cos(s1p2-s2p2)+ np.cos(s1p3-s2p3)+ np.cos(s1p1-s11p1)+ np.cos(s1p2-s11p2)+ np.cos(s1p3-s11p3)+ np.cos(s1p1-s41p1)+ np.cos(s1p2-s41p2)+ np.cos(s1p3-s41p3)+ np.cos(s1p1-s5p1)+ np.cos(s1p2-s5p2)+ np.cos(s1p3-s5p3)
    
    H12 = - np.cos(s1p1e2-s1p2e2)- np.cos(s1p3e2-s1p1e2)- np.cos(s1p2e2-s1p3e2)+ np.cos(s1p1e2-s2p1e2)+ np.cos(s1p2e2-s2p2e2)+ np.cos(s1p3e2-s2p3e2)+ np.cos(s1p1e2-s11p1e2)+ np.cos(s1p2e2-s11p2e2)+ np.cos(s1p3e2-s11p3e2)+ np.cos(s1p1e2-s41p1e2)+ np.cos(s1p2e2-s41p2e2)+ np.cos(s1p3e2-s41p3e2)+ np.cos(s1p1e2-s5p1e2)+ np.cos(s1p2e2-s5p2e2)+ np.cos(s1p3e2-s5p3e2)

    r= prob(H12)/prob(H1)
    x= np.random.choice([random.uniform(0, 1)])
    if r >= x:
        s1p1n = s1p1e2
        s1p2n = s1p2e2
        s1p3n = s1p3e2
        
        s1p1 = s1p1e2
        s1p2 = s1p2e2
        s1p3 = s1p3e2
        
    else:
        s1p1n = s1p1
        s1p2n = s1p2
        s1p3n = s1p3
    if s1p1n>=s1p2n>=s1p3n:
        s1= -1
    if s1p2n>=s1p1n>=s1p3n:    
        s1=1
    if s1p3n>=s1p2n>=s1p1n:   
        s1=1
    if s1p3n>=s1p1n>=s1p2n:    
        s1= -1     
    if s1p1n>=s1p3n>=s1p2n:
        s1=1    
    if s1p2n>=s1p3n>=s1p1n:    
        s1= -1    
  
    s1p1e2 =s1p1
    s1p2e2 =s1p2
    s1p3e2 =s1p3
    
    s2p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site2    
    H2 = - np.cos(s2p2-s2p3)- np.cos(s2p3-s2p1)- np.cos(s2p1-s2p2)+ np.cos(s2p1-s12p1)+ np.cos(s2p2-s12p2)+ np.cos(s2p3-s12p3)+ np.cos(s2p1-s1p1)+ np.cos(s2p2-s1p2)+ np.cos(s2p3-s1p2)+ np.cos(s2p1-s3p1)+ np.cos(s2p2-s3p2)+ np.cos(s2p3-s3p3)+ np.cos(s2p1-s42p1)+ np.cos(s2p2-s42p2)+ np.cos(s2p3-s42p3)

    H22 =- np.cos(s2p3e2-s2p1e2)- np.cos(s2p2e2-s2p3e2)- np.cos(s2p1e2-s2p2e2)+ np.cos(s2p1e2-s1p1e2)+ np.cos(s2p2e2-s1p2e2)+ np.cos(s2p3e2-s1p3e2)+ np.cos(s2p1e2-s12p1e2)+ np.cos(s2p2e2-s12p2e2)+ np.cos(s2p3e2-s12p3e2)+ np.cos(s2p1e2-s3p1e2)+ np.cos(s2p2e2-s3p2e2)+ np.cos(s2p3e2-s3p3e2)+ np.cos(s2p1e2-s42p1e2)+ np.cos(s2p2e2-s42p2e2)+ np.cos(s2p3e2-s42p3e2)

    r1 = prob(H22)/prob(H2)
    x1 = np.random.choice([random.uniform(0, 1)])
    if r1 >= x1:
        s2p1n = s2p1e2
        s2p2n = s2p2e2
        s2p3n = s2p3e2
        
        s2p1 = s2p1e2
        s2p2 = s2p2e2
        s2p3 = s2p3e2
        
    else:
        s2p1n = s2p1
        s2p2n = s2p2
        s2p3n = s2p3
        
    if s2p1n>=s2p2n>=s2p3n:
        s2= -1
    if s2p2n>=s2p1n>=s2p3n:    
        s2=1
    if s2p3n>=s2p2n>=s2p1n:   
        s2=1
    if s2p3n>=s2p1n>=s2p2n:    
        s2= -1     
    if s2p1n>=s2p3n>=s2p2n:
        s2=1    
    if s2p2n>=s2p3n>=s2p1n:    
        s2= -1    

    s2p1e2 = s2p1
    s2p2e2 = s2p2
    s2p3e2 = s2p3
    
    s3p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site3    
    H3 = -np.cos(s3p2-s3p3)- np.cos(s3p3-s3p1)- np.cos(s3p1-s3p2)+ np.cos(s3p1-s2p1)+ np.cos(s3p2-s2p2)+ np.cos(s3p3-s2p3)+ np.cos(s3p1-s13p1)+ np.cos(s3p2-s13p2)+ np.cos(s3p3-s13p3)+ np.cos(s3p1-s4p1)+ np.cos(s3p2-s4p2)+ np.cos(s3p3-s4p3)+ np.cos(s3p1-s43p1)+ np.cos(s3p2-s43p2)+ np.cos(s3p3-s43p3)

    H32 = - np.cos(s3p2e2-s3p3e2)- np.cos(s3p3e2-s3p1e2)- np.cos(s3p1e2-s3p2e2)+ np.cos(s3p1e2-s2p1e2)+ np.cos(s3p2e2-s2p2e2)+ np.cos(s3p3e2-s2p3e2)+ np.cos(s3p1e2-s13p1e2)+ np.cos(s3p2e2-s13p2e2)+ np.cos(s3p3e2-s13p3e2)+ np.cos(s3p1e2-s4p1e2)+ np.cos(s3p2e2-s4p2e2)+ np.cos(s3p3e2-s4p3e2)+ np.cos(s3p1e2-s43p1e2)+ np.cos(s3p2e2-s43p2e2)+ np.cos(s3p3e2-s43p3e2)
  
    r2 = prob(H32)/prob(H3)
    x2 = np.random.choice([random.uniform(0, 1)])
    if r2 >= x2:
        s3p1n = s3p1e2
        s3p2n = s3p2e2
        s3p3n = s3p3e2
        
        s3p1 = s3p1e2
        s3p2 = s3p2e2
        s3p3 = s3p3e2
    else:
        s3p1n = s3p1
        s3p2n = s3p2
        s3p3n = s3p3
    if s3p1n>=s3p2n>=s3p3n:
        s3= -1
    if s3p2n>=s3p1n>=s3p3n:    
        s3=1
    if s3p3n>=s3p2n>=s3p1n:   
        s3=1
    if s3p3n>=s3p1n>=s3p2n:    
        s3= -1     
    if s3p1n>=s3p3n>=s3p2n:
        s3=1    
    if s3p2n>=s3p3n>=s3p1n:    
        s3= -1  
 
    s3p1e2 = s3p1
    s3p2e2 = s3p2
    s3p3e2 = s3p3
    
    s4p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site4    
    H4 = - np.cos(s4p2-s4p3)- np.cos(s4p3-s4p1)- np.cos(s4p1-s4p2)+ np.cos(s4p1-s3p1)+ np.cos(s4p2-s3p2)+ np.cos(s4p3-s3p3)+ np.cos(s4p1-s14p1)+ np.cos(s4p2-s14p2)+ np.cos(s4p3-s14p3)+ np.cos(s4p1-s5p1)+ np.cos(s4p2-s5p2)+ np.cos(s4p3-s5p3)+ np.cos(s4p1-s44p1)+ np.cos(s4p2-s44p2)+ np.cos(s4p3-s44p3)

    H42 = - np.cos(s4p3e2-s4p1e2)- np.cos(s4p2e2-s3p3e2)- np.cos(s4p1e2-s4p2e2)+ np.cos(s4p1e2-s3p1e2)+ np.cos(s4p2e2-s3p2e2)+ np.cos(s4p3e2-s3p3e2)+ np.cos(s4p1e2-s14p1e2)+ np.cos(s4p2e2-s14p2e2)+ np.cos(s4p3e2-s14p3e2)+ np.cos(s4p1e2-s5p1e2)+ np.cos(s4p2e2-s5p2e2)+ np.cos(s4p3e2-s5p3e2)+ np.cos(s4p1e2-s44p1e2)+ np.cos(s4p2e2-s44p2e2)+ np.cos(s4p3e2-s44p3e2)

    r3 = prob(H42)/prob(H4)
    x3 = np.random.choice([random.uniform(0, 1)])
    if r3 >= x3:
        s4p1n = s4p1e2
        s4p2n = s4p2e2
        s4p3n = s4p3e2
        
        s4p1 = s4p1e2
        s4p2 = s4p2e2
        s4p3 = s4p3e2
    else:
        s4p1n = s4p1
        s4p2n = s4p2
        s4p3n = s4p3
    if s4p1n>=s4p2n>=s4p3n:
        s4= -1
    if s4p2n>=s4p1n>=s4p3n:    
        s4=1
    if s4p3n>=s4p2n>=s4p1n:   
        s4=1
    if s4p3n>=s4p1n>=s4p2n:    
        s4= -1     
    if s4p1n>=s4p3n>=s4p2n:
        s4=1    
    if s4p2n>=s4p3n>=s4p1n:    
        s4= -1    

    s4p1e2 = s4p1
    s4p2e2 = s4p2
    s4p3e2 = s4p3
    
    s5p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site5    
    H5 =- np.cos(s5p2-s5p3)- np.cos(s5p3-s5p1)- np.cos(s5p1-s5p2)+ np.cos(s5p1-s4p1)+ np.cos(s5p2-s4p2)+ np.cos(s5p3-s4p3)+ np.cos(s5p1-s15p1)+ np.cos(s5p2-s15p2)+ np.cos(s5p3-s15p3)+ np.cos(s5p1-s45p1)+ np.cos(s5p2-s45p2)+ np.cos(s5p3-s45p3)+ np.cos(s5p1-s1p1)+ np.cos(s5p2-s1p2)+ np.cos(s5p3-s1p3)

    H52 = - np.cos(s5p3e2-s5p1e2)- np.cos(s5p2e2-s5p3e2)- np.cos(s5p1e2-s5p2e2)+ np.cos(s5p1e2-s4p1e2)+ np.cos(s5p2e2-s4p2e2)+ np.cos(s5p3e2-s4p3e2)+ np.cos(s5p1e2-s15p1e2)+ np.cos(s5p2e2-s15p2e2)+ np.cos(s5p3e2-s15p3e2)+ np.cos(s5p1e2-s45p1e2)+ np.cos(s5p2e2-s45p2e2)+ np.cos(s5p3e2-s45p3e2)+ np.cos(s5p1e2-s1p1e2)+ np.cos(s5p2e2-s1p2e2)+ np.cos(s5p3e2-s1p3e2)

    r4 = prob(H52)/prob(H5)
    x4 = np.random.choice([random.uniform(0, 1)])
    if r4 >= x4:
        s5p1n = s5p1e2
        s5p2n = s5p2e2
        s5p3n = s5p3e2
        
        s5p1 = s5p1e2
        s5p2 = s5p2e2
        s5p3 = s5p3e2
    else:
        s5p1n = s5p1
        s5p2n = s5p2
        s5p3n = s5p3
    if s5p1n>=s5p2n>=s5p3n:
        s5= -1
    if s5p2n>=s5p1n>=s5p3n:    
        s5=1
    if s5p3n>=s5p2n>=s5p1n:   
        s5=1
    if s5p3n>=s5p1n>=s5p2n:    
        s5= -1     
    if s5p1n>=s5p3n>=s5p2n:
        s5=1    
    if s5p2n>=s5p3n>=s5p1n:    
        s5= -1   
          
    s5p1e2 = s5p1
    s5p2e2 = s5p2
    s5p3e2 = s5p3
    
    s11p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site11    
    H11 =- np.cos(s11p3-s11p1)- np.cos(s11p2-s11p3)- np.cos(s11p1-s11p2)+ np.cos(s11p1-s1p1)+ np.cos(s11p2-s1p2)+ np.cos(s11p3-s1p3)+ np.cos(s11p1-s12p1)+ np.cos(s11p2-s12p2)+ np.cos(s11p3-s12p3)+ np.cos(s11p1-s21p1)+ np.cos(s11p2-s21p2)+ np.cos(s11p3-s21p3)+ np.cos(s11p1-s15p1)+ np.cos(s11p2-s15p2)+ np.cos(s11p3-s15p3)

    H112 =- np.cos(s11p3e2-s11p1e2)- np.cos(s11p2e2-s11p3e2)- np.cos(s11p1e2-s11p2e2)+ np.cos(s11p1e2-s1p1e2)+ np.cos(s11p2e2-s1p2e2)+ np.cos(s11p3e2-s1p3e2)+ np.cos(s11p1e2-s12p1e2)+ np.cos(s11p2e2-s12p2e2)+ np.cos(s11p3e2-s12p3e2)+ np.cos(s11p1e2-s21p1e2)+ np.cos(s11p2e2-s21p2e2)+ np.cos(s11p3e2-s21p3e2)+ np.cos(s11p1e2-s15p1e2)+ np.cos(s11p2e2-s15p2e2)+ np.cos(s11p3e2-s15p3e2)

    r11 = prob(H112)/prob(H11)
    x11 = np.random.choice([random.uniform(0, 1)])
    if r11 >= x11:
        s11p1n = s11p1e2
        s11p2n = s11p2e2
        s11p3n = s11p3e2
        
        s11p1 = s11p1e2
        s11p2 = s11p2e2
        s11p3 = s11p3e2
        
    else:
        s11p1n = s11p1
        s11p2n = s11p2
        s11p3n = s11p3
    if s11p1n>=s11p2n>=s11p3n:
        s11= -1
    if s11p2n>=s11p1n>=s11p3n:    
        s11=1
    if s11p3n>=s11p2n>=s11p1n:   
        s11=1
    if s11p3n>=s11p1n>=s11p2n:    
        s11= -1     
    if s11p1n>=s11p3n>=s11p2n:
        s11=1    
    if s11p2n>=s11p3n>=s11p1n:    
        s11= -1   
          
    s11p1e2 = s11p1
    s11p2e2 = s11p2
    s11p3e2 = s11p3
    
    s12p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site12    
    H12s =- np.cos(s12p3-s12p1)- np.cos(s12p2-s12p3)- np.cos(s12p1-s12p2)+ np.cos(s12p1-s2p1)+ np.cos(s12p2-s2p2)+ np.cos(s12p3-s2p3)+ np.cos(s12p1-s13p1)+ np.cos(s12p2-s13p2)+ np.cos(s12p3-s13p3)+ np.cos(s12p1-s22p1)+ np.cos(s12p2-s22p2)+ np.cos(s12p3-s22p3)+ np.cos(s12p1-s11p1)+ np.cos(s12p2-s11p2)+ np.cos(s12p3-s11p3)

    H122 =- np.cos(s12p3e2-s12p1e2)- np.cos(s12p2e2-s12p3e2)- np.cos(s12p1e2-s12p2e2)+ np.cos(s12p1e2-s2p1e2)+ np.cos(s12p2e2-s2p2e2)+ np.cos(s12p3e2-s2p3e2)+ np.cos(s12p1e2-s13p1e2)+ np.cos(s12p2e2-s13p2e2)+ np.cos(s12p3e2-s13p3e2)+ np.cos(s12p1e2-s22p1e2)+ np.cos(s12p2e2-s22p2e2)+ np.cos(s12p3e2-s22p3e2)+ np.cos(s12p1e2-s11p1e2)+ np.cos(s12p2e2-s11p2e2)+ np.cos(s12p3e2-s11p3e2)

    r12 = prob(H122)/prob(H12s)
    x12 = np.random.choice([random.uniform(0, 1)])
    if r12 >= x12:
        s12p1n = s12p1e2
        s12p2n = s12p2e2
        s12p3n = s12p3e2
        
        s12p1 = s12p1e2
        s12p2 = s12p2e2
        s12p3 = s12p3e2
        
    else:
        s12p1n = s12p1
        s12p2n = s12p2
        s12p3n = s12p3
    if s12p1n>=s12p2n>=s12p3n:
        s12= -1
    if s12p2n>=s12p1n>=s12p3n:    
        s12=1
    if s12p3n>=s12p2n>=s12p1n:   
        s12=1
    if s12p3n>=s12p1n>=s12p2n:    
        s12= -1     
    if s12p1n>=s12p3n>=s12p2n:
        s12=1    
    if s12p2n>=s12p3n>=s12p1n:    
        s12= -1    
    
    s12p1e2 = s12p1
    s12p2e2 = s12p2
    s12p3e2 = s12p3
    
    s13p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site13    
    H13 =- np.cos(s13p3-s13p1)- np.cos(s13p2-s13p3)- np.cos(s13p1-s13p2)+ np.cos(s13p1-s3p1)+ np.cos(s13p2-s3p2)+ np.cos(s13p3-s3p3)+ np.cos(s13p1-s14p1)+ np.cos(s13p2-s14p2)+ np.cos(s13p3-s14p3)+ np.cos(s13p1-s23p1)+ np.cos(s13p2-s23p2)+ np.cos(s13p3-s23p3)+ np.cos(s13p1-s12p1)+ np.cos(s13p2-s12p2)+ np.cos(s13p3-s12p3)

    H132 =- np.cos(s13p3e2-s13p1e2)- np.cos(s13p2e2-s13p3e2)- np.cos(s13p1e2-s13p2e2)+ np.cos(s13p1e2-s3p1e2)+ np.cos(s13p2e2-s3p2e2)+ np.cos(s13p3e2-s3p3e2)+ np.cos(s13p1e2-s14p1e2)+ np.cos(s13p2e2-s14p2e2)+ np.cos(s13p3e2-s14p3e2)+ np.cos(s13p1e2-s23p1e2)+ np.cos(s13p2e2-s23p2e2)+ np.cos(s13p3e2-s23p3e2)+ np.cos(s13p1e2-s12p1e2)+ np.cos(s13p2e2-s12p2e2)+ np.cos(s13p3e2-s12p3e2)

    r13 = prob(H132)/prob(H13)
    x13 = np.random.choice([random.uniform(0, 1)])
    if r13 >= x13:
        s13p1n = s13p1e2
        s13p2n = s13p2e2
        s13p3n = s13p3e2
        
        s13p1 = s13p1e2
        s13p2 = s13p2e2
        s13p3 = s13p3e2
        
    else:
        s13p1n = s13p1
        s13p2n = s13p2
        s13p3n = s13p3
    if s13p1n>=s13p2n>=s13p3n:
        s13= -1
    if s13p2n>=s13p1n>=s13p3n:    
        s13=1
    if s13p3n>=s13p2n>=s13p1n:   
        s13=1
    if s13p3n>=s13p1n>=s13p2n:    
        s13= -1     
    if s13p1n>=s13p3n>=s13p2n:
        s13=1    
    if s13p2n>=s13p3n>=s13p1n:    
        s13= -1  

    s13p1e2 = s13p1
    s13p2e2 = s13p2
    s13p3e2 = s13p3
    
    s14p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site14    
    H14 =- np.cos(s14p3-s14p1)- np.cos(s14p2-s14p3)- np.cos(s14p1-s14p2)+ np.cos(s14p1-s4p1)+ np.cos(s14p2-s4p2)+ np.cos(s14p3-s4p3)+ np.cos(s14p1-s15p1)+ np.cos(s14p2-s15p2)+ np.cos(s14p3-s15p3)+ np.cos(s14p1-s24p1)+ np.cos(s14p2-s24p2)+ np.cos(s14p3-s24p3)+ np.cos(s14p1-s13p1)+ np.cos(s14p2-s13p2)+ np.cos(s14p3-s13p3)

    H142 =- np.cos(s14p3e2-s14p1e2)- np.cos(s14p2e2-s14p3e2)- np.cos(s14p1e2-s14p2e2)+ np.cos(s14p1e2-s4p1e2)+ np.cos(s14p2e2-s4p2e2)+ np.cos(s14p3e2-s4p3e2)+ np.cos(s14p1e2-s15p1e2)+ np.cos(s14p2e2-s15p2e2)+ np.cos(s14p3e2-s15p3e2)+ np.cos(s14p1e2-s24p1e2)+ np.cos(s14p2e2-s24p2e2)+ np.cos(s14p3e2-s24p3e2)+ np.cos(s14p1e2-s13p1e2)+ np.cos(s14p2e2-s13p2e2)+ np.cos(s14p3e2-s13p3e2)

    r14 = prob(H142)/prob(H14)
    x14 = np.random.choice([random.uniform(0, 1)])
    if r14 >= x14:
        s14p1n = s14p1e2
        s14p2n = s14p2e2
        s14p3n = s14p3e2
        
        s14p1 = s14p1e2
        s14p2 = s14p2e2
        s14p3 = s14p3e2
        
    else:
        s14p1n = s14p1
        s14p2n = s14p2
        s14p3n = s14p3
    if s14p1n>=s14p2n>=s14p3n:
        s14= -1
    if s14p2n>=s14p1n>=s14p3n:    
        s14=1
    if s14p3n>=s14p2n>=s14p1n:   
        s14=1
    if s14p3n>=s14p1n>=s14p2n:    
        s14= -1     
    if s14p1n>=s14p3n>=s14p2n:
        s14=1    
    if s14p2n>=s14p3n>=s14p1n:    
        s14= -1  

    s14p1e2 = s14p1
    s14p2e2 = s14p2
    s14p3e2 = s14p3

    s15p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])                  
#site15    
    H15 =- np.cos(s15p3-s15p1)- np.cos(s15p2-s15p3)- np.cos(s15p1-s15p2)+ np.cos(s15p1-s5p1)+ np.cos(s15p2-s5p2)+ np.cos(s15p3-s5p3)+ np.cos(s15p1-s25p1)+ np.cos(s15p2-s25p2)+ np.cos(s15p3-s25p3)+ np.cos(s15p1-s14p1)+ np.cos(s15p2-s14p2)+ np.cos(s15p3-s14p3)+ np.cos(s15p1-s11p1)+ np.cos(s15p2-s11p2)+ np.cos(s15p3-s11p3)

    H152 =- np.cos(s15p3e2-s15p1e2)- np.cos(s15p2e2-s15p3e2)- np.cos(s15p1e2-s15p2e2)+ np.cos(s15p1e2-s5p1e2)+ np.cos(s15p2e2-s5p2e2)+ np.cos(s15p3e2-s5p3e2)+ np.cos(s15p1e2-s25p1e2)+ np.cos(s15p2e2-s25p2e2)+ np.cos(s15p3e2-s25p3e2)+ np.cos(s15p1e2-s14p1e2)+ np.cos(s15p2e2-s14p2e2)+ np.cos(s15p3e2-s14p3e2)+ np.cos(s15p1e2-s11p1e2)+ np.cos(s15p2e2-s11p2e2)+ np.cos(s15p3e2-s11p3e2)

    r15 = prob(H152)/prob(H15)
    x15 = np.random.choice([random.uniform(0, 1)])
    if r15 >= x15:
        s15p1n = s15p1e2
        s15p2n = s15p2e2
        s15p3n = s15p3e2
        
        s15p1 = s15p1e2
        s15p2 = s15p2e2
        s15p3 = s15p3e2
    else:
        s15p1n = s15p1
        s15p2n = s15p2
        s15p3n = s15p3
    if s15p1n>=s15p2n>=s15p3n:
        s15= -1
    if s15p2n>=s15p1n>=s15p3n:    
        s15=1
    if s15p3n>=s15p2n>=s15p1n:   
        s15=1
    if s15p3n>=s15p1n>=s15p2n:    
        s15= -1     
    if s15p1n>=s15p3n>=s15p2n:
        s15=1    
    if s15p2n>=s15p3n>=s15p1n:    
        s15= -1    

    s15p1e2 = s15p1
    s15p2e2 = s15p2
    s15p3e2 = s15p3

    s21p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
#site21    
    H21 =- np.cos(s21p3-s21p1)- np.cos(s21p2-s21p3)- np.cos(s21p1-s21p2)+ np.cos(s21p1-s11p1)+ np.cos(s21p2-s11p2)+ np.cos(s21p3-s11p3)+ np.cos(s21p1-s31p1)+ np.cos(s21p2-s31p2)+ np.cos(s21p3-s31p3)+ np.cos(s21p1-s22p1)+ np.cos(s21p2-s22p2)+ np.cos(s21p3-s22p3)+ np.cos(s21p1-s25p1)+ np.cos(s21p2-s25p2)+ np.cos(s21p3-s25p3)

    H212 =- np.cos(s21p3e2-s21p1e2)- np.cos(s21p2e2-s21p3e2)- np.cos(s21p1e2-s21p2e2)+ np.cos(s21p1e2-s11p1e2)+ np.cos(s21p2e2-s11p2e2)+ np.cos(s21p3e2-s11p3e2)+ np.cos(s21p1e2-s31p1e2)+ np.cos(s21p2e2-s31p2e2)+ np.cos(s21p3e2-s31p3e2)+ np.cos(s21p1e2-s22p1e2)+ np.cos(s21p2e2-s22p2e2)+ np.cos(s21p3e2-s22p3e2)+ np.cos(s21p1e2-s25p1e2)+ np.cos(s21p2e2-s25p2e2)+ np.cos(s21p3e2-s25p3e2)

    r21 = prob(H212)/prob(H21)
    x21 = np.random.choice([random.uniform(0, 1)])
    if r21 >= x21:
        s21p1n = s21p1e2
        s21p2n = s21p2e2
        s21p3n = s21p3e2
        
        s21p1 = s21p1e2
        s21p2 = s21p2e2
        s21p3 = s21p3e2
  
    else:
        s21p1n = s21p1
        s21p2n = s21p2
        s21p3n = s21p3
    if s21p1n>=s21p2n>=s21p3n:
        s21= -1
    if s21p2n>=s21p1n>=s21p3n:    
        s21=1
    if s21p3n>=s21p2n>=s21p1n:   
        s21=1
    if s21p3n>=s21p1n>=s21p2n:    
        s21= -1     
    if s21p1n>=s21p3n>=s21p2n:
        s21=1    
    if s21p2n>=s21p3n>=s21p1n:    
        s21= -1

    s21p1e2 = s21p1
    s21p2e2 = s21p2
    s21p3e2 = s22p3   

    s22p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])            
#site22    
    H22 =- np.cos(s22p3-s22p1)- np.cos(s22p2-s22p3)- np.cos(s22p1-s22p2)+ np.cos(s22p1-s12p1)+ np.cos(s22p2-s12p2)+ np.cos(s22p3-s12p3)+ np.cos(s22p1-s32p1)+ np.cos(s22p2-s32p2)+ np.cos(s22p3-s32p3)+ np.cos(s22p1-s23p1)+ np.cos(s22p2-s23p2)+ np.cos(s22p3-s23p3)+ np.cos(s22p1-s21p1)+ np.cos(s22p2-s21p2)+ np.cos(s22p3-s21p3)

    H222 =- np.cos(s22p3e2-s22p1e2)- np.cos(s22p2e2-s22p3e2)- np.cos(s22p1e2-s22p2e2)+ np.cos(s22p1e2-s12p1e2)+ np.cos(s22p2e2-s12p2e2)+ np.cos(s22p3e2-s12p3e2)+ np.cos(s22p1e2-s32p1e2)+ np.cos(s22p2e2-s32p2e2)+ np.cos(s22p3e2-s32p3e2)+ np.cos(s22p1e2-s23p1e2)+ np.cos(s22p2e2-s23p2e2)+ np.cos(s22p3e2-s23p3e2)+ np.cos(s22p1e2-s21p1e2)+ np.cos(s22p2e2-s21p2e2)+ np.cos(s22p3e2-s21p3e2)

    r22 = prob(H222)/prob(H22)
    x22 = np.random.choice([random.uniform(0, 1)])
    if r22 >= x22:
        s22p1n = s22p1e2
        s22p2n = s22p2e2
        s22p3n = s22p3e2
        
        s22p1 = s22p1e2
        s22p2 = s22p2e2
        s22p3 = s22p3e2
        
    else:
        s22p1n = s22p1
        s22p2n = s22p2
        s22p3n = s22p3
    if s22p1n>=s22p2n>=s22p3n:
        s22= -1
    if s22p2n>=s22p1n>=s22p3n:    
        s22=1
    if s22p3n>=s22p2n>=s22p1n:   
        s22=1
    if s22p3n>=s22p1n>=s22p2n:    
        s22= -1     
    if s22p1n>=s22p3n>=s22p2n:
        s22=1    
    if s22p2n>=s22p3n>=s22p1n:    
        s22= -1    
   
    s22p1e2 = s22p1
    s22p2e2 = s22p2
    s22p3e2 = s22p3  
    
    s23p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])   
#site23    
    H23 =- np.cos(s23p3-s23p1)- np.cos(s23p2-s23p3)- np.cos(s23p1-s23p2)+ np.cos(s23p1-s13p1)+ np.cos(s23p2-s13p2)+ np.cos(s23p3-s13p3)+ np.cos(s23p1-s33p1)+ np.cos(s23p2-s33p2)+ np.cos(s23p3-s33p3)+ np.cos(s23p1-s24p1)+ np.cos(s23p2-s24p2)+ np.cos(s23p3-s24p3)+ np.cos(s23p1-s22p1)+ np.cos(s23p2-s22p2)+ np.cos(s23p3-s22p3)

    H232 =- np.cos(s23p3e2-s23p1e2)- np.cos(s23p2e2-s23p3e2)- np.cos(s23p1e2-s23p2e2)+ np.cos(s23p1e2-s13p1e2)+ np.cos(s23p2e2-s13p2e2)+ np.cos(s23p3e2-s13p3e2)+ np.cos(s23p1e2-s33p1e2)+ np.cos(s23p2e2-s33p2e2)+ np.cos(s23p3e2-s33p3e2)+ np.cos(s23p1e2-s24p1e2)+ np.cos(s23p2e2-s24p2e2)+ np.cos(s23p3e2-s24p3e2)+ np.cos(s23p1e2-s22p1e2)+ np.cos(s23p2e2-s22p2e2)+ np.cos(s23p3e2-s22p3e2)

    r23 = prob(H232)/prob(H23)
    x23 = np.random.choice([random.uniform(0, 1)])
    if r23>=x23:
        s23p1n = s23p1e2
        s23p2n = s23p2e2
        s23p3n = s23p3e2
        
        s23p1 = s23p1e2
        s23p2 = s23p2e2
        s23p3 = s23p3e2

    else:
        s23p1n = s23p1
        s23p2n = s23p2
        s23p3n = s23p3
    if s23p1n>=s23p2n>=s23p3n:
        s23= -1
    if s23p2n>=s23p1n>=s23p3n:    
        s23=1
    if s23p3n>=s23p2n>=s23p1n:   
        s23=1
    if s23p3n>=s23p1n>=s23p2n:    
        s23= -1     
    if s23p1n>=s23p3n>=s23p2n:
        s23=1    
    if s23p2n>=s23p3n>=s23p1n:    
        s23= -1  
   
    s23p1e2 = s23p1
    s23p2e2 = s23p2
    s23p3e2 = s23p3
    
    s24p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])           
#site24    
    H24 =- np.cos(s24p3-s24p1)- np.cos(s24p2-s24p3)- np.cos(s24p1-s24p2)+ np.cos(s24p1-s14p1)+ np.cos(s24p2-s14p2)+ np.cos(s24p3-s14p3)+ np.cos(s24p1-s34p1)+ np.cos(s24p2-s34p2)+ np.cos(s24p3-s34p3)+ np.cos(s24p1-s25p1)+ np.cos(s24p2-s25p2)+ np.cos(s24p3-s25p3)+ np.cos(s24p1-s23p1)+ np.cos(s24p2-s23p2)+ np.cos(s24p3-s23p3)

    H242 =- np.cos(s24p3e2-s24p1e2)- np.cos(s24p2e2-s24p3e2)- np.cos(s24p1e2-s24p2e2)+ np.cos(s24p1e2-s14p1e2)+ np.cos(s24p2e2-s14p2e2)+ np.cos(s24p3e2-s14p3e2)+ np.cos(s24p1e2-s34p1e2)+ np.cos(s24p2e2-s34p2e2)+ np.cos(s24p3e2-s34p3e2)+ np.cos(s24p1e2-s25p1e2)+ np.cos(s24p2e2-s25p2e2)+ np.cos(s24p3e2-s25p3e2)+ np.cos(s24p1e2-s23p1e2)+ np.cos(s24p2e2-s23p2e2)+ np.cos(s24p3e2-s23p3e2)

    r24 = prob(H242)/prob(H24)
    x24 = np.random.choice([random.uniform(0, 1)])
    if r24>=x24:
        s24p1n = s24p1e2
        s24p2n = s24p2e2
        s24p3n = s24p3e2
        
        s24p1 = s24p1e2
        s24p2 = s24p2e2
        s24p3 = s24p3e2

    else:
        s24p1n = s24p1
        s24p2n = s24p2
        s24p3n = s24p3 
    if s24p1n>=s24p2n>=s24p3n:
        s24= -1
    if s24p2n>=s24p1n>=s24p3n:    
        s24=1
    if s24p3n>=s24p2n>=s24p1n:   
        s24=1
    if s24p3n>=s24p1n>=s24p2n:    
        s24= -1     
    if s24p1n>=s24p3n>=s24p2n:
        s24=1    
    if s24p2n>=s24p3n>=s24p1n:    
        s24= -1  
         
    s24p1e2 = s24p1
    s24p2e2 = s24p2
    s24p3e2 = s24p3 
    
    s25p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
#site25    
    H25 =- np.cos(s25p3-s25p1)- np.cos(s25p2-s25p3)- np.cos(s25p1-s25p2)+ np.cos(s25p1-s15p1)+ np.cos(s25p2-s15p2)+ np.cos(s25p3-s15p3)+ np.cos(s25p1-s35p1)+ np.cos(s25p2-s35p2)+ np.cos(s25p3-s35p3)+ np.cos(s25p1-s24p1)+ np.cos(s25p2-s24p2)+ np.cos(s25p3-s24p3)+ np.cos(s25p1-s21p1)+ np.cos(s25p2-s21p2)+ np.cos(s25p3-s21p3)

    H252 =- np.cos(s25p3e2-s25p1e2)- np.cos(s25p2e2-s25p3e2)- np.cos(s25p1e2-s25p2e2)+ np.cos(s25p1e2-s15p1e2)+ np.cos(s25p2e2-s15p2e2)+ np.cos(s25p3e2-s15p3e2)+ np.cos(s25p1e2-s35p1e2)+ np.cos(s25p2e2-s35p2e2)+ np.cos(s25p3e2-s35p3e2)+ np.cos(s25p1e2-s24p1e2)+ np.cos(s25p2e2-s24p2e2)+ np.cos(s25p3e2-s24p3e2)+ np.cos(s25p1e2-s21p1e2)+ np.cos(s25p2e2-s21p2e2)+ np.cos(s25p3e2-s21p3e2)

    r25 = prob(H252)/prob(H25)
    x25 = np.random.choice([random.uniform(0, 1)])
    if r25>=x25:
        s25p1n = s25p1e2
        s25p2n = s25p2e2
        s25p3n = s25p3e2
        
        s25p1 = s25p1e2
        s25p2 = s25p2e2
        s25p3 = s25p3e2

    else:
        s25p1n = s25p1
        s25p2n = s25p2
        s25p3n = s25p3
    if s25p1n>=s25p2n>=s25p3n:
        s25= -1
    if s25p2n>=s25p1n>=s25p3n:    
        s25=1
    if s25p3n>=s25p2n>=s25p1n:   
        s25=1
    if s25p3n>=s25p1n>=s25p2n:    
        s25= -1     
    if s25p1n>=s25p3n>=s25p2n:
        s25=1    
    if s25p2n>=s25p3n>=s25p1n:    
        s25= -1 
  
    s25p1e2 = s25p1
    s25p2e2 = s25p2
    s25p3e2 = s25p3

    s31p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 

#site31    
    H31 =- np.cos(s31p3-s31p1)- np.cos(s31p2-s31p3)- np.cos(s31p1-s31p2)+ np.cos(s31p1-s21p1)+ np.cos(s31p2-s21p2)+ np.cos(s31p3-s21p3)+ np.cos(s31p1-s41p1)+ np.cos(s31p2-s41p2)+ np.cos(s31p3-s41p3)+ np.cos(s31p1-s32p1)+ np.cos(s31p2-s32p2)+ np.cos(s31p3-s32p3)+ np.cos(s31p1-s35p1)+ np.cos(s31p2-s35p2)+ np.cos(s31p3-s35p3)

    H312 =- np.cos(s31p3e2-s31p1e2)- np.cos(s31p2e2-s31p3e2)- np.cos(s31p1e2-s31p2e2)+ np.cos(s31p1e2-s21p1e2)+ np.cos(s31p2e2-s21p2e2)+ np.cos(s31p3e2-s21p3e2)+ np.cos(s31p1e2-s41p1e2)+ np.cos(s31p2e2-s41p2e2)+ np.cos(s31p3e2-s41p3e2)+ np.cos(s31p1e2-s32p1e2)+ np.cos(s31p2e2-s32p2e2)+ np.cos(s31p3e2-s32p3e2)+ np.cos(s31p1e2-s35p1e2)+ np.cos(s31p2e2-s35p2e2)+ np.cos(s31p3e2-s35p3e2)

    r31 = prob(H312)/prob(H31)
    x31 = np.random.choice([random.uniform(0, 1)])
    if r31>=x31:
        s31p1n = s31p1e2
        s31p2n = s31p2e2
        s31p3n = s31p3e2

        s31p1 = s31p1e2
        s31p2 = s31p2e2
        s31p3 = s31p3e2
    else:
        s31p1n = s31p1
        s31p2n = s31p2
        s31p3n = s31p3
    if s31p1n>=s31p2n>=s31p3n:
        s31= -1
    if s31p2n>=s31p1n>=s31p3n:    
        s31=1
    if s31p3n>=s31p2n>=s31p1n:   
        s31=1
    if s31p3n>=s31p1n>=s31p2n:    
        s31= -1     
    if s31p1n>=s31p3n>=s31p2n:
        s31=1    
    if s31p2n>=s31p3n>=s31p1n:    
        s31= -1

    s31p1e2 = s31p1
    s31p2e2 = s31p2
    s31p3e2 = s31p3
    
    s32p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
    
#site32    
    H32 =- np.cos(s32p3-s32p1)- np.cos(s32p2-s32p3)- np.cos(s32p1-s32p2)+ np.cos(s32p1-s22p1)+ np.cos(s32p2-s22p2)+ np.cos(s32p3-s22p3)+ np.cos(s32p1-s42p1)+ np.cos(s32p2-s42p2)+ np.cos(s32p3-s42p3)+ np.cos(s32p1-s33p1)+ np.cos(s32p2-s33p2)+ np.cos(s32p3-s33p3)+ np.cos(s32p1-s31p1)+ np.cos(s32p2-s31p2)+ np.cos(s32p3-s31p3)

    H322 =- np.cos(s32p3e2-s32p1e2)- np.cos(s32p2e2-s32p3e2)- np.cos(s32p1e2-s32p2e2)+ np.cos(s32p1e2-s22p1e2)+ np.cos(s32p2e2-s22p2e2)+ np.cos(s32p3e2-s22p3e2)+ np.cos(s32p1e2-s42p1e2)+ np.cos(s32p2e2-s42p2e2)+ np.cos(s32p3e2-s42p3e2)+ np.cos(s32p1e2-s33p1e2)+ np.cos(s32p2e2-s33p2e2)+ np.cos(s32p3e2-s33p3e2)+ np.cos(s32p1e2-s31p1e2)+ np.cos(s32p2e2-s31p2e2)+ np.cos(s32p3e2-s31p3e2)

    r32 = prob(H322)/prob(H32)
    x32 = np.random.choice([random.uniform(0, 1)])
    if r32>=x32:
        s32p1n = s32p1e2
        s32p2n = s32p2e2
        s32p3n = s32p3e2

        s32p1 = s32p1e2
        s32p2 = s32p2e2
        s32p3 = s32p3e2
    else:
        s32p1n = s32p1
        s32p2n = s32p2
        s32p3n = s32p3
    if s32p1n>=s32p2n>=s32p3n:
        s32= -1
    if s32p2n>=s32p1n>=s32p3n:    
        s32=1
    if s32p3n>=s32p2n>=s32p1n:   
        s32=1
    if s32p3n>=s32p1n>=s32p2n:    
        s32= -1     
    if s32p1n>=s32p3n>=s32p2n:
        s32=1    
    if s32p2n>=s32p3n>=s32p1n:    
        s32= -1    
           
    s32p1e2 = s32p1
    s32p2e2 = s32p2
    s32p3e2 = s32p3        
    
    s33p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site33    
    H33 =- np.cos(s33p3-s33p1)- np.cos(s33p2-s33p3)- np.cos(s33p1-s33p2)+ np.cos(s33p1-s23p1)+ np.cos(s33p2-s23p2)+ np.cos(s33p3-s23p3)+ np.cos(s33p1-s43p1)+ np.cos(s33p2-s43p2)+ np.cos(s33p3-s43p3)+ np.cos(s33p1-s34p1)+ np.cos(s33p2-s34p2)+ np.cos(s33p3-s34p3)+ np.cos(s33p1-s32p1)+ np.cos(s33p2-s32p2)+ np.cos(s33p3-s32p3)

    H332 =- np.cos(s33p3e2-s33p1e2)- np.cos(s33p2e2-s33p3e2)- np.cos(s33p1e2-s33p2e2)+ np.cos(s33p1e2-s23p1e2)+ np.cos(s33p2e2-s23p2e2)+ np.cos(s33p3e2-s23p3e2)+ np.cos(s33p1e2-s43p1e2)+ np.cos(s33p2e2-s43p2e2)+ np.cos(s33p3e2-s43p3e2)+ np.cos(s33p1e2-s34p1e2)+ np.cos(s33p2e2-s34p2e2)+ np.cos(s33p3e2-s34p3e2)+ np.cos(s33p1e2-s32p1e2)+ np.cos(s33p2e2-s32p2e2)+ np.cos(s33p3e2-s32p3e2)

    r33 = prob(H332)/prob(H33)
    x33 = np.random.choice([random.uniform(0, 1)])
    if r33>=x33:
        s33p1n = s33p1e2
        s33p2n = s33p2e2
        s33p3n = s33p3e2
        
        s33p1 = s33p1e2
        s33p2 = s33p2e2
        s33p3 = s33p3e2
        
    else:
        s33p1n = s33p1
        s33p2n = s33p2
        s33p3n = s33p3
    if s33p1n>=s33p2n>=s33p3n:
        s33= -1
    if s33p2n>=s33p1n>=s33p3n:    
        s33=1
    if s33p3n>=s33p2n>=s33p1n:   
        s33=1
    if s33p3n>=s33p1n>=s33p2n:    
        s33= -1     
    if s33p1n>=s33p3n>=s33p2n:
        s33=1    
    if s33p2n>=s33p3n>=s33p1n:    
        s33= -1
     
    s33p1e2 = s33p1
    s33p2e2 = s33p2
    s33p3e2 = s33p3

    s34p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site34    
    H34 =- np.cos(s34p3-s34p1)- np.cos(s34p2-s34p3)- np.cos(s34p1-s34p2)+ np.cos(s34p1-s24p1)+ np.cos(s34p2-s24p2)+ np.cos(s34p3-s24p3)+ np.cos(s34p1-s44p1)+ np.cos(s34p2-s44p2)+ np.cos(s34p3-s44p3)+ np.cos(s34p1-s35p1)+ np.cos(s34p2-s35p2)+ np.cos(s34p3-s35p3)+ np.cos(s34p1-s33p1)+ np.cos(s34p2-s33p2)+ np.cos(s34p3-s33p3)

    H342 =- np.cos(s34p3e2-s34p1e2)- np.cos(s34p2e2-s34p3e2)- np.cos(s34p1e2-s34p2e2)+ np.cos(s34p1e2-s24p1e2)+ np.cos(s34p2e2-s24p2e2)+ np.cos(s34p3e2-s24p3e2)+ np.cos(s34p1e2-s44p1e2)+ np.cos(s34p2e2-s44p2e2)+ np.cos(s34p3e2-s44p3e2)+ np.cos(s34p1e2-s35p1e2)+ np.cos(s34p2e2-s35p2e2)+ np.cos(s34p3e2-s35p3e2)+ np.cos(s34p1e2-s33p1e2)+ np.cos(s34p2e2-s33p2e2)+ np.cos(s34p3e2-s33p3e2)

    r34 = prob(H342)/prob(H34)
    x34 = np.random.choice([random.uniform(0, 1)])
    if r34>=x34:
        s34p1n = s34p1e2
        s34p2n = s34p2e2
        s34p3n = s34p3e2
        
        s34p1 = s34p1e2
        s34p2 = s34p2e2
        s34p3 = s34p3e2

    else:
        s34p1n = s34p1
        s34p2n = s34p2
        s34p3n = s34p3
    if s34p1n>=s34p2n>=s34p3n:
        s34= -1
    if s34p2n>=s34p1n>=s34p3n:    
        s34=1
    if s34p3n>=s34p2n>=s34p1n:   
        s34=1
    if s34p3n>=s34p1n>=s34p2n:    
        s34= -1     
    if s34p1n>=s34p3n>=s34p2n:
        s34=1    
    if s34p2n>=s34p3n>=s34p1n:    
        s34= -1    
       
    s34p1e2 = s34p1
    s34p2e2 = s34p2
    s34p3e2 = s34p3

    s35p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site35    
    H35 =- np.cos(s35p3-s35p1)- np.cos(s35p2-s35p3)- np.cos(s35p1-s35p2)+ np.cos(s35p1-s25p1)+ np.cos(s35p2-s25p2)+ np.cos(s35p3-s25p3)+ np.cos(s35p1-s45p1)+ np.cos(s35p2-s45p2)+ np.cos(s35p3-s45p3)+ np.cos(s35p1-s34p1)+ np.cos(s35p2-s34p2)+ np.cos(s35p3-s34p3)+ np.cos(s35p1-s31p1)+ np.cos(s35p2-s31p2)+ np.cos(s35p3-s31p3)

    H352 =- np.cos(s35p3e2-s35p1e2)- np.cos(s35p2e2-s35p3e2)- np.cos(s35p1e2-s35p2e2)+ np.cos(s35p1e2-s25p1e2)+ np.cos(s35p2e2-s25p2e2)+ np.cos(s35p3e2-s25p3e2)+ np.cos(s35p1e2-s45p1e2)+ np.cos(s35p2e2-s45p2e2)+ np.cos(s35p3e2-s45p3e2)+ np.cos(s35p1e2-s34p1e2)+ np.cos(s35p2e2-s34p2e2)+ np.cos(s35p3e2-s34p3e2)+ np.cos(s35p1e2-s31p1e2)+ np.cos(s35p2e2-s31p2e2)+ np.cos(s35p3e2-s31p3e2)

    r35 = prob(H352)/prob(H35)
    x35 = np.random.choice([random.uniform(0, 1)])
    if r35>=x35:
        s35p1n = s35p1e2
        s35p2n = s35p2e2
        s35p3n = s35p3e2
        
        s35p1 = s35p1e2
        s35p2 = s35p2e2
        s35p3 = s35p3e2

    else:
        s35p1n = s35p1
        s35p2n = s35p2
        s35p3n = s35p3
    if s35p1n>=s35p2n>=s35p3n:
        s35= -1
    if s35p2n>=s35p1n>=s35p3n:    
        s35=1
    if s35p3n>=s35p2n>=s35p1n:   
        s35=1
    if s35p3n>=s35p1n>=s35p2n:    
        s35= -1     
    if s35p1n>=s35p3n>=s35p2n:
        s35=1    
    if s35p2n>=s35p3n>=s35p1n:    
        s35= -1    
   
    s35p1e2 = s35p1
    s35p2e2 = s35p2
    s35p3e2 = s35p3

    s41p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site41    
    H41 =- np.cos(s41p3-s41p1)- np.cos(s41p2-s41p3)- np.cos(s41p1-s41p2)+ np.cos(s41p1-s31p1)+ np.cos(s41p2-s31p2)+ np.cos(s41p3-s31p3)+ np.cos(s41p1-s1p1)+ np.cos(s41p2-s1p2)+ np.cos(s41p3-s1p3)+ np.cos(s41p1-s42p1)+ np.cos(s41p2-s42p2)+ np.cos(s41p3-s42p3)+ np.cos(s41p1-s45p1)+ np.cos(s41p2-s45p2)+ np.cos(s41p3-s45p3)

    H412 =- np.cos(s41p3e2-s41p1e2)- np.cos(s41p2e2-s41p3e2)- np.cos(s41p1e2-s41p2e2)+ np.cos(s41p1e2-s31p1e2)+ np.cos(s41p2e2-s31p2e2)+ np.cos(s41p3e2-s31p3e2)+ np.cos(s41p1e2-s1p1e2)+ np.cos(s41p2e2-s1p2e2)+ np.cos(s41p3e2-s1p3e2)+ np.cos(s41p1e2-s42p1e2)+ np.cos(s41p2e2-s42p2e2)+ np.cos(s41p3e2-s42p3e2)+ np.cos(s41p1e2-s45p1e2)+ np.cos(s41p2e2-s45p2e2)+ np.cos(s41p3e2-s45p3e2)

    r41 = prob(H412)/prob(H41)
    x41 = np.random.choice([random.uniform(0, 1)])
    if r41>=x41:
        s41p1n = s41p1e2
        s41p2n = s41p2e2
        s41p3n = s41p3e2
        
        s41p1 = s41p1e2
        s41p2 = s41p2e2
        s41p3 = s41p3e2

    else:
        s41p1n = s41p1
        s41p2n = s41p2
        s41p3n = s41p3
    if s41p1n>=s41p2n>=s41p3n:
        s41= -1
    if s41p2n>=s41p1n>=s41p3n:    
        s41=1
    if s41p3n>=s41p2n>=s41p1n:   
        s41=1
    if s41p3n>=s41p1n>=s41p2n:    
        s41= -1     
    if s41p1n>=s41p3n>=s41p2n:
        s41=1    
    if s41p2n>=s41p3n>=s41p1n:    
        s41= -1  
   
    s41p1e2 = s41p1
    s41p2e2 = s41p2
    s41p3e2 = s42p3

    s42p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site42    
    H42 =- np.cos(s42p3-s42p1)- np.cos(s42p2-s42p3)- np.cos(s42p1-s42p2)+ np.cos(s42p1-s32p1)+ np.cos(s42p2-s32p2)+ np.cos(s42p3-s32p3)+ np.cos(s42p1-s2p1)+ np.cos(s42p2-s2p2)+ np.cos(s42p3-s2p3)+ np.cos(s42p1-s43p1)+ np.cos(s42p2-s43p2)+ np.cos(s42p3-s43p3)+ np.cos(s42p1-s41p1)+ np.cos(s42p2-s41p2)+ np.cos(s42p3-s41p3)

    H422 =- np.cos(s42p3e2-s42p1e2)- np.cos(s42p2e2-s42p3e2)- np.cos(s42p1e2-s42p2e2)+ np.cos(s42p1e2-s32p1e2)+ np.cos(s42p2e2-s32p2e2)+ np.cos(s42p3e2-s32p3e2)+ np.cos(s42p1e2-s2p1e2)+ np.cos(s42p2e2-s2p2e2)+ np.cos(s42p3e2-s2p3e2)+ np.cos(s42p1e2-s43p1e2)+ np.cos(s42p2e2-s43p2e2)+ np.cos(s42p3e2-s43p3e2)+ np.cos(s42p1e2-s41p1e2)+ np.cos(s42p2e2-s41p2e2)+ np.cos(s42p3e2-s41p3e2)

    r42 = prob(H422)/prob(H42)
    x42 = np.random.choice([random.uniform(0, 1)])
    if r42>=x42:
        s42p1n = s42p1e2
        s42p2n = s42p2e2
        s42p3n = s42p3e2
        
        s42p1 = s42p1e2
        s42p2 = s42p2e2
        s42p3 = s42p3e2

    else:
        s42p1n = s42p1
        s42p2n = s42p2
        s42p3n = s42p3
    if s42p1n>=s42p2n>=s42p3n:
        s42= -1
    if s42p2n>=s42p1n>=s42p3n:    
        s42=1
    if s42p3n>=s42p2n>=s42p1n:   
        s42=1
    if s42p3n>=s42p1n>=s42p2n:    
        s42= -1     
    if s42p1n>=s42p3n>=s42p2n:
        s42=1    
    if s42p2n>=s42p3n>=s42p1n:    
        s42= -1    
   
    s42p1e2 = s42p1
    s42p2e2 = s42p2
    s42p3e2 = s42p3

    s43p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site43    
    H43 =- np.cos(s43p3-s43p1)- np.cos(s43p2-s43p3)- np.cos(s43p1-s43p2)+ np.cos(s43p1-s33p1)+ np.cos(s43p2-s33p2)+ np.cos(s43p3-s33p3)+ np.cos(s43p1-s3p1)+ np.cos(s43p2-s3p2)+ np.cos(s43p3-s3p3)+ np.cos(s43p1-s44p1)+ np.cos(s43p2-s44p2)+ np.cos(s43p3-s44p3)+ np.cos(s43p1-s42p1)+ np.cos(s43p2-s42p2)+ np.cos(s43p3-s42p3)

    H432 =- np.cos(s43p3e2-s43p1e2)- np.cos(s43p2e2-s43p3e2)- np.cos(s43p1e2-s43p2e2)+ np.cos(s43p1e2-s33p1e2)+ np.cos(s43p2e2-s33p2e2)+ np.cos(s43p3e2-s33p3e2)+ np.cos(s43p1e2-s3p1e2)+ np.cos(s43p2e2-s3p2e2)+ np.cos(s43p3e2-s3p3e2)+ np.cos(s43p1e2-s44p1e2)+ np.cos(s43p2e2-s44p2e2)+ np.cos(s43p3e2-s44p3e2)+ np.cos(s43p1e2-s42p1e2)+ np.cos(s43p2e2-s42p2e2)+ np.cos(s43p3e2-s42p3e2)

    r43 = prob(H432)/prob(H43)
    x43 = np.random.choice([random.uniform(0, 1)])
    if r43>=x43:
        s43p1n = s43p1e2
        s43p2n = s43p2e2
        s43p3n = s43p3e2
        
        s43p1 = s43p1e2
        s43p2 = s43p2e2
        s43p3 = s43p3e2

    else:
        s43p1n = s43p1
        s43p2n = s43p2
        s43p3n = s43p3
    if s43p1n>=s43p2n>=s43p3n:
        s43= -1
    if s43p2n>=s43p1n>=s43p3n:    
        s43=1
    if s43p3n>=s43p2n>=s43p1n:   
        s43=1
    if s43p3n>=s43p1n>=s43p2n:    
        s43= -1     
    if s43p1n>=s43p3n>=s43p2n:
        s43=1    
    if s43p2n>=s43p3n>=s43p1n:    
        s43= -1 
  
    s43p1e2 = s43p1
    s43p2e2 = s43p2
    s43p3e2 = s43p3

    s44p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site44    
    H44 =- np.cos(s44p3-s44p1)- np.cos(s44p2-s44p3)- np.cos(s44p1-s44p2)+ np.cos(s44p1-s34p1)+ np.cos(s44p2-s34p2)+ np.cos(s44p3-s34p3)+ np.cos(s44p1-s4p1)+ np.cos(s44p2-s4p2)+ np.cos(s44p3-s4p3)+ np.cos(s44p1-s45p1)+ np.cos(s44p2-s45p2)+ np.cos(s44p3-s45p3)+ np.cos(s44p1-s43p1)+ np.cos(s44p2-s43p2)+ np.cos(s44p3-s43p3)

    H442 =- np.cos(s44p3e2-s44p1e2)- np.cos(s44p2e2-s44p3e2)- np.cos(s44p1e2-s44p2e2)+ np.cos(s44p1e2-s34p1e2)+ np.cos(s44p2e2-s34p2e2)+ np.cos(s44p3e2-s34p3e2)+ np.cos(s44p1e2-s4p1e2)+ np.cos(s44p2e2-s4p2e2)+ np.cos(s44p3e2-s4p3e2)+ np.cos(s44p1e2-s45p1e2)+ np.cos(s44p2e2-s45p2e2)+ np.cos(s44p3e2-s45p3e2)+ np.cos(s44p1e2-s43p1e2)+ np.cos(s44p2e2-s43p2e2)+ np.cos(s44p3e2-s43p3e2)

    r44 = prob(H442)/prob(H44)
    x44 = np.random.choice([random.uniform(0, 1)])
    if r44>=x44:
        s44p1n = s44p1e2
        s44p2n = s44p2e2
        s44p3n = s44p3e2
        
        s44p1 = s44p1e2
        s44p2 = s44p2e2
        s44p3 = s44p3e2
 
    else:
        s44p1n = s44p1
        s44p2n = s44p2
        s44p3n = s44p3
    if s44p1n>=s44p2n>=s44p3n:
        s44= -1
    if s44p2n>=s44p1n>=s44p3n:    
        s44=1
    if s44p3n>=s44p2n>=s44p1n:   
        s44=1
    if s44p3n>=s44p1n>=s44p2n:    
        s44= -1     
    if s44p1n>=s44p3n>=s44p2n:
        s44=1    
    if s44p2n>=s44p3n>=s44p1n:    
        s44= -1 
          
    s44p1e2 = s44p1
    s44p2e2 = s44p2
    s44p3e2 = s44p3
    
    s45p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])        
#site45    
    H45 =- np.cos(s45p3-s45p1)- np.cos(s45p2-s45p3)- np.cos(s45p1-s45p2)+ np.cos(s45p1-s35p1)+ np.cos(s45p2-s35p2)+ np.cos(s45p3-s35p3)+ np.cos(s45p1-s5p1)+ np.cos(s45p2-s5p2)+ np.cos(s45p3-s5p3)+ np.cos(s45p1-s44p1)+ np.cos(s45p2-s44p2)+ np.cos(s45p3-s44p3)+ np.cos(s45p1-s41p1)+ np.cos(s45p2-s41p2)+ np.cos(s45p3-s41p3)

    H452 =- np.cos(s45p3e2-s45p1e2)- np.cos(s45p2e2-s45p3e2)- np.cos(s45p1e2-s45p2e2)+ np.cos(s45p1e2-s35p1e2)+ np.cos(s45p2e2-s35p2e2)+ np.cos(s45p3e2-s35p3e2)+ np.cos(s45p1e2-s5p1e2)+ np.cos(s45p2e2-s5p2e2)+ np.cos(s45p3e2-s5p3e2)+ np.cos(s45p1e2-s44p1e2)+ np.cos(s45p2e2-s44p2e2)+ np.cos(s45p3e2-s44p3e2)+ np.cos(s45p1e2-s41p1e2)+ np.cos(s45p2e2-s41p2e2)+ np.cos(s45p3e2-s41p3e2)

    r45 = prob(H452)/prob(H45)
    x45 = np.random.choice([random.uniform(0, 1)])
    if r45>=x45:
        s45p1n = s45p1e2
        s45p2n = s45p2e2
        s45p3n = s45p3e2
        
        s45p1 = s45p1e2
        s45p2 = s45p2e2
        s45p3 = s45p3e2

    else:
        s45p1n = s45p1
        s45p2n = s45p2
        s45p3n = s45p3
    if s45p1n>=s45p2n>=s45p3n:
        s45= -1
    if s45p2n>=s45p1n>=s45p3n:    
        s45=1
    if s45p3n>=s45p2n>=s45p1n:   
        s45=1
    if s45p3n>=s45p1n>=s45p2n:    
        s45= -1     
    if s45p1n>=s45p3n>=s45p2n:
        s45=1    
    if s45p2n>=s45p3n>=s45p1n:    
        s45= -1  
    if J<4500:
        J=J+1
    else:
        s.append(s1)
        s.append(s2)
        s.append(s3)
        s.append(s4)
        s.append(s5)
        s.append(s11)
        s.append(s12)
        s.append(s13)
        s.append(s14)
        s.append(s15)
        s.append(s21)
        s.append(s22)
        s.append(s23)
        s.append(s24)
        s.append(s25)
        s.append(s31)
        s.append(s32)
        s.append(s33)
        s.append(s34)
        s.append(s35)
        s.append(s41)
        s.append(s42)
        s.append(s43)
        s.append(s44)
        s.append(s45)
        S.append(abs(mean(s)))
sigma=[]
C=0
s1s=0
OUI=[500,2500,5000]
while s1s<=499:
    S1= S[s1s]
    s1s=s1s+1
    C=C+np.sqrt(abs(-(1/5000)*((1/5000)*S1**2)-((1/5000)*S1)**2))
print(C)
C1.append(C)
plt.plot(OUI, C1, color='red')
plt.xlabel('Number of simulation N')
plt.ylabel('Standard deviation')
# Out:
# 0.9638578998215346
# 0.2828427124746155
# 0.14142135623730775
# Text(0, 0.5, 'Standard deviation')

# %% [markdown]
# <h1 style="font-size:100px; text-align:center;">CORRELATION</h1>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Apr 23 11:57:49 2023

@author: Logan
"""

import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import random
from statistics import mean 

k=1
s1p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s1p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s2p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s2p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s11p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s11p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s31p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s31p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s41p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s41p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s32p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s32p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s42p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s42p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s43p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s43p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s44p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s44p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s33p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s33p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s34p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s34p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s35p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s35p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s45p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s45p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s12p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s12p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s3p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s3p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s13p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s13p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s14p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s14p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s15p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s15p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s21p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s21p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s22p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s22p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s23p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s23p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s24p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s24p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s25p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s25p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s4p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s4p3 = np.random.choice([random.uniform(0, 2*np.pi)])

s5p1 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p2 = np.random.choice([random.uniform(0, 2*np.pi)])
s5p3 = np.random.choice([random.uniform(0, 2*np.pi)])
T=0.1
b= k/T
s = []
def prob(H):
    return np.exp(H*b) 

S = []
SA=[]

for i in range(1000):
    s1p1e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    s1p2e2 =np.random.choice([random.uniform(0, 2*np.pi)])
    s1p3e2 =np.random.choice([random.uniform(0, 2*np.pi)])

    s2p1e2 =s2p1
    s2p2e2 =s2p2
    s2p3e2 =s2p3
    
    s11p1e2 = s11p1
    s11p2e2 = s11p2
    s11p3e2 = s11p3
    
    s31p1e2 = s31p1
    s31p2e2 = s31p2
    s31p3e2 = s31p3
    
    s41p1e2 = s41p1
    s41p2e2 = s41p2
    s41p3e2 = s41p3
    
    s42p1e2 = s42p1
    s42p2e2 = s42p2
    s42p3e2 = s42p3
    
    s43p1e2 = s43p1
    s43p2e2 = s43p2
    s43p3e2 = s43p3
    
    s44p1e2 = s44p1
    s44p2e2 = s44p2
    s44p3e2 = s44p3
    
    s32p1e2 = s32p1
    s32p2e2 = s32p2
    s32p3e2 = s32p3
    
    s33p1e2 = s33p1
    s33p2e2 = s33p2
    s33p3e2 = s33p3
    
    s34p1e2 = s34p1
    s34p2e2 = s34p2
    s34p3e2 = s34p3
    
    s35p1e2 = s35p1
    s35p2e2 = s35p2
    s35p3e2 = s35p3
    
    s45p1e2 = s45p1
    s45p2e2 = s45p2
    s45p3e2 = s45p3
    
    s12p1e2 = s12p1
    s12p2e2 = s12p2
    s12p3e2 = s12p3
    
    s13p1e2 = s13p1
    s13p2e2 = s13p2
    s13p3e2 = s13p3
    
    s3p1e2 = s3p1
    s3p2e2 = s3p2
    s3p3e2 = s3p3
    
    s4p1e2 = s4p1
    s4p2e2 = s4p2
    s4p3e2 = s4p3
    
    s14p1e2 = s14p1
    s14p2e2 = s14p2
    s14p3e2 = s14p3
    
    s15p1e2 = s15p1
    s15p2e2 = s15p2
    s15p3e2 = s15p3
    
    s21p1e2 = s21p1
    s21p2e2 = s21p2
    s21p3e2 = s21p3
    
    s5p1e2 = s5p1
    s5p2e2 = s5p2
    s5p3e2 = s5p3
    
    s22p1e2 = s22p1
    s22p2e2 = s22p2
    s22p3e2 = s22p3
    
    s23p1e2 = s23p1
    s23p2e2 = s23p2
    s23p3e2 = s23p3
    
    s24p1e2 = s24p1
    s24p2e2 = s24p2
    s24p3e2 = s24p3
    
    s25p1e2 = s25p1
    s25p2e2 = s25p2
    s25p3e2 = s25p3
#site1        
    H1 = - np.cos(s1p1-s1p2) - np.cos(s1p2-s1p3)- np.cos(s1p3-s1p1)+ np.cos(s1p1-s2p1)+ np.cos(s1p2-s2p2)+ np.cos(s1p3-s2p3)+ np.cos(s1p1-s11p1)+ np.cos(s1p2-s11p2)+ np.cos(s1p3-s11p3)+ np.cos(s1p1-s41p1)+ np.cos(s1p2-s41p2)+ np.cos(s1p3-s41p3)+ np.cos(s1p1-s5p1)+ np.cos(s1p2-s5p2)+ np.cos(s1p3-s5p3)
    
    H12 = - np.cos(s1p1e2-s1p2e2)- np.cos(s1p3e2-s1p1e2)- np.cos(s1p2e2-s1p3e2)+ np.cos(s1p1e2-s2p1e2)+ np.cos(s1p2e2-s2p2e2)+ np.cos(s1p3e2-s2p3e2)+ np.cos(s1p1e2-s11p1e2)+ np.cos(s1p2e2-s11p2e2)+ np.cos(s1p3e2-s11p3e2)+ np.cos(s1p1e2-s41p1e2)+ np.cos(s1p2e2-s41p2e2)+ np.cos(s1p3e2-s41p3e2)+ np.cos(s1p1e2-s5p1e2)+ np.cos(s1p2e2-s5p2e2)+ np.cos(s1p3e2-s5p3e2)

    r= prob(H12)/prob(H1)
    x= np.random.choice([random.uniform(0, 1)])
    if r >= x:
        s1p1n = s1p1e2
        s1p2n = s1p2e2
        s1p3n = s1p3e2
        
        s1p1 = s1p1e2
        s1p2 = s1p2e2
        s1p3 = s1p3e2
        
    else:
        s1p1n = s1p1
        s1p2n = s1p2
        s1p3n = s1p3
    if s1p1n>=s1p2n>=s1p3n:
        s1= -1
    if s1p2n>=s1p1n>=s1p3n:    
        s1=1
    if s1p3n>=s1p2n>=s1p1n:   
        s1=1
    if s1p3n>=s1p1n>=s1p2n:    
        s1= -1     
    if s1p1n>=s1p3n>=s1p2n:
        s1=1    
    if s1p2n>=s1p3n>=s1p1n:    
        s1= -1    
    s.append(s1)    
    s1p1e2 =s1p1
    s1p2e2 =s1p2
    s1p3e2 =s1p3
    
    s2p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s2p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site2    
    H2 = - np.cos(s2p2-s2p3)- np.cos(s2p3-s2p1)- np.cos(s2p1-s2p2)+ np.cos(s2p1-s12p1)+ np.cos(s2p2-s12p2)+ np.cos(s2p3-s12p3)+ np.cos(s2p1-s1p1)+ np.cos(s2p2-s1p2)+ np.cos(s2p3-s1p2)+ np.cos(s2p1-s3p1)+ np.cos(s2p2-s3p2)+ np.cos(s2p3-s3p3)+ np.cos(s2p1-s42p1)+ np.cos(s2p2-s42p2)+ np.cos(s2p3-s42p3)

    H22 =- np.cos(s2p3e2-s2p1e2)- np.cos(s2p2e2-s2p3e2)- np.cos(s2p1e2-s2p2e2)+ np.cos(s2p1e2-s1p1e2)+ np.cos(s2p2e2-s1p2e2)+ np.cos(s2p3e2-s1p3e2)+ np.cos(s2p1e2-s12p1e2)+ np.cos(s2p2e2-s12p2e2)+ np.cos(s2p3e2-s12p3e2)+ np.cos(s2p1e2-s3p1e2)+ np.cos(s2p2e2-s3p2e2)+ np.cos(s2p3e2-s3p3e2)+ np.cos(s2p1e2-s42p1e2)+ np.cos(s2p2e2-s42p2e2)+ np.cos(s2p3e2-s42p3e2)

    r1 = prob(H22)/prob(H2)
    x1 = np.random.choice([random.uniform(0, 1)])
    if r1 >= x1:
        s2p1n = s2p1e2
        s2p2n = s2p2e2
        s2p3n = s2p3e2
        
        s2p1 = s2p1e2
        s2p2 = s2p2e2
        s2p3 = s2p3e2
        
    else:
        s2p1n = s2p1
        s2p2n = s2p2
        s2p3n = s2p3
        
    if s2p1n>=s2p2n>=s2p3n:
        s2= -1
    if s2p2n>=s2p1n>=s2p3n:    
        s2=1
    if s2p3n>=s2p2n>=s2p1n:   
        s2=1
    if s2p3n>=s2p1n>=s2p2n:    
        s2= -1     
    if s2p1n>=s2p3n>=s2p2n:
        s2=1    
    if s2p2n>=s2p3n>=s2p1n:    
        s2= -1    
    s.append(s2) 
    s2p1e2 = s2p1
    s2p2e2 = s2p2
    s2p3e2 = s2p3
    
    s3p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s3p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site3    
    H3 = -np.cos(s3p2-s3p3)- np.cos(s3p3-s3p1)- np.cos(s3p1-s3p2)+ np.cos(s3p1-s2p1)+ np.cos(s3p2-s2p2)+ np.cos(s3p3-s2p3)+ np.cos(s3p1-s13p1)+ np.cos(s3p2-s13p2)+ np.cos(s3p3-s13p3)+ np.cos(s3p1-s4p1)+ np.cos(s3p2-s4p2)+ np.cos(s3p3-s4p3)+ np.cos(s3p1-s43p1)+ np.cos(s3p2-s43p2)+ np.cos(s3p3-s43p3)

    H32 = - np.cos(s3p2e2-s3p3e2)- np.cos(s3p3e2-s3p1e2)- np.cos(s3p1e2-s3p2e2)+ np.cos(s3p1e2-s2p1e2)+ np.cos(s3p2e2-s2p2e2)+ np.cos(s3p3e2-s2p3e2)+ np.cos(s3p1e2-s13p1e2)+ np.cos(s3p2e2-s13p2e2)+ np.cos(s3p3e2-s13p3e2)+ np.cos(s3p1e2-s4p1e2)+ np.cos(s3p2e2-s4p2e2)+ np.cos(s3p3e2-s4p3e2)+ np.cos(s3p1e2-s43p1e2)+ np.cos(s3p2e2-s43p2e2)+ np.cos(s3p3e2-s43p3e2)
  
    r2 = prob(H32)/prob(H3)
    x2 = np.random.choice([random.uniform(0, 1)])
    if r2 >= x2:
        s3p1n = s3p1e2
        s3p2n = s3p2e2
        s3p3n = s3p3e2
        
        s3p1 = s3p1e2
        s3p2 = s3p2e2
        s3p3 = s3p3e2
    else:
        s3p1n = s3p1
        s3p2n = s3p2
        s3p3n = s3p3
    if s3p1n>=s3p2n>=s3p3n:
        s3= -1
    if s3p2n>=s3p1n>=s3p3n:    
        s3=1
    if s3p3n>=s3p2n>=s3p1n:   
        s3=1
    if s3p3n>=s3p1n>=s3p2n:    
        s3= -1     
    if s3p1n>=s3p3n>=s3p2n:
        s3=1    
    if s3p2n>=s3p3n>=s3p1n:    
        s3= -1  
    s.append(s3)    
    s3p1e2 = s3p1
    s3p2e2 = s3p2
    s3p3e2 = s3p3
    
    s4p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s4p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site4    
    H4 = - np.cos(s4p2-s4p3)- np.cos(s4p3-s4p1)- np.cos(s4p1-s4p2)+ np.cos(s4p1-s3p1)+ np.cos(s4p2-s3p2)+ np.cos(s4p3-s3p3)+ np.cos(s4p1-s14p1)+ np.cos(s4p2-s14p2)+ np.cos(s4p3-s14p3)+ np.cos(s4p1-s5p1)+ np.cos(s4p2-s5p2)+ np.cos(s4p3-s5p3)+ np.cos(s4p1-s44p1)+ np.cos(s4p2-s44p2)+ np.cos(s4p3-s44p3)

    H42 = - np.cos(s4p3e2-s4p1e2)- np.cos(s4p2e2-s3p3e2)- np.cos(s4p1e2-s4p2e2)+ np.cos(s4p1e2-s3p1e2)+ np.cos(s4p2e2-s3p2e2)+ np.cos(s4p3e2-s3p3e2)+ np.cos(s4p1e2-s14p1e2)+ np.cos(s4p2e2-s14p2e2)+ np.cos(s4p3e2-s14p3e2)+ np.cos(s4p1e2-s5p1e2)+ np.cos(s4p2e2-s5p2e2)+ np.cos(s4p3e2-s5p3e2)+ np.cos(s4p1e2-s44p1e2)+ np.cos(s4p2e2-s44p2e2)+ np.cos(s4p3e2-s44p3e2)

    r3 = prob(H42)/prob(H4)
    x3 = np.random.choice([random.uniform(0, 1)])
    if r3 >= x3:
        s4p1n = s4p1e2
        s4p2n = s4p2e2
        s4p3n = s4p3e2
        
        s4p1 = s4p1e2
        s4p2 = s4p2e2
        s4p3 = s4p3e2
    else:
        s4p1n = s4p1
        s4p2n = s4p2
        s4p3n = s4p3
    if s4p1n>=s4p2n>=s4p3n:
        s4= -1
    if s4p2n>=s4p1n>=s4p3n:    
        s4=1
    if s4p3n>=s4p2n>=s4p1n:   
        s4=1
    if s4p3n>=s4p1n>=s4p2n:    
        s4= -1     
    if s4p1n>=s4p3n>=s4p2n:
        s4=1    
    if s4p2n>=s4p3n>=s4p1n:    
        s4= -1    
    s.append(s4)
    s4p1e2 = s4p1
    s4p2e2 = s4p2
    s4p3e2 = s4p3
    
    s5p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s5p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site5    
    H5 =- np.cos(s5p2-s5p3)- np.cos(s5p3-s5p1)- np.cos(s5p1-s5p2)+ np.cos(s5p1-s4p1)+ np.cos(s5p2-s4p2)+ np.cos(s5p3-s4p3)+ np.cos(s5p1-s15p1)+ np.cos(s5p2-s15p2)+ np.cos(s5p3-s15p3)+ np.cos(s5p1-s45p1)+ np.cos(s5p2-s45p2)+ np.cos(s5p3-s45p3)+ np.cos(s5p1-s1p1)+ np.cos(s5p2-s1p2)+ np.cos(s5p3-s1p3)

    H52 = - np.cos(s5p3e2-s5p1e2)- np.cos(s5p2e2-s5p3e2)- np.cos(s5p1e2-s5p2e2)+ np.cos(s5p1e2-s4p1e2)+ np.cos(s5p2e2-s4p2e2)+ np.cos(s5p3e2-s4p3e2)+ np.cos(s5p1e2-s15p1e2)+ np.cos(s5p2e2-s15p2e2)+ np.cos(s5p3e2-s15p3e2)+ np.cos(s5p1e2-s45p1e2)+ np.cos(s5p2e2-s45p2e2)+ np.cos(s5p3e2-s45p3e2)+ np.cos(s5p1e2-s1p1e2)+ np.cos(s5p2e2-s1p2e2)+ np.cos(s5p3e2-s1p3e2)

    r4 = prob(H52)/prob(H5)
    x4 = np.random.choice([random.uniform(0, 1)])
    if r4 >= x4:
        s5p1n = s5p1e2
        s5p2n = s5p2e2
        s5p3n = s5p3e2
        
        s5p1 = s5p1e2
        s5p2 = s5p2e2
        s5p3 = s5p3e2
    else:
        s5p1n = s5p1
        s5p2n = s5p2
        s5p3n = s5p3
    if s5p1n>=s5p2n>=s5p3n:
        s5= -1
    if s5p2n>=s5p1n>=s5p3n:    
        s5=1
    if s5p3n>=s5p2n>=s5p1n:   
        s5=1
    if s5p3n>=s5p1n>=s5p2n:    
        s5= -1     
    if s5p1n>=s5p3n>=s5p2n:
        s5=1    
    if s5p2n>=s5p3n>=s5p1n:    
        s5= -1   
    s.append(s5)            
    s5p1e2 = s5p1
    s5p2e2 = s5p2
    s5p3e2 = s5p3
    
    s11p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s11p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site11    
    H11 =- np.cos(s11p3-s11p1)- np.cos(s11p2-s11p3)- np.cos(s11p1-s11p2)+ np.cos(s11p1-s1p1)+ np.cos(s11p2-s1p2)+ np.cos(s11p3-s1p3)+ np.cos(s11p1-s12p1)+ np.cos(s11p2-s12p2)+ np.cos(s11p3-s12p3)+ np.cos(s11p1-s21p1)+ np.cos(s11p2-s21p2)+ np.cos(s11p3-s21p3)+ np.cos(s11p1-s15p1)+ np.cos(s11p2-s15p2)+ np.cos(s11p3-s15p3)

    H112 =- np.cos(s11p3e2-s11p1e2)- np.cos(s11p2e2-s11p3e2)- np.cos(s11p1e2-s11p2e2)+ np.cos(s11p1e2-s1p1e2)+ np.cos(s11p2e2-s1p2e2)+ np.cos(s11p3e2-s1p3e2)+ np.cos(s11p1e2-s12p1e2)+ np.cos(s11p2e2-s12p2e2)+ np.cos(s11p3e2-s12p3e2)+ np.cos(s11p1e2-s21p1e2)+ np.cos(s11p2e2-s21p2e2)+ np.cos(s11p3e2-s21p3e2)+ np.cos(s11p1e2-s15p1e2)+ np.cos(s11p2e2-s15p2e2)+ np.cos(s11p3e2-s15p3e2)

    r11 = prob(H112)/prob(H11)
    x11 = np.random.choice([random.uniform(0, 1)])
    if r11 >= x11:
        s11p1n = s11p1e2
        s11p2n = s11p2e2
        s11p3n = s11p3e2
        
        s11p1 = s11p1e2
        s11p2 = s11p2e2
        s11p3 = s11p3e2
        
    else:
        s11p1n = s11p1
        s11p2n = s11p2
        s11p3n = s11p3
    if s11p1n>=s11p2n>=s11p3n:
        s11= -1
    if s11p2n>=s11p1n>=s11p3n:    
        s11=1
    if s11p3n>=s11p2n>=s11p1n:   
        s11=1
    if s11p3n>=s11p1n>=s11p2n:    
        s11= -1     
    if s11p1n>=s11p3n>=s11p2n:
        s11=1    
    if s11p2n>=s11p3n>=s11p1n:    
        s11= -1   
    s.append(s11)            
    s11p1e2 = s11p1
    s11p2e2 = s11p2
    s11p3e2 = s11p3
    
    s12p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s12p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site12    
    H12s =- np.cos(s12p3-s12p1)- np.cos(s12p2-s12p3)- np.cos(s12p1-s12p2)+ np.cos(s12p1-s2p1)+ np.cos(s12p2-s2p2)+ np.cos(s12p3-s2p3)+ np.cos(s12p1-s13p1)+ np.cos(s12p2-s13p2)+ np.cos(s12p3-s13p3)+ np.cos(s12p1-s22p1)+ np.cos(s12p2-s22p2)+ np.cos(s12p3-s22p3)+ np.cos(s12p1-s11p1)+ np.cos(s12p2-s11p2)+ np.cos(s12p3-s11p3)

    H122 =- np.cos(s12p3e2-s12p1e2)- np.cos(s12p2e2-s12p3e2)- np.cos(s12p1e2-s12p2e2)+ np.cos(s12p1e2-s2p1e2)+ np.cos(s12p2e2-s2p2e2)+ np.cos(s12p3e2-s2p3e2)+ np.cos(s12p1e2-s13p1e2)+ np.cos(s12p2e2-s13p2e2)+ np.cos(s12p3e2-s13p3e2)+ np.cos(s12p1e2-s22p1e2)+ np.cos(s12p2e2-s22p2e2)+ np.cos(s12p3e2-s22p3e2)+ np.cos(s12p1e2-s11p1e2)+ np.cos(s12p2e2-s11p2e2)+ np.cos(s12p3e2-s11p3e2)

    r12 = prob(H122)/prob(H12s)
    x12 = np.random.choice([random.uniform(0, 1)])
    if r12 >= x12:
        s12p1n = s12p1e2
        s12p2n = s12p2e2
        s12p3n = s12p3e2
        
        s12p1 = s12p1e2
        s12p2 = s12p2e2
        s12p3 = s12p3e2
        
    else:
        s12p1n = s12p1
        s12p2n = s12p2
        s12p3n = s12p3
    if s12p1n>=s12p2n>=s12p3n:
        s12= -1
    if s12p2n>=s12p1n>=s12p3n:    
        s12=1
    if s12p3n>=s12p2n>=s12p1n:   
        s12=1
    if s12p3n>=s12p1n>=s12p2n:    
        s12= -1     
    if s12p1n>=s12p3n>=s12p2n:
        s12=1    
    if s12p2n>=s12p3n>=s12p1n:    
        s12= -1    
    s.append(s12)      
    s12p1e2 = s12p1
    s12p2e2 = s12p2
    s12p3e2 = s12p3
    
    s13p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s13p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site13    
    H13 =- np.cos(s13p3-s13p1)- np.cos(s13p2-s13p3)- np.cos(s13p1-s13p2)+ np.cos(s13p1-s3p1)+ np.cos(s13p2-s3p2)+ np.cos(s13p3-s3p3)+ np.cos(s13p1-s14p1)+ np.cos(s13p2-s14p2)+ np.cos(s13p3-s14p3)+ np.cos(s13p1-s23p1)+ np.cos(s13p2-s23p2)+ np.cos(s13p3-s23p3)+ np.cos(s13p1-s12p1)+ np.cos(s13p2-s12p2)+ np.cos(s13p3-s12p3)

    H132 =- np.cos(s13p3e2-s13p1e2)- np.cos(s13p2e2-s13p3e2)- np.cos(s13p1e2-s13p2e2)+ np.cos(s13p1e2-s3p1e2)+ np.cos(s13p2e2-s3p2e2)+ np.cos(s13p3e2-s3p3e2)+ np.cos(s13p1e2-s14p1e2)+ np.cos(s13p2e2-s14p2e2)+ np.cos(s13p3e2-s14p3e2)+ np.cos(s13p1e2-s23p1e2)+ np.cos(s13p2e2-s23p2e2)+ np.cos(s13p3e2-s23p3e2)+ np.cos(s13p1e2-s12p1e2)+ np.cos(s13p2e2-s12p2e2)+ np.cos(s13p3e2-s12p3e2)

    r13 = prob(H132)/prob(H13)
    x13 = np.random.choice([random.uniform(0, 1)])
    if r13 >= x13:
        s13p1n = s13p1e2
        s13p2n = s13p2e2
        s13p3n = s13p3e2
        
        s13p1 = s13p1e2
        s13p2 = s13p2e2
        s13p3 = s13p3e2
        
    else:
        s13p1n = s13p1
        s13p2n = s13p2
        s13p3n = s13p3
    if s13p1n>=s13p2n>=s13p3n:
        s13= -1
    if s13p2n>=s13p1n>=s13p3n:    
        s13=1
    if s13p3n>=s13p2n>=s13p1n:   
        s13=1
    if s13p3n>=s13p1n>=s13p2n:    
        s13= -1     
    if s13p1n>=s13p3n>=s13p2n:
        s13=1    
    if s13p2n>=s13p3n>=s13p1n:    
        s13= -1  
    s.append(s13)    
    s13p1e2 = s13p1
    s13p2e2 = s13p2
    s13p3e2 = s13p3
    
    s14p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s14p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site14    
    H14 =- np.cos(s14p3-s14p1)- np.cos(s14p2-s14p3)- np.cos(s14p1-s14p2)+ np.cos(s14p1-s4p1)+ np.cos(s14p2-s4p2)+ np.cos(s14p3-s4p3)+ np.cos(s14p1-s15p1)+ np.cos(s14p2-s15p2)+ np.cos(s14p3-s15p3)+ np.cos(s14p1-s24p1)+ np.cos(s14p2-s24p2)+ np.cos(s14p3-s24p3)+ np.cos(s14p1-s13p1)+ np.cos(s14p2-s13p2)+ np.cos(s14p3-s13p3)

    H142 =- np.cos(s14p3e2-s14p1e2)- np.cos(s14p2e2-s14p3e2)- np.cos(s14p1e2-s14p2e2)+ np.cos(s14p1e2-s4p1e2)+ np.cos(s14p2e2-s4p2e2)+ np.cos(s14p3e2-s4p3e2)+ np.cos(s14p1e2-s15p1e2)+ np.cos(s14p2e2-s15p2e2)+ np.cos(s14p3e2-s15p3e2)+ np.cos(s14p1e2-s24p1e2)+ np.cos(s14p2e2-s24p2e2)+ np.cos(s14p3e2-s24p3e2)+ np.cos(s14p1e2-s13p1e2)+ np.cos(s14p2e2-s13p2e2)+ np.cos(s14p3e2-s13p3e2)

    r14 = prob(H142)/prob(H14)
    x14 = np.random.choice([random.uniform(0, 1)])
    if r14 >= x14:
        s14p1n = s14p1e2
        s14p2n = s14p2e2
        s14p3n = s14p3e2
        
        s14p1 = s14p1e2
        s14p2 = s14p2e2
        s14p3 = s14p3e2
        
    else:
        s14p1n = s14p1
        s14p2n = s14p2
        s14p3n = s14p3
    if s14p1n>=s14p2n>=s14p3n:
        s14= -1
    if s14p2n>=s14p1n>=s14p3n:    
        s14=1
    if s14p3n>=s14p2n>=s14p1n:   
        s14=1
    if s14p3n>=s14p1n>=s14p2n:    
        s14= -1     
    if s14p1n>=s14p3n>=s14p2n:
        s14=1    
    if s14p2n>=s14p3n>=s14p1n:    
        s14= -1  
    s.append(s14)
    s14p1e2 = s14p1
    s14p2e2 = s14p2
    s14p3e2 = s14p3

    s15p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s15p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])                  
#site15    
    H15 =- np.cos(s15p3-s15p1)- np.cos(s15p2-s15p3)- np.cos(s15p1-s15p2)+ np.cos(s15p1-s5p1)+ np.cos(s15p2-s5p2)+ np.cos(s15p3-s5p3)+ np.cos(s15p1-s25p1)+ np.cos(s15p2-s25p2)+ np.cos(s15p3-s25p3)+ np.cos(s15p1-s14p1)+ np.cos(s15p2-s14p2)+ np.cos(s15p3-s14p3)+ np.cos(s15p1-s11p1)+ np.cos(s15p2-s11p2)+ np.cos(s15p3-s11p3)

    H152 =- np.cos(s15p3e2-s15p1e2)- np.cos(s15p2e2-s15p3e2)- np.cos(s15p1e2-s15p2e2)+ np.cos(s15p1e2-s5p1e2)+ np.cos(s15p2e2-s5p2e2)+ np.cos(s15p3e2-s5p3e2)+ np.cos(s15p1e2-s25p1e2)+ np.cos(s15p2e2-s25p2e2)+ np.cos(s15p3e2-s25p3e2)+ np.cos(s15p1e2-s14p1e2)+ np.cos(s15p2e2-s14p2e2)+ np.cos(s15p3e2-s14p3e2)+ np.cos(s15p1e2-s11p1e2)+ np.cos(s15p2e2-s11p2e2)+ np.cos(s15p3e2-s11p3e2)

    r15 = prob(H152)/prob(H15)
    x15 = np.random.choice([random.uniform(0, 1)])
    if r15 >= x15:
        s15p1n = s15p1e2
        s15p2n = s15p2e2
        s15p3n = s15p3e2
        
        s15p1 = s15p1e2
        s15p2 = s15p2e2
        s15p3 = s15p3e2
    else:
        s15p1n = s15p1
        s15p2n = s15p2
        s15p3n = s15p3
    if s15p1n>=s15p2n>=s15p3n:
        s15= -1
    if s15p2n>=s15p1n>=s15p3n:    
        s15=1
    if s15p3n>=s15p2n>=s15p1n:   
        s15=1
    if s15p3n>=s15p1n>=s15p2n:    
        s15= -1     
    if s15p1n>=s15p3n>=s15p2n:
        s15=1    
    if s15p2n>=s15p3n>=s15p1n:    
        s15= -1    
    s.append(s15) 
    s15p1e2 = s15p1
    s15p2e2 = s15p2
    s15p3e2 = s15p3

    s21p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s21p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
#site21    
    H21 =- np.cos(s21p3-s21p1)- np.cos(s21p2-s21p3)- np.cos(s21p1-s21p2)+ np.cos(s21p1-s11p1)+ np.cos(s21p2-s11p2)+ np.cos(s21p3-s11p3)+ np.cos(s21p1-s31p1)+ np.cos(s21p2-s31p2)+ np.cos(s21p3-s31p3)+ np.cos(s21p1-s22p1)+ np.cos(s21p2-s22p2)+ np.cos(s21p3-s22p3)+ np.cos(s21p1-s25p1)+ np.cos(s21p2-s25p2)+ np.cos(s21p3-s25p3)

    H212 =- np.cos(s21p3e2-s21p1e2)- np.cos(s21p2e2-s21p3e2)- np.cos(s21p1e2-s21p2e2)+ np.cos(s21p1e2-s11p1e2)+ np.cos(s21p2e2-s11p2e2)+ np.cos(s21p3e2-s11p3e2)+ np.cos(s21p1e2-s31p1e2)+ np.cos(s21p2e2-s31p2e2)+ np.cos(s21p3e2-s31p3e2)+ np.cos(s21p1e2-s22p1e2)+ np.cos(s21p2e2-s22p2e2)+ np.cos(s21p3e2-s22p3e2)+ np.cos(s21p1e2-s25p1e2)+ np.cos(s21p2e2-s25p2e2)+ np.cos(s21p3e2-s25p3e2)

    r21 = prob(H212)/prob(H21)
    x21 = np.random.choice([random.uniform(0, 1)])
    if r21 >= x21:
        s21p1n = s21p1e2
        s21p2n = s21p2e2
        s21p3n = s21p3e2
        
        s21p1 = s21p1e2
        s21p2 = s21p2e2
        s21p3 = s21p3e2
  
    else:
        s21p1n = s21p1
        s21p2n = s21p2
        s21p3n = s21p3
    if s21p1n>=s21p2n>=s21p3n:
        s21= -1
    if s21p2n>=s21p1n>=s21p3n:    
        s21=1
    if s21p3n>=s21p2n>=s21p1n:   
        s21=1
    if s21p3n>=s21p1n>=s21p2n:    
        s21= -1     
    if s21p1n>=s21p3n>=s21p2n:
        s21=1    
    if s21p2n>=s21p3n>=s21p1n:    
        s21= -1
    s.append(s21)
    s21p1e2 = s21p1
    s21p2e2 = s21p2
    s21p3e2 = s22p3   

    s22p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s22p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])            
#site22    
    H22 =- np.cos(s22p3-s22p1)- np.cos(s22p2-s22p3)- np.cos(s22p1-s22p2)+ np.cos(s22p1-s12p1)+ np.cos(s22p2-s12p2)+ np.cos(s22p3-s12p3)+ np.cos(s22p1-s32p1)+ np.cos(s22p2-s32p2)+ np.cos(s22p3-s32p3)+ np.cos(s22p1-s23p1)+ np.cos(s22p2-s23p2)+ np.cos(s22p3-s23p3)+ np.cos(s22p1-s21p1)+ np.cos(s22p2-s21p2)+ np.cos(s22p3-s21p3)

    H222 =- np.cos(s22p3e2-s22p1e2)- np.cos(s22p2e2-s22p3e2)- np.cos(s22p1e2-s22p2e2)+ np.cos(s22p1e2-s12p1e2)+ np.cos(s22p2e2-s12p2e2)+ np.cos(s22p3e2-s12p3e2)+ np.cos(s22p1e2-s32p1e2)+ np.cos(s22p2e2-s32p2e2)+ np.cos(s22p3e2-s32p3e2)+ np.cos(s22p1e2-s23p1e2)+ np.cos(s22p2e2-s23p2e2)+ np.cos(s22p3e2-s23p3e2)+ np.cos(s22p1e2-s21p1e2)+ np.cos(s22p2e2-s21p2e2)+ np.cos(s22p3e2-s21p3e2)

    r22 = prob(H222)/prob(H22)
    x22 = np.random.choice([random.uniform(0, 1)])
    if r22 >= x22:
        s22p1n = s22p1e2
        s22p2n = s22p2e2
        s22p3n = s22p3e2
        
        s22p1 = s22p1e2
        s22p2 = s22p2e2
        s22p3 = s22p3e2
        
    else:
        s22p1n = s22p1
        s22p2n = s22p2
        s22p3n = s22p3
    if s22p1n>=s22p2n>=s22p3n:
        s22= -1
    if s22p2n>=s22p1n>=s22p3n:    
        s22=1
    if s22p3n>=s22p2n>=s22p1n:   
        s22=1
    if s22p3n>=s22p1n>=s22p2n:    
        s22= -1     
    if s22p1n>=s22p3n>=s22p2n:
        s22=1    
    if s22p2n>=s22p3n>=s22p1n:    
        s22= -1    
    s.append(s22)    
    s22p1e2 = s22p1
    s22p2e2 = s22p2
    s22p3e2 = s22p3  
    
    s23p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s23p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])   
#site23    
    H23 =- np.cos(s23p3-s23p1)- np.cos(s23p2-s23p3)- np.cos(s23p1-s23p2)+ np.cos(s23p1-s13p1)+ np.cos(s23p2-s13p2)+ np.cos(s23p3-s13p3)+ np.cos(s23p1-s33p1)+ np.cos(s23p2-s33p2)+ np.cos(s23p3-s33p3)+ np.cos(s23p1-s24p1)+ np.cos(s23p2-s24p2)+ np.cos(s23p3-s24p3)+ np.cos(s23p1-s22p1)+ np.cos(s23p2-s22p2)+ np.cos(s23p3-s22p3)

    H232 =- np.cos(s23p3e2-s23p1e2)- np.cos(s23p2e2-s23p3e2)- np.cos(s23p1e2-s23p2e2)+ np.cos(s23p1e2-s13p1e2)+ np.cos(s23p2e2-s13p2e2)+ np.cos(s23p3e2-s13p3e2)+ np.cos(s23p1e2-s33p1e2)+ np.cos(s23p2e2-s33p2e2)+ np.cos(s23p3e2-s33p3e2)+ np.cos(s23p1e2-s24p1e2)+ np.cos(s23p2e2-s24p2e2)+ np.cos(s23p3e2-s24p3e2)+ np.cos(s23p1e2-s22p1e2)+ np.cos(s23p2e2-s22p2e2)+ np.cos(s23p3e2-s22p3e2)

    r23 = prob(H232)/prob(H23)
    x23 = np.random.choice([random.uniform(0, 1)])
    if r23>=x23:
        s23p1n = s23p1e2
        s23p2n = s23p2e2
        s23p3n = s23p3e2
        
        s23p1 = s23p1e2
        s23p2 = s23p2e2
        s23p3 = s23p3e2

    else:
        s23p1n = s23p1
        s23p2n = s23p2
        s23p3n = s23p3
    if s23p1n>=s23p2n>=s23p3n:
        s23= -1
    if s23p2n>=s23p1n>=s23p3n:    
        s23=1
    if s23p3n>=s23p2n>=s23p1n:   
        s23=1
    if s23p3n>=s23p1n>=s23p2n:    
        s23= -1     
    if s23p1n>=s23p3n>=s23p2n:
        s23=1    
    if s23p2n>=s23p3n>=s23p1n:    
        s23= -1  
    s.append(s23)    
    s23p1e2 = s23p1
    s23p2e2 = s23p2
    s23p3e2 = s23p3
    
    s24p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s24p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])           
#site24    
    H24 =- np.cos(s24p3-s24p1)- np.cos(s24p2-s24p3)- np.cos(s24p1-s24p2)+ np.cos(s24p1-s14p1)+ np.cos(s24p2-s14p2)+ np.cos(s24p3-s14p3)+ np.cos(s24p1-s34p1)+ np.cos(s24p2-s34p2)+ np.cos(s24p3-s34p3)+ np.cos(s24p1-s25p1)+ np.cos(s24p2-s25p2)+ np.cos(s24p3-s25p3)+ np.cos(s24p1-s23p1)+ np.cos(s24p2-s23p2)+ np.cos(s24p3-s23p3)

    H242 =- np.cos(s24p3e2-s24p1e2)- np.cos(s24p2e2-s24p3e2)- np.cos(s24p1e2-s24p2e2)+ np.cos(s24p1e2-s14p1e2)+ np.cos(s24p2e2-s14p2e2)+ np.cos(s24p3e2-s14p3e2)+ np.cos(s24p1e2-s34p1e2)+ np.cos(s24p2e2-s34p2e2)+ np.cos(s24p3e2-s34p3e2)+ np.cos(s24p1e2-s25p1e2)+ np.cos(s24p2e2-s25p2e2)+ np.cos(s24p3e2-s25p3e2)+ np.cos(s24p1e2-s23p1e2)+ np.cos(s24p2e2-s23p2e2)+ np.cos(s24p3e2-s23p3e2)

    r24 = prob(H242)/prob(H24)
    x24 = np.random.choice([random.uniform(0, 1)])
    if r24>=x24:
        s24p1n = s24p1e2
        s24p2n = s24p2e2
        s24p3n = s24p3e2
        
        s24p1 = s24p1e2
        s24p2 = s24p2e2
        s24p3 = s24p3e2

    else:
        s24p1n = s24p1
        s24p2n = s24p2
        s24p3n = s24p3 
    if s24p1n>=s24p2n>=s24p3n:
        s24= -1
    if s24p2n>=s24p1n>=s24p3n:    
        s24=1
    if s24p3n>=s24p2n>=s24p1n:   
        s24=1
    if s24p3n>=s24p1n>=s24p2n:    
        s24= -1     
    if s24p1n>=s24p3n>=s24p2n:
        s24=1    
    if s24p2n>=s24p3n>=s24p1n:    
        s24= -1  
    s.append(s24)            
    s24p1e2 = s24p1
    s24p2e2 = s24p2
    s24p3e2 = s24p3 
    
    s25p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s25p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])          
#site25    
    H25 =- np.cos(s25p3-s25p1)- np.cos(s25p2-s25p3)- np.cos(s25p1-s25p2)+ np.cos(s25p1-s15p1)+ np.cos(s25p2-s15p2)+ np.cos(s25p3-s15p3)+ np.cos(s25p1-s35p1)+ np.cos(s25p2-s35p2)+ np.cos(s25p3-s35p3)+ np.cos(s25p1-s24p1)+ np.cos(s25p2-s24p2)+ np.cos(s25p3-s24p3)+ np.cos(s25p1-s21p1)+ np.cos(s25p2-s21p2)+ np.cos(s25p3-s21p3)

    H252 =- np.cos(s25p3e2-s25p1e2)- np.cos(s25p2e2-s25p3e2)- np.cos(s25p1e2-s25p2e2)+ np.cos(s25p1e2-s15p1e2)+ np.cos(s25p2e2-s15p2e2)+ np.cos(s25p3e2-s15p3e2)+ np.cos(s25p1e2-s35p1e2)+ np.cos(s25p2e2-s35p2e2)+ np.cos(s25p3e2-s35p3e2)+ np.cos(s25p1e2-s24p1e2)+ np.cos(s25p2e2-s24p2e2)+ np.cos(s25p3e2-s24p3e2)+ np.cos(s25p1e2-s21p1e2)+ np.cos(s25p2e2-s21p2e2)+ np.cos(s25p3e2-s21p3e2)

    r25 = prob(H252)/prob(H25)
    x25 = np.random.choice([random.uniform(0, 1)])
    if r25>=x25:
        s25p1n = s25p1e2
        s25p2n = s25p2e2
        s25p3n = s25p3e2
        
        s25p1 = s25p1e2
        s25p2 = s25p2e2
        s25p3 = s25p3e2

    else:
        s25p1n = s25p1
        s25p2n = s25p2
        s25p3n = s25p3
    if s25p1n>=s25p2n>=s25p3n:
        s25= -1
    if s25p2n>=s25p1n>=s25p3n:    
        s25=1
    if s25p3n>=s25p2n>=s25p1n:   
        s25=1
    if s25p3n>=s25p1n>=s25p2n:    
        s25= -1     
    if s25p1n>=s25p3n>=s25p2n:
        s25=1    
    if s25p2n>=s25p3n>=s25p1n:    
        s25= -1 
    s.append(s25)    
    s25p1e2 = s25p1
    s25p2e2 = s25p2
    s25p3e2 = s25p3

    s31p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s31p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 

#site31    
    H31 =- np.cos(s31p3-s31p1)- np.cos(s31p2-s31p3)- np.cos(s31p1-s31p2)+ np.cos(s31p1-s21p1)+ np.cos(s31p2-s21p2)+ np.cos(s31p3-s21p3)+ np.cos(s31p1-s41p1)+ np.cos(s31p2-s41p2)+ np.cos(s31p3-s41p3)+ np.cos(s31p1-s32p1)+ np.cos(s31p2-s32p2)+ np.cos(s31p3-s32p3)+ np.cos(s31p1-s35p1)+ np.cos(s31p2-s35p2)+ np.cos(s31p3-s35p3)

    H312 =- np.cos(s31p3e2-s31p1e2)- np.cos(s31p2e2-s31p3e2)- np.cos(s31p1e2-s31p2e2)+ np.cos(s31p1e2-s21p1e2)+ np.cos(s31p2e2-s21p2e2)+ np.cos(s31p3e2-s21p3e2)+ np.cos(s31p1e2-s41p1e2)+ np.cos(s31p2e2-s41p2e2)+ np.cos(s31p3e2-s41p3e2)+ np.cos(s31p1e2-s32p1e2)+ np.cos(s31p2e2-s32p2e2)+ np.cos(s31p3e2-s32p3e2)+ np.cos(s31p1e2-s35p1e2)+ np.cos(s31p2e2-s35p2e2)+ np.cos(s31p3e2-s35p3e2)

    r31 = prob(H312)/prob(H31)
    x31 = np.random.choice([random.uniform(0, 1)])
    if r31>=x31:
        s31p1n = s31p1e2
        s31p2n = s31p2e2
        s31p3n = s31p3e2

        s31p1 = s31p1e2
        s31p2 = s31p2e2
        s31p3 = s31p3e2
    else:
        s31p1n = s31p1
        s31p2n = s31p2
        s31p3n = s31p3
    if s31p1n>=s31p2n>=s31p3n:
        s31= -1
    if s31p2n>=s31p1n>=s31p3n:    
        s31=1
    if s31p3n>=s31p2n>=s31p1n:   
        s31=1
    if s31p3n>=s31p1n>=s31p2n:    
        s31= -1     
    if s31p1n>=s31p3n>=s31p2n:
        s31=1    
    if s31p2n>=s31p3n>=s31p1n:    
        s31= -1
    s.append(s31)  
    s31p1e2 = s31p1
    s31p2e2 = s31p2
    s31p3e2 = s31p3
    
    s32p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s32p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
    
#site32    
    H32 =- np.cos(s32p3-s32p1)- np.cos(s32p2-s32p3)- np.cos(s32p1-s32p2)+ np.cos(s32p1-s22p1)+ np.cos(s32p2-s22p2)+ np.cos(s32p3-s22p3)+ np.cos(s32p1-s42p1)+ np.cos(s32p2-s42p2)+ np.cos(s32p3-s42p3)+ np.cos(s32p1-s33p1)+ np.cos(s32p2-s33p2)+ np.cos(s32p3-s33p3)+ np.cos(s32p1-s31p1)+ np.cos(s32p2-s31p2)+ np.cos(s32p3-s31p3)

    H322 =- np.cos(s32p3e2-s32p1e2)- np.cos(s32p2e2-s32p3e2)- np.cos(s32p1e2-s32p2e2)+ np.cos(s32p1e2-s22p1e2)+ np.cos(s32p2e2-s22p2e2)+ np.cos(s32p3e2-s22p3e2)+ np.cos(s32p1e2-s42p1e2)+ np.cos(s32p2e2-s42p2e2)+ np.cos(s32p3e2-s42p3e2)+ np.cos(s32p1e2-s33p1e2)+ np.cos(s32p2e2-s33p2e2)+ np.cos(s32p3e2-s33p3e2)+ np.cos(s32p1e2-s31p1e2)+ np.cos(s32p2e2-s31p2e2)+ np.cos(s32p3e2-s31p3e2)

    r32 = prob(H322)/prob(H32)
    x32 = np.random.choice([random.uniform(0, 1)])
    if r32>=x32:
        s32p1n = s32p1e2
        s32p2n = s32p2e2
        s32p3n = s32p3e2

        s32p1 = s32p1e2
        s32p2 = s32p2e2
        s32p3 = s32p3e2
    else:
        s32p1n = s32p1
        s32p2n = s32p2
        s32p3n = s32p3
    if s32p1n>=s32p2n>=s32p3n:
        s32= -1
    if s32p2n>=s32p1n>=s32p3n:    
        s32=1
    if s32p3n>=s32p2n>=s32p1n:   
        s32=1
    if s32p3n>=s32p1n>=s32p2n:    
        s32= -1     
    if s32p1n>=s32p3n>=s32p2n:
        s32=1    
    if s32p2n>=s32p3n>=s32p1n:    
        s32= -1    
    s.append(s32)            
    s32p1e2 = s32p1
    s32p2e2 = s32p2
    s32p3e2 = s32p3        
    
    s33p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s33p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site33    
    H33 =- np.cos(s33p3-s33p1)- np.cos(s33p2-s33p3)- np.cos(s33p1-s33p2)+ np.cos(s33p1-s23p1)+ np.cos(s33p2-s23p2)+ np.cos(s33p3-s23p3)+ np.cos(s33p1-s43p1)+ np.cos(s33p2-s43p2)+ np.cos(s33p3-s43p3)+ np.cos(s33p1-s34p1)+ np.cos(s33p2-s34p2)+ np.cos(s33p3-s34p3)+ np.cos(s33p1-s32p1)+ np.cos(s33p2-s32p2)+ np.cos(s33p3-s32p3)

    H332 =- np.cos(s33p3e2-s33p1e2)- np.cos(s33p2e2-s33p3e2)- np.cos(s33p1e2-s33p2e2)+ np.cos(s33p1e2-s23p1e2)+ np.cos(s33p2e2-s23p2e2)+ np.cos(s33p3e2-s23p3e2)+ np.cos(s33p1e2-s43p1e2)+ np.cos(s33p2e2-s43p2e2)+ np.cos(s33p3e2-s43p3e2)+ np.cos(s33p1e2-s34p1e2)+ np.cos(s33p2e2-s34p2e2)+ np.cos(s33p3e2-s34p3e2)+ np.cos(s33p1e2-s32p1e2)+ np.cos(s33p2e2-s32p2e2)+ np.cos(s33p3e2-s32p3e2)

    r33 = prob(H332)/prob(H33)
    x33 = np.random.choice([random.uniform(0, 1)])
    if r33>=x33:
        s33p1n = s33p1e2
        s33p2n = s33p2e2
        s33p3n = s33p3e2
        
        s33p1 = s33p1e2
        s33p2 = s33p2e2
        s33p3 = s33p3e2
        
    else:
        s33p1n = s33p1
        s33p2n = s33p2
        s33p3n = s33p3
    if s33p1n>=s33p2n>=s33p3n:
        s33= -1
    if s33p2n>=s33p1n>=s33p3n:    
        s33=1
    if s33p3n>=s33p2n>=s33p1n:   
        s33=1
    if s33p3n>=s33p1n>=s33p2n:    
        s33= -1     
    if s33p1n>=s33p3n>=s33p2n:
        s33=1    
    if s33p2n>=s33p3n>=s33p1n:    
        s33= -1
    s.append(s33)        
    s33p1e2 = s33p1
    s33p2e2 = s33p2
    s33p3e2 = s33p3

    s34p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s34p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site34    
    H34 =- np.cos(s34p3-s34p1)- np.cos(s34p2-s34p3)- np.cos(s34p1-s34p2)+ np.cos(s34p1-s24p1)+ np.cos(s34p2-s24p2)+ np.cos(s34p3-s24p3)+ np.cos(s34p1-s44p1)+ np.cos(s34p2-s44p2)+ np.cos(s34p3-s44p3)+ np.cos(s34p1-s35p1)+ np.cos(s34p2-s35p2)+ np.cos(s34p3-s35p3)+ np.cos(s34p1-s33p1)+ np.cos(s34p2-s33p2)+ np.cos(s34p3-s33p3)

    H342 =- np.cos(s34p3e2-s34p1e2)- np.cos(s34p2e2-s34p3e2)- np.cos(s34p1e2-s34p2e2)+ np.cos(s34p1e2-s24p1e2)+ np.cos(s34p2e2-s24p2e2)+ np.cos(s34p3e2-s24p3e2)+ np.cos(s34p1e2-s44p1e2)+ np.cos(s34p2e2-s44p2e2)+ np.cos(s34p3e2-s44p3e2)+ np.cos(s34p1e2-s35p1e2)+ np.cos(s34p2e2-s35p2e2)+ np.cos(s34p3e2-s35p3e2)+ np.cos(s34p1e2-s33p1e2)+ np.cos(s34p2e2-s33p2e2)+ np.cos(s34p3e2-s33p3e2)

    r34 = prob(H342)/prob(H34)
    x34 = np.random.choice([random.uniform(0, 1)])
    if r34>=x34:
        s34p1n = s34p1e2
        s34p2n = s34p2e2
        s34p3n = s34p3e2
        
        s34p1 = s34p1e2
        s34p2 = s34p2e2
        s34p3 = s34p3e2

    else:
        s34p1n = s34p1
        s34p2n = s34p2
        s34p3n = s34p3
    if s34p1n>=s34p2n>=s34p3n:
        s34= -1
    if s34p2n>=s34p1n>=s34p3n:    
        s34=1
    if s34p3n>=s34p2n>=s34p1n:   
        s34=1
    if s34p3n>=s34p1n>=s34p2n:    
        s34= -1     
    if s34p1n>=s34p3n>=s34p2n:
        s34=1    
    if s34p2n>=s34p3n>=s34p1n:    
        s34= -1    
    s.append(s34)        
    s34p1e2 = s34p1
    s34p2e2 = s34p2
    s34p3e2 = s34p3

    s35p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s35p3e2 = np.random.choice([random.uniform(0, 2*np.pi)]) 
#site35    
    H35 =- np.cos(s35p3-s35p1)- np.cos(s35p2-s35p3)- np.cos(s35p1-s35p2)+ np.cos(s35p1-s25p1)+ np.cos(s35p2-s25p2)+ np.cos(s35p3-s25p3)+ np.cos(s35p1-s45p1)+ np.cos(s35p2-s45p2)+ np.cos(s35p3-s45p3)+ np.cos(s35p1-s34p1)+ np.cos(s35p2-s34p2)+ np.cos(s35p3-s34p3)+ np.cos(s35p1-s31p1)+ np.cos(s35p2-s31p2)+ np.cos(s35p3-s31p3)

    H352 =- np.cos(s35p3e2-s35p1e2)- np.cos(s35p2e2-s35p3e2)- np.cos(s35p1e2-s35p2e2)+ np.cos(s35p1e2-s25p1e2)+ np.cos(s35p2e2-s25p2e2)+ np.cos(s35p3e2-s25p3e2)+ np.cos(s35p1e2-s45p1e2)+ np.cos(s35p2e2-s45p2e2)+ np.cos(s35p3e2-s45p3e2)+ np.cos(s35p1e2-s34p1e2)+ np.cos(s35p2e2-s34p2e2)+ np.cos(s35p3e2-s34p3e2)+ np.cos(s35p1e2-s31p1e2)+ np.cos(s35p2e2-s31p2e2)+ np.cos(s35p3e2-s31p3e2)

    r35 = prob(H352)/prob(H35)
    x35 = np.random.choice([random.uniform(0, 1)])
    if r35>=x35:
        s35p1n = s35p1e2
        s35p2n = s35p2e2
        s35p3n = s35p3e2
        
        s35p1 = s35p1e2
        s35p2 = s35p2e2
        s35p3 = s35p3e2

    else:
        s35p1n = s35p1
        s35p2n = s35p2
        s35p3n = s35p3
    if s35p1n>=s35p2n>=s35p3n:
        s35= -1
    if s35p2n>=s35p1n>=s35p3n:    
        s35=1
    if s35p3n>=s35p2n>=s35p1n:   
        s35=1
    if s35p3n>=s35p1n>=s35p2n:    
        s35= -1     
    if s35p1n>=s35p3n>=s35p2n:
        s35=1    
    if s35p2n>=s35p3n>=s35p1n:    
        s35= -1    
    s.append(s35)    
    s35p1e2 = s35p1
    s35p2e2 = s35p2
    s35p3e2 = s35p3

    s41p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s41p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site41    
    H41 =- np.cos(s41p3-s41p1)- np.cos(s41p2-s41p3)- np.cos(s41p1-s41p2)+ np.cos(s41p1-s31p1)+ np.cos(s41p2-s31p2)+ np.cos(s41p3-s31p3)+ np.cos(s41p1-s1p1)+ np.cos(s41p2-s1p2)+ np.cos(s41p3-s1p3)+ np.cos(s41p1-s42p1)+ np.cos(s41p2-s42p2)+ np.cos(s41p3-s42p3)+ np.cos(s41p1-s45p1)+ np.cos(s41p2-s45p2)+ np.cos(s41p3-s45p3)

    H412 =- np.cos(s41p3e2-s41p1e2)- np.cos(s41p2e2-s41p3e2)- np.cos(s41p1e2-s41p2e2)+ np.cos(s41p1e2-s31p1e2)+ np.cos(s41p2e2-s31p2e2)+ np.cos(s41p3e2-s31p3e2)+ np.cos(s41p1e2-s1p1e2)+ np.cos(s41p2e2-s1p2e2)+ np.cos(s41p3e2-s1p3e2)+ np.cos(s41p1e2-s42p1e2)+ np.cos(s41p2e2-s42p2e2)+ np.cos(s41p3e2-s42p3e2)+ np.cos(s41p1e2-s45p1e2)+ np.cos(s41p2e2-s45p2e2)+ np.cos(s41p3e2-s45p3e2)

    r41 = prob(H412)/prob(H41)
    x41 = np.random.choice([random.uniform(0, 1)])
    if r41>=x41:
        s41p1n = s41p1e2
        s41p2n = s41p2e2
        s41p3n = s41p3e2
        
        s41p1 = s41p1e2
        s41p2 = s41p2e2
        s41p3 = s41p3e2

    else:
        s41p1n = s41p1
        s41p2n = s41p2
        s41p3n = s41p3
    if s41p1n>=s41p2n>=s41p3n:
        s41= -1
    if s41p2n>=s41p1n>=s41p3n:    
        s41=1
    if s41p3n>=s41p2n>=s41p1n:   
        s41=1
    if s41p3n>=s41p1n>=s41p2n:    
        s41= -1     
    if s41p1n>=s41p3n>=s41p2n:
        s41=1    
    if s41p2n>=s41p3n>=s41p1n:    
        s41= -1  
    s.append(s41)    
    s41p1e2 = s41p1
    s41p2e2 = s41p2
    s41p3e2 = s42p3

    s42p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s42p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site42    
    H42 =- np.cos(s42p3-s42p1)- np.cos(s42p2-s42p3)- np.cos(s42p1-s42p2)+ np.cos(s42p1-s32p1)+ np.cos(s42p2-s32p2)+ np.cos(s42p3-s32p3)+ np.cos(s42p1-s2p1)+ np.cos(s42p2-s2p2)+ np.cos(s42p3-s2p3)+ np.cos(s42p1-s43p1)+ np.cos(s42p2-s43p2)+ np.cos(s42p3-s43p3)+ np.cos(s42p1-s41p1)+ np.cos(s42p2-s41p2)+ np.cos(s42p3-s41p3)

    H422 =- np.cos(s42p3e2-s42p1e2)- np.cos(s42p2e2-s42p3e2)- np.cos(s42p1e2-s42p2e2)+ np.cos(s42p1e2-s32p1e2)+ np.cos(s42p2e2-s32p2e2)+ np.cos(s42p3e2-s32p3e2)+ np.cos(s42p1e2-s2p1e2)+ np.cos(s42p2e2-s2p2e2)+ np.cos(s42p3e2-s2p3e2)+ np.cos(s42p1e2-s43p1e2)+ np.cos(s42p2e2-s43p2e2)+ np.cos(s42p3e2-s43p3e2)+ np.cos(s42p1e2-s41p1e2)+ np.cos(s42p2e2-s41p2e2)+ np.cos(s42p3e2-s41p3e2)

    r42 = prob(H422)/prob(H42)
    x42 = np.random.choice([random.uniform(0, 1)])
    if r42>=x42:
        s42p1n = s42p1e2
        s42p2n = s42p2e2
        s42p3n = s42p3e2
        
        s42p1 = s42p1e2
        s42p2 = s42p2e2
        s42p3 = s42p3e2

    else:
        s42p1n = s42p1
        s42p2n = s42p2
        s42p3n = s42p3
    if s42p1n>=s42p2n>=s42p3n:
        s42= -1
    if s42p2n>=s42p1n>=s42p3n:    
        s42=1
    if s42p3n>=s42p2n>=s42p1n:   
        s42=1
    if s42p3n>=s42p1n>=s42p2n:    
        s42= -1     
    if s42p1n>=s42p3n>=s42p2n:
        s42=1    
    if s42p2n>=s42p3n>=s42p1n:    
        s42= -1    
    s.append(s42)    
    s42p1e2 = s42p1
    s42p2e2 = s42p2
    s42p3e2 = s42p3

    s43p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s43p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site43    
    H43 =- np.cos(s43p3-s43p1)- np.cos(s43p2-s43p3)- np.cos(s43p1-s43p2)+ np.cos(s43p1-s33p1)+ np.cos(s43p2-s33p2)+ np.cos(s43p3-s33p3)+ np.cos(s43p1-s3p1)+ np.cos(s43p2-s3p2)+ np.cos(s43p3-s3p3)+ np.cos(s43p1-s44p1)+ np.cos(s43p2-s44p2)+ np.cos(s43p3-s44p3)+ np.cos(s43p1-s42p1)+ np.cos(s43p2-s42p2)+ np.cos(s43p3-s42p3)

    H432 =- np.cos(s43p3e2-s43p1e2)- np.cos(s43p2e2-s43p3e2)- np.cos(s43p1e2-s43p2e2)+ np.cos(s43p1e2-s33p1e2)+ np.cos(s43p2e2-s33p2e2)+ np.cos(s43p3e2-s33p3e2)+ np.cos(s43p1e2-s3p1e2)+ np.cos(s43p2e2-s3p2e2)+ np.cos(s43p3e2-s3p3e2)+ np.cos(s43p1e2-s44p1e2)+ np.cos(s43p2e2-s44p2e2)+ np.cos(s43p3e2-s44p3e2)+ np.cos(s43p1e2-s42p1e2)+ np.cos(s43p2e2-s42p2e2)+ np.cos(s43p3e2-s42p3e2)

    r43 = prob(H432)/prob(H43)
    x43 = np.random.choice([random.uniform(0, 1)])
    if r43>=x43:
        s43p1n = s43p1e2
        s43p2n = s43p2e2
        s43p3n = s43p3e2
        
        s43p1 = s43p1e2
        s43p2 = s43p2e2
        s43p3 = s43p3e2

    else:
        s43p1n = s43p1
        s43p2n = s43p2
        s43p3n = s43p3
    if s43p1n>=s43p2n>=s43p3n:
        s43= -1
    if s43p2n>=s43p1n>=s43p3n:    
        s43=1
    if s43p3n>=s43p2n>=s43p1n:   
        s43=1
    if s43p3n>=s43p1n>=s43p2n:    
        s43= -1     
    if s43p1n>=s43p3n>=s43p2n:
        s43=1    
    if s43p2n>=s43p3n>=s43p1n:    
        s43= -1 
    s.append(s43)    
    s43p1e2 = s43p1
    s43p2e2 = s43p2
    s43p3e2 = s43p3

    s44p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s44p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])
#site44    
    H44 =- np.cos(s44p3-s44p1)- np.cos(s44p2-s44p3)- np.cos(s44p1-s44p2)+ np.cos(s44p1-s34p1)+ np.cos(s44p2-s34p2)+ np.cos(s44p3-s34p3)+ np.cos(s44p1-s4p1)+ np.cos(s44p2-s4p2)+ np.cos(s44p3-s4p3)+ np.cos(s44p1-s45p1)+ np.cos(s44p2-s45p2)+ np.cos(s44p3-s45p3)+ np.cos(s44p1-s43p1)+ np.cos(s44p2-s43p2)+ np.cos(s44p3-s43p3)

    H442 =- np.cos(s44p3e2-s44p1e2)- np.cos(s44p2e2-s44p3e2)- np.cos(s44p1e2-s44p2e2)+ np.cos(s44p1e2-s34p1e2)+ np.cos(s44p2e2-s34p2e2)+ np.cos(s44p3e2-s34p3e2)+ np.cos(s44p1e2-s4p1e2)+ np.cos(s44p2e2-s4p2e2)+ np.cos(s44p3e2-s4p3e2)+ np.cos(s44p1e2-s45p1e2)+ np.cos(s44p2e2-s45p2e2)+ np.cos(s44p3e2-s45p3e2)+ np.cos(s44p1e2-s43p1e2)+ np.cos(s44p2e2-s43p2e2)+ np.cos(s44p3e2-s43p3e2)

    r44 = prob(H442)/prob(H44)
    x44 = np.random.choice([random.uniform(0, 1)])
    if r44>=x44:
        s44p1n = s44p1e2
        s44p2n = s44p2e2
        s44p3n = s44p3e2
        
        s44p1 = s44p1e2
        s44p2 = s44p2e2
        s44p3 = s44p3e2
 
    else:
        s44p1n = s44p1
        s44p2n = s44p2
        s44p3n = s44p3
    if s44p1n>=s44p2n>=s44p3n:
        s44= -1
    if s44p2n>=s44p1n>=s44p3n:    
        s44=1
    if s44p3n>=s44p2n>=s44p1n:   
        s44=1
    if s44p3n>=s44p1n>=s44p2n:    
        s44= -1     
    if s44p1n>=s44p3n>=s44p2n:
        s44=1    
    if s44p2n>=s44p3n>=s44p1n:    
        s44= -1 
    s.append(s44)            
    s44p1e2 = s44p1
    s44p2e2 = s44p2
    s44p3e2 = s44p3
    
    s45p1e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p2e2 = np.random.choice([random.uniform(0, 2*np.pi)])
    s45p3e2 = np.random.choice([random.uniform(0, 2*np.pi)])        
#site45    
    H45 =- np.cos(s45p3-s45p1)- np.cos(s45p2-s45p3)- np.cos(s45p1-s45p2)+ np.cos(s45p1-s35p1)+ np.cos(s45p2-s35p2)+ np.cos(s45p3-s35p3)+ np.cos(s45p1-s5p1)+ np.cos(s45p2-s5p2)+ np.cos(s45p3-s5p3)+ np.cos(s45p1-s44p1)+ np.cos(s45p2-s44p2)+ np.cos(s45p3-s44p3)+ np.cos(s45p1-s41p1)+ np.cos(s45p2-s41p2)+ np.cos(s45p3-s41p3)

    H452 =- np.cos(s45p3e2-s45p1e2)- np.cos(s45p2e2-s45p3e2)- np.cos(s45p1e2-s45p2e2)+ np.cos(s45p1e2-s35p1e2)+ np.cos(s45p2e2-s35p2e2)+ np.cos(s45p3e2-s35p3e2)+ np.cos(s45p1e2-s5p1e2)+ np.cos(s45p2e2-s5p2e2)+ np.cos(s45p3e2-s5p3e2)+ np.cos(s45p1e2-s44p1e2)+ np.cos(s45p2e2-s44p2e2)+ np.cos(s45p3e2-s44p3e2)+ np.cos(s45p1e2-s41p1e2)+ np.cos(s45p2e2-s41p2e2)+ np.cos(s45p3e2-s41p3e2)

    r45 = prob(H452)/prob(H45)
    x45 = np.random.choice([random.uniform(0, 1)])
    if r45>=x45:
        s45p1n = s45p1e2
        s45p2n = s45p2e2
        s45p3n = s45p3e2
        
        s45p1 = s45p1e2
        s45p2 = s45p2e2
        s45p3 = s45p3e2

    else:
        s45p1n = s45p1
        s45p2n = s45p2
        s45p3n = s45p3
    if s45p1n>=s45p2n>=s45p3n:
        s45= -1
    if s45p2n>=s45p1n>=s45p3n:    
        s45=1
    if s45p3n>=s45p2n>=s45p1n:   
        s45=1
    if s45p3n>=s45p1n>=s45p2n:    
        s45= -1     
    if s45p1n>=s45p3n>=s45p2n:
        s45=1    
    if s45p2n>=s45p3n>=s45p1n:    
        s45= -1  
    s.append(s45)
    SA.append(abs(mean(s)))
C=0
c=[]
s1=0
s2=1
S=[]
while s2<=999:
    S1= SA[s1]
    S2=SA[s2]
    c.append(np.sqrt(abs((1/1000)*S1*S2))+C)
    s1 = s1+1
    s2= s2+1
    C= C+np.sqrt(abs((1/1000)*S1*S2))
    S.append(s2)
plt.plot(S, c) 
plt.xlabel('Simulation number n')
plt.ylabel('Correlation between n-th/n+1-th value in %')
# Out:
# Text(0, 0.5, 'Correlation between n-th/n+1-th value in %')
